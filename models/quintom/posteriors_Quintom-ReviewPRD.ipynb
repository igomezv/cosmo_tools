# %%
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
from getdist import *

# import planckStyle
import pylab
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker

# matplotlib.use('TkAgg')
# %matplotlib inline

# %%
dir_name = "/home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/"

# PantheonPlus+HD23
roots_couple = [
#                 'Quintom_couple_phy_HD23_nested_multi',
#                 'Quintom_couple_phy_PantheonPlus_nested_multi',
                'Quintom_couple_phy_DR16BAO_nested_multi',
#                 'Quintom_couple_phy_PantheonPlus+HD23_nested_multi',
                'Quintom_couple_phy_DR16BAO+HD23_nested_multi',
#                 'Quintom_couple_phy_PantheonPlus+DR16BAO_nested_multi',
                'Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi',
                ]

roots_couple_all = [
                'Quintom_couple_phy_HD23_nested_multi',
                'Quintom_couple_phy_PantheonPlus_nested_multi',
                'Quintom_couple_phy_DR16BAO_nested_multi',
                'Quintom_couple_phy_PantheonPlus+HD23_nested_multi',
                'Quintom_couple_phy_DR16BAO+HD23_nested_multi',
                'Quintom_couple_phy_PantheonPlus+DR16BAO_nested_multi',
                'Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi',
                ]

roots_couple_final = [
                'Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi',
                ]

roots_couple_final_Planck = [
                'Quintom_couple_phy_HD23+PantheonPlus+DR16BAO+Planck_15_nested_multi',
                ]

roots_quintom = ['Quintom_phy_HD23_nested_multi',
                 'Quintom_phy_PantheonPlus_nested_multi',
                 'Quintom_phy_DR16BAO_nested_multi',
                 'Quintom_phy_PantheonPlus+HD23_nested_multi',
                 'Quintom_phy_DR16BAO+HD23_nested_multi',
                 'Quintom_phy_PantheonPlus+DR16BAO_nested_multi',
                 'Quintom_phy_HD23+PantheonPlus+DR16BAO_nested_multi']

roots_quintess = [
                 'Quintess_phy_HD23_nested_multi',
                 'Quintess_phy_PantheonPlus_nested_multi',
                 'Quintess_phy_DR16BAO_nested_multi',
                 'Quintess_phy_PantheonPlus+HD23_nested_multi',
                 'Quintess_phy_DR16BAO+HD23_nested_multi',
                 'Quintess_phy_PantheonPlus+DR16BAO_nested_multi',
                 'Quintess_phy_HD23+PantheonPlus+DR16BAO_nested_multi',
                 ]

roots_phantom = [ 
                'Phantom_phy_HD23_nested_multi',
                'Phantom_phy_PantheonPlus_nested_multi',
                'Phantom_phy_DR16BAO_nested_multi',
                'Phantom_phy_PantheonPlus+HD23_nested_multi',
                'Phantom_phy_DR16BAO+HD23_nested_multi',
                'Phantom_phy_PantheonPlus+DR16BAO_nested_multi',
                'Phantom_phy_HD23+PantheonPlus+DR16BAO_nested_multi',
                 ]

roots_mix = [
            'Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi',
            'Quintom_phy_HD23+PantheonPlus+DR16BAO_nested_multi',
            'Quintess_phy_HD23+PantheonPlus+DR16BAO_nested_multi',                
            'Phantom_phy_HD23+PantheonPlus+DR16BAO_nested_multi',
            ]


roots_lcdm = [
                'LCDM_phy_HD23_nested_multi',
                'LCDM_phy_PantheonPlus_nested_multi',
                'LCDM_phy_DR16BAO_nested_multi',
                'LCDM_phy_PantheonPlus+HD23_nested_multi',
                'LCDM_phy_DR16BAO+HD23_nested_multi',
                'LCDM_phy_PantheonPlus+DR16BAO_nested_multi',
                'LCDM_phy_HD23+PantheonPlus+DR16BAO_nested_multi',
                
]

type(roots_mix)
# Out:
# list

# %%
plt.figure(figsize=(12, 10), dpi=200)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.8,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 15
gg.settings.axes_fontsize = 18 
gg.settings.linewidth_meanlikes = 5
gg.settings.linewidth_contour = 1


# plt.figure(figsize=(10,8))
gg.plot_2d(roots_couple_all, 'h', 'beta', colors=['red','gray', 'green', 'blue', 'orange', 'black', 'purple'], 
          filled=True, alphas = [0.3, 0.6, 0.6, 0.8, 1], 
          legend_loc='upper right')

gg.add_text('Quintom with $\\beta$', 0.05, 0.06, fontsize=25)    

gg.add_y_marker(0, color='green', lw=3.0)
gg.add_x_marker(0.7324, color='purple', lw=3.0, ls='dotted')
gg.add_x_marker(0.674, color='brown', lw=3.0, ls='dashdot')

plt.text(0.32, 12, '·-·- $H_0 = 67.4$', fontsize=22, color='brown')
plt.text(0.32, 10.5, '··· $H_0 = 73.24$', fontsize=22, color='purple')
plt.text(0.32, 9, '--- $\\beta = 0$', fontsize=22, color='green')

gg.add_legend(['HD', 'SN', 'BAO', 'HD+SN', 'BAO+HD', 'BAO+SN', 'BAO+HD+SN'])
plt.xlim(0.3, 1.18)
plt.ylim(-14, 14)
# plt.grid()
plt.savefig('img/hvsbeta_QuintomCouple2_updated.png')
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_HD23_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_PantheonPlus_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_PantheonPlus+HD23_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_DR16BAO+HD23_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.8,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.2})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 15
gg.settings.axes_fontsize = 25 
gg.settings.linewidth_contour = 1



# plt.figure(figsize=(10,8))
gg.plot_2d(roots_couple_all, 'mquin', 'mphan',  colors=['red','gray', 'green', 'blue', 'orange', 'black', 'purple'], 
          filled=True, alphas = [0.3, 0.6, 0.7, 0.9, 0.9],
          legend_loc='upper right', plot_3d_with_param='beta')

gg.add_text('Quintom with $\\beta$', 0.05, 0.95, fontsize=25)        

#                 'Quintom_couple_phy_HD23_nested_multi',
#                 'Quintom_couple_phy_PantheonPlus_nested_multi',
#                 'Quintom_couple_phy_DR16BAO_nested_multi',
#                 'Quintom_couple_phy_PantheonPlus+HD23_nested_multi',
#                 'Quintom_couple_phy_DR16BAO+HD23_nested_multi',
#                 'Quintom_couple_phy_PantheonPlus+DR16BAO_nested_multi',
#                 'Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi',

gg.add_legend(['HD', 'SN', 'BAO', 'HD+SN', 'BAO+HD', 'SN+BAO', 'BAO+HD+SN'])
plt.xlim(0.0, 5.2)
plt.ylim(0.0, 3.5)
# plt.grid()
plt.savefig('img/mphinvsmphan_QuintomCouple_updated.png', dpi=80)
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_HD23_nested_multi_1.txt
# Removed 0.2 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_PantheonPlus_nested_multi_1.txt
# Removed 0.2 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_DR16BAO_nested_multi_1.txt
# Removed 0.2 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_PantheonPlus+HD23_nested_multi_1.txt
# Removed 0.2 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_DR16BAO+HD23_nested_multi_1.txt
# Removed 0.2 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.2 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.2 as burn in

# %%
plt.figure(figsize=(10, 10), dpi=100)

# gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.2})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 15
gg.settings.axes_fontsize = 25 
gg.settings.linewidth_contour = 1



# plt.figure(figsize=(10,8))
gg.plot_3d(roots_couple_final, ['mquin', 'mphan','beta'], 
          legend_loc='upper right', scatter_size=30)

# max_scatter_points – if set, maximum number of points to plots from each root)

gg.add_text(' Quintom + $\\beta$\n BAO+HD+SN', 0.05, 0.90, fontsize=20) 
gg.add_2d_contours(roots_couple_final[0], 'mquin','mphan')

# gg.add_legend(['CBAO+HD+SN'])
plt.xlim(0, 2.7)
plt.ylim(0.0, 2)
# plt.grid()
plt.savefig('img/mphinvsmphan_QuintomCouple2_updated.png', dpi=80)

# %%
plt.figure(figsize=(10, 10), dpi=100)

# gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.2})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 15
gg.settings.axes_fontsize = 25 
gg.settings.linewidth_contour = 1



# plt.figure(figsize=(10,8))
gg.plot_3d(roots_couple_final_Planck, ['mquin', 'mphan','beta'], 
          legend_loc='upper right', scatter_size=30)

# max_scatter_points – if set, maximum number of points to plots from each root)

gg.add_text(' Quintom + $\\beta$\n BAO+HD+SN+Planck', 0.05, 0.90, fontsize=20) 
gg.add_2d_contours(roots_couple_final_Planck[0], 'mquin','mphan')

# gg.add_legend(['CBAO+HD+SN'])
plt.xlim(0, 2.7)
plt.ylim(0.0, 2)
# plt.grid()
plt.savefig('img/mphinvsmphan_QuintomCouple_Planck2_updated.png', dpi=80)

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.4,
                                             'smooth_scale_1D': 0.4, 
                                             'ignore_rows': 0.2})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 15
gg.settings.axes_fontsize = 25 
gg.settings.linewidth_contour = 1



# plt.figure(figsize=(10,8))
gg.plot_3d(roots_couple_final_Planck, ['mquin', 'mphan','h'], 
          legend_loc='upper right', scatter_size=30)

# max_scatter_points – if set, maximum number of points to plots from each root)

gg.add_text(' Quintom with $\\beta$\n BAO+HD+SN+Planck', 0.05, 0.95, fontsize=20) 
gg.add_2d_contours(roots_couple_final_Planck[0], 'mquin','mphan')

# gg.add_legend(['CBAO+HD+SN'])
plt.xlim(0.0, 2.4)
# plt.ylim(-0.01, 3.2)
# plt.grid()
plt.savefig('img/mphinvsmphan_QuintomCouplePlanck_updated.png', dpi=80)

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.4,
                                             'smooth_scale_1D': 0.4, 
                                             'ignore_rows': 0.2})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 15
gg.settings.axes_fontsize = 25 
gg.settings.linewidth_contour = 1



# plt.figure(figsize=(10,8))
gg.plot_3d(roots_couple_final_Planck, ['mquin', 'mphan','beta'], 
          legend_loc='upper right', scatter_size=30)

# max_scatter_points – if set, maximum number of points to plots from each root)

gg.add_text(' Quintom + $\\beta$\n BAO+HD+SN', 0.05, 0.95, fontsize=20) 
gg.add_2d_contours(roots_couple_final_Planck[0], 'mquin','mphan')

# gg.add_legend(['CBAO+HD+SN'])
plt.xlim(-0.01, 2.4)
# plt.ylim(-0.01, 2.5)
# plt.grid()
plt.savefig('img/mphinvsmphan_QuintomCouple_updated.png', dpi=80)
# plt.savefig('img/mphinvsmphan+h_QuintomCouplePlanck15.png', dpi=80)

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.2})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 15
gg.settings.axes_fontsize = 25 
gg.settings.linewidth_contour = 1



# plt.figure(figsize=(10,8))
gg.plot_3d(roots_couple_final_Planck, ['beta', 'mphan','h'], 
          legend_loc='upper right', scatter_size=30)

# max_scatter_points – if set, maximum number of points to plots from each root)

gg.add_text(' Quintom with $\\beta$\n BAO+HD+SN+Planck', 0.95, 0.95, fontsize=20) 
gg.add_2d_contours(roots_couple_final_Planck[0], 'beta','mphan')

# gg.add_legend(['CBAO+HD+SN'])
# plt.xlim(-0.01, 4.2)
# plt.ylim(-0.01, 3.2)
# plt.grid()
# plt.savefig('img/mphinvsmphan_QuintomCouple.png', dpi=80)
plt.savefig('img/betavsmphan+h_QuintomCouplePlanck15_updated.png', dpi=80)

# %% [markdown]
# # Statistics

# %%
mc_samp = mcsamples.loadMCSamples(dir_name +'/'+ roots_lcdm[6], settings={'ignore_rows':0.0})
mcsamplefile = mc_samp
mcstats = mcsamplefile.getLikeStats()
summary = mcstats.likeSummary()

#                 0 '_phy_HD23_nested_multi',
#                 1 '_phy_PantheonPlus_nested_multi',
#                 2 '_phy_DR16BAO_nested_multi',
#                 3 '_phy_PantheonPlus+HD23_nested_multi',
#                 4 '_phy_DR16BAO+HD23_nested_multi',
#                 5 '_phy_PantheonPlus+DR16BAO_nested_multi',
#                 6 '_phy_HD23+PantheonPlus+DR16BAO_nested_multi',

# %%
summary
# Out:
# 'Best fit sample -log(Like) = 710.692825\nmean(-Ln(like)) = 712.172272\n-Ln(mean like)  = 711.713614\n'

# %%
print("-2loglike: {:.6}".format(2*mcstats.logLike_sample))
# Out:
# -2loglike: 1421.39

# %%
for i in [0,1,2,3,4,5]:
    print(mcstats.list()[i])
#     top = mcstats.names[i].ND_limit_top[1]
#     low = mcstats.names[i].ND_limit_bot[1]
    best = mcstats.names[i].bestfit_sample
    print(best)
    #print(top)
    #print(low)
    print("best %4.5f"%(best))
    print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
#     print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
    print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
#     print("$  {%4.3f} \pm $"%(mcsamplefile.getMeans()[i]))
    print("${:.3f} +/- {:.3f}$".format(mcsamplefile.getMeans()[i], mcsamplefile.std(mcstats.list()[i])))
    print("--"*20)
# Out:
# Om
# 0.31132309
# best 0.31132
# mean 0.31241
# std dev 0.0129
# $0.312 +/- 0.013$
# ----------------------------------------
# Obh2
# 0.02200535
# best 0.02201
# mean 0.02201
# std dev 0.0005
# $0.022 +/- 0.000$
# ----------------------------------------
# h
# 0.6972983
# best 0.69730
# mean 0.69728
# std dev 0.0191
# $0.697 +/- 0.019$
# ----------------------------------------
# Ol
# 0.6879498359196545
# best 0.68795
# mean 0.68758
# std dev 0.0130
# $0.688 +/- 0.013$
# ----------------------------------------
# H0
# 69.71140701719773
# best 69.71141
# mean 69.72822
# std dev 1.9110
# $69.728 +/- 1.911$
# ----------------------------------------
# Age
# 13.378127684198718
# best 13.37813
# mean 13.38422
# std dev 0.4009
# $13.384 +/- 0.401$
# ----------------------------------------
