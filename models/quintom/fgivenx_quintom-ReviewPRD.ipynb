# %%
# import planckStyle
import sys
import pylab
import numpy as np
import tkinter
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker

import fgivenx
from fgivenx import plot_contours, samples_from_getdist_chains, plot_lines, plot_dkl


sys.path.append("/home/isidro/Documents/github/SimpleMC/")
from simplemc.plots.plot_Quintom_variables import *
from simplemc.models.QuintomCosmology import QuintomCosmology
from simplemc.models.LCDMCosmology import LCDMCosmology
from simplemc.cosmo.paramDefs import *

# matplotlib.use('TkAgg')
# %matplotlib inline
# Out:
# Initalizing nu density look up table...
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# Done

# %%
dir_name = 'chains_quintom/'
cmap_reversed = matplotlib.cm.get_cmap('Greens_r')
# Out:
# /tmp/ipykernel_18285/2857714626.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_reversed = matplotlib.cm.get_cmap('Greens_r')

# %%
steps = 9
coupling = 0
fname = 'Quintom_coupling_both'


if fname == 'Quintessence':
    T = QuintomCosmology(vary_mquin=True)
    name = fname
    mlabel = '$m_\phi$'

if fname == 'Phantom':
    T = QuintomCosmology(vary_mphan=True)
    name = fname
    mlabel = '$m_\psi$'

if fname == 'Quintom_mquin':
    T = QuintomCosmology(vary_mquin=True, vary_mphan=True)
    mphan = 1.2
    name = 'Quintom, $m_{\psi}$=%0.1f'%mphan
    mlabel = '$m_\phi$'

if fname == 'Quintom_mphan':
    T = QuintomCosmology(vary_mquin=False, vary_mphan=True)
    mphi = 1.2
    name = 'Quintom, $m_{\phi}$=%0.1f'%mphi
    mlabel = '$m_\psi$'

if fname == 'Quintom_coupling_mquin':
    T = QuintomCosmology(vary_mquin=True, vary_coupling=True)
    mphan = 1.2
    coupling = 4.0
    name = 'Quintom, $m_{\psi}$=%0.1f, $\\beta=%0.1f$'%(mphan, coupling)
    mlabel = '$m_\phi$'

if fname == 'Quintom_coupling_mphan':
    T = QuintomCosmology(vary_mphan=True, vary_coupling=True)
    mphi = 1.0 #1.2
    coupling = 10 #6.0
    name = 'Quintom, $m_{\phi}$=%0.1f, $\\beta=%0.1f$'%(mphi, coupling)
    mlabel = '$m_\psi$'

if fname == 'Quintom_coupling_both':
    T = QuintomCosmology(vary_mquin=True, vary_mphan=True, vary_coupling=True)
    mphi = 2.0
    mphan = 1.0
    coupling = -1
    name = 'Quintom, $m_{\phi}$=%0.1f, $m_{\psi}$=%0.1f'%(mphi, mphan)
    mlabel = '$\\beta$'

if fname == 'Quintom_coupling_both':
    min, max = (4., 8.)
else:
    min, max = (0.1, 2.5)
if coupling < 0:
    min, max = (-10, -1.)

# %%
step = (max-min)/steps

mquin_ = mquin_par
mphan_ = mphan_par
coupling_ = coupling_par
om_ = Om_par
obh2_ = Obh2_par
h_ = h_par

ww = []
zz = []
PP = []


for i in np.arange(min, max, step):
    if fname == 'Quintessence':
        mquin_.setValue(i)
        T.updateParams([mquin_])

    if fname == 'Phantom':
        mphan_.setValue(i)
        T.updateParams([mphan_])


    if fname == 'Quintom_mquin':
        mquin_.setValue(i)
        mphan_.setValue(mphan)
        T.updateParams([mquin_, mphan_])


    if fname == 'Quintom_mphan':
        mphan_.setValue(i)
        mquin_.setValue(mphi)
        T.updateParams([mquin_, mphan_])

    if fname == 'Quintom_coupling_mquin':
        mquin_.setValue(i)
        mphan_.setValue(mphan)
        coupling_.setValue(coupling)
        T.updateParams([mquin_, mphan_, coupling_])

    if fname == 'Quintom_coupling_mphan':
        mquin_.setValue(mphi)
        mphan_.setValue(i)
        coupling_.setValue(coupling)
        T.updateParams([mquin_, mphan_, coupling_])

    if fname == 'Quintom_coupling_both':
        mquin_.setValue(mphi)
        mphan_.setValue(mphan)
        coupling_.setValue(i)
        T.updateParams([mquin_, mphan_, coupling_])


    T.call_functions()
    zl = np.arange(0, 3, 0.05)
    ww.append([T.w_de(1./(1+z)) for z in zl])
    PP.append(i)
    zz.append(zl)

# %%
def eos(z, params):
#     mphi, mphan, coupling = params
    om, obh2, h, mphi, mphan, coupling = params
    T = QuintomCosmology(vary_mquin=True, vary_mphan=True, vary_coupling=True)
    mquin_.setValue(mphi)
    mphan_.setValue(mphan)
    coupling_.setValue(coupling)
    om_.setValue(om)
    obh2_.setValue(obh2)
    h_.setValue(h)

    T.updateParams([om_, obh2_, h_, mquin_, mphan_, coupling_])
    T.call_functions()
    return T.w_de(1./(1+z))

# %%
# file_root = dir_name + 'Quintom_couple_phy_SN+HD+CBAO_nested_multi'
file_root = dir_name + 'PRDReview/Quintom_couple_phy_CBAO_nested_multi'


fig = plt.figure(figsize=(7,5), dpi=300)

samples, weights = samples_from_getdist_chains(['Om', 'Obh2', 'h','mquin', 'mphan', 'beta'], file_root,
                                               settings={'ignore_rows':0.5})
# k = np.linspace(0,2,9)
k = np.arange(0, 3.1, 0.05)

cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed, contour_line_levels=[1,2], 
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2],  )
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])
plt.hlines(-1, xmin=0, xmax=3, colors='blue',  linestyles='dashed', label='$w=-1$', lw=4)
# plt.ylabel(r'$H(z)/(1+z)[km\;s^{-1}Mpc^{-1}]$')
plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')
plt.ylim(-2,0)
plt.xlim(0, 2.9)
plt.tight_layout()
plt.grid()

# plt.legend(loc='lower left')
plt.text(0.01,-1.7, 'BAO', fontsize=13)
plt.savefig('img/eos_quintom_couple_cbao_burn5.png')
plt.savefig('img/eos_quintom_couple_cbao_burn5.svg')
# Out:
#   0%|          | 0/920 [00:00<?, ?it/s]
#   0%|          | 0/62 [00:00<?, ?it/s]

# %%
file_root = dir_name + '350/Quintom_couple_phy_CBAO_nested_multi'
# file_root = dir_name + 'PRDReview/Quintom_couple_phy_CBAO_nested_multi'
mcmc_bao = np.loadtxt(file_root+'_1.txt', usecols=[2,3,4,5,6,7])
np.shape(mcmc_bao)
# Out:
# (6878, 6)

# %%
zz = np.arange(0.01, 3.1, 0.5)
# 'Om', 'Obh2', 'h','mquin', 'mphan', 'beta'
eoss = []
for i, row in enumerate(mcmc_bao):    
    if i%2==0:
#         if row[5] <= 0:
        for z in zz:
            ev_eos = eos(zz, row)
#             if np.max(ev_eos) <= 1 and np.min(ev_eos) >= -3:
            eoss.append(ev_eos)

eoss = np.array(eoss)
np.shape(eoss), np.shape(zz), type(z), type(eoss)
# Out:
# /home/isidro/Documents/github/SimpleMC/simplemc/models/QuintomCosmology.py:144: RuntimeWarning: invalid value encountered in sqrt
#   hubble = self.h*np.sqrt(self.Omrad/a**4 + self.Ocb/a**3 + self.Ok/a**2 + self.Ol + omega_de)
# /home/isidro/.local/lib/python3.10/site-packages/scipy/integrate/_odepack_py.py:248: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3028801986060D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3028801986060D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3028801986060D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3028801986060D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3028801986060D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3028801986060D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.1876340555354D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2459405139167D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2748951062182D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2893453052690D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2965652279717D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3001740494283D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3028801986060D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3019781922052D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2213791799929D+00   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2213791799929D+00   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2213791799929D+00   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2213791799929D+00   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2213791799929D+00   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2213791799929D+00   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2213791799929D+00   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3472955754227D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3544917870253D+01   r2 =                  NaN
# /home/isidro/.local/lib/python3.10/site-packages/scipy/integrate/_odepack_py.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3472955754227D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3580896022033D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3544917870253D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3598884401341D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3580896022033D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3607878420177D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3598884401341D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2926624018122D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3503063228733D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2926624018122D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3790554848859D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3503063228733D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3934171529413D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3790554848859D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4005948545805D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3934171529413D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4041829135632D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4005948545805D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4059767429289D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4041829135632D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4068736072473D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4059767429289D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3472955754227D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3544917870253D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3472955754227D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3580896022033D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3544917870253D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3598884401341D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3580896022033D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3607878420177D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3598884401341D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2926624018122D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3503063228733D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2926624018122D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3790554848859D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3503063228733D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3934171529413D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3790554848859D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4005948545805D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3934171529413D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4041829135632D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4005948545805D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4059767429289D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4041829135632D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4068736072473D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4059767429289D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3472955754227D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3544917870253D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3472955754227D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3580896022033D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3544917870253D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3598884401341D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3580896022033D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3607878420177D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3598884401341D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2926624018122D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3503063228733D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2926624018122D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3790554848859D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3503063228733D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3934171529413D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3790554848859D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4005948545805D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3934171529413D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4041829135632D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4005948545805D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4059767429289D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4041829135632D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4068736072473D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4059767429289D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3472955754227D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3544917870253D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3472955754227D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3580896022033D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3544917870253D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3598884401341D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3580896022033D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3607878420177D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3598884401341D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2926624018122D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3503063228733D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2926624018122D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3790554848859D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3503063228733D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3934171529413D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3790554848859D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4005948545805D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3934171529413D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4041829135632D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4005948545805D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4059767429289D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4041829135632D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4068736072473D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4059767429289D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3472955754227D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3544917870253D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3472955754227D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3580896022033D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3544917870253D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3598884401341D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3580896022033D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3607878420177D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3598884401341D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2926624018122D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3503063228733D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2926624018122D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3790554848859D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3503063228733D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3934171529413D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3790554848859D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4005948545805D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3934171529413D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4041829135632D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4005948545805D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4059767429289D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4041829135632D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4068736072473D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4059767429289D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2463819121486D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3040973785941D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3472955754227D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3329005863789D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3544917870253D+01   r2 =                  NaN
# ...
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4047629112978D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4038640189536D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3114927804820D-02   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3114927804820D-02   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2899201966928D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3480013820475D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2899201966928D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3768683155856D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3480013820475D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3912731816707D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3768683155856D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3984694116519D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3912731816707D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4020660562418D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3984694116519D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4038640189536D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4020660562418D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4047629112978D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4038640189536D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3114927804820D-02   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3114927804820D-02   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2899201966928D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3480013820475D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2899201966928D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3768683155856D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3480013820475D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3912731816707D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3768683155856D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3984694116519D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3912731816707D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4020660562418D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3984694116519D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4038640189536D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4020660562418D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4047629112978D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4038640189536D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3114927804820D-02   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3114927804820D-02   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2899201966928D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3480013820475D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2899201966928D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3768683155856D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3480013820475D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3912731816707D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3768683155856D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3984694116519D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3912731816707D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4020660562418D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3984694116519D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4038640189536D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4020660562418D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4047629112978D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4038640189536D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3114927804820D-02   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3114927804820D-02   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2899201966928D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3480013820475D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.2899201966928D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3768683155856D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3480013820475D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3912731816707D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3768683155856D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3984694116519D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3912731816707D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4020660562418D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.3984694116519D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4038640189536D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4020660562418D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4047629112978D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4038640189536D+01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.4433830259811D-01   r2 =                  NaN
# ((24073, 7), (7,), numpy.float64, numpy.ndarray)

# %%
fig = plt.figure(figsize=(7,5), dpi=300)
for line in eoss:
    plt.plot(zz, line, alpha=0.05, lw=0.1, c='green')

plt.hlines(-1, xmin=0, xmax=3.05, colors='red',  linestyles='dashed', label='$w=-1$', lw=3, alpha=1)
plt.xlabel("Redshift z")
plt.ylabel("EoS")
plt.ylim(-2, 1)
plt.xlim(0, 3)
plt.legend()

# plt.savefig('img/linesEoSBAO_full4.png')
# Out:
# /home/isidro/anaconda3/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /home/isidro/anaconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
def hoverzfn(z, params):
    om, obh2, h, mphi, mphan, coupling = params
    T = QuintomCosmology(vary_mquin=True, vary_mphan=True, vary_coupling=True)
    mquin_.setValue(mphi)
    mphan_.setValue(mphan)
    coupling_.setValue(coupling)
    om_.setValue(om)
    obh2_.setValue(obh2)
    h_.setValue(h)

    T.updateParams([om_, obh2_, h_, mquin_, mphan_, coupling_])
#     mphi, mphan, coupling = params
#     T = QuintomCosmology(vary_mquin=True, vary_coupling=True)
#     mquin_.setValue(mphi)
#     mphan_.setValue(mphan)
#     coupling_.setValue(coupling)
#     T.updateParams([mquin_, mphan_, coupling_])
    T.call_functions()
    H = T.Hubble_a(1./(1+z))
    return H/(1+z)

# %%
file_root = dir_name + '350/Quintom_couple_phy_SN+HD+CBAO_nested_multi'
fig = plt.figure(figsize=(7,5), dpi=300)

# file_root = dir_name + 'Quintom_couple_phy_CBAO_nested_multi'

samples, weights = samples_from_getdist_chains(['Om', 'Obh2', 'h','mquin', 'mphan', 'beta'], file_root,
                                               settings={'ignore_rows':0.5})
# k = np.linspace(0,2,9)
k = np.arange(0, 3.1, 0.05)

cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed, contour_line_levels=[1,2], 
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2],  )
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])
plt.hlines(-1, xmin=0, xmax=3, colors='blue',  linestyles='dashed', label='$w=-1$', lw=4)

# plt.ylabel(r'$H(z)/(1+z)[km\;s^{-1}Mpc^{-1}]$')
plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')
plt.ylim(-2,0)
plt.xlim(0, 3)
plt.tight_layout()
plt.grid()

# plt.legend(loc='lower left')
# plt.text(0.01,-1.7, 'SN+HD+CBAO', fontsize=13)
plt.text(0.01,-1.7, 'BAO+HD+SN', fontsize=13)
# plt.savefig('img/eos_quintom_couple_sn+hd+cbao_burn5.png')
# plt.savefig('img/eos_quintom_couple_sn+hd+cbao_burn5.svg')
# Out:
# chains_quintom/350/Quintom_couple_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed 0.5 as burn in
#   0%|          | 0/765 [00:00<?, ?it/s]
#   0%|          | 0/62 [00:00<?, ?it/s]

# %%
# file_root = dir_name + '350/Quintom_couple_phy_SN+HD+CBAO_nested_multi'
file_root = dir_name + 'Quintom_couple_phy_SN+HD+CBAO_nested_multi'

fig = plt.figure(figsize=(7,5), dpi=300)

samples, weights = samples_from_getdist_chains(['Om', 'Obh2', 'h','mquin', 'mphan', 'beta'], file_root,
                                               settings={'ignore_rows':0.0})
# k = np.linspace(0,2,9)
k = np.arange(0, 3.1, 0.05)

cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed, contour_line_levels=[1,2], 
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2],  )
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])
plt.hlines(-1, xmin=0, xmax=3, colors='blue',  linestyles='dashed', label='$w=-1$', lw=4)

# plt.ylabel(r'$H(z)/(1+z)[km\;s^{-1}Mpc^{-1}]$')
plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')
plt.ylim(-2,0)
plt.xlim(0, 3)
plt.tight_layout()
plt.grid()

# plt.legend(loc='lower left')
# plt.text(0.01,-1.7, 'SN+HD+CBAO', fontsize=13)
plt.text(0.01,-1.7, 'BAO+HD+SN', fontsize=13)
plt.savefig('img/eos_quintom_couple_sn+hd+cbao_burn0.png')
plt.savefig('img/eos_quintom_couple_sn+hd+cbao_burn0.svg')
# Out:
# chains_quintom/Quintom_couple_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed no burn in
# HBox(children=(FloatProgress(value=0.0, max=968.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=62.0), HTML(value='')))

# %%
plt.savefig('img/eos_quintom_couple_sn+hd+cbao_burn0_250lp.png', dpi=300)
plt.savefig('img/eos_quintom_couple_sn+hd+cbao_burn0_250lp.svg')

# %%
def hoverzfn_lcdm(z, om, obh2, h):
    T = LCDMCosmology()
    om_.setValue(om)
    obh2_.setValue(obh2)
    h_.setValue(h)
    T.updateParams([om_, obh2_, h_])
    h_list =[]
    for zz in z:
#       T.RHSquared_a = E(z) = H(z)^2/H(z=0)^2
        Ez = T.RHSquared_a(1./(1+zz))
        H = np.sqrt((100*h)**2*Ez)
        hinv = H/(1+zz)
        h_list.append(hinv)
           
    return np.array(h_list)

# %%
z = np.linspace(0, 3, 100)
rd_fid_DR12 = 147.78

zLyaA = 2.34
zLyaC = 2.35
zCombBAO1 = 0.38
zCombBAO2 = 0.51
zCombBAO3 = 0.61
fact = (300000./rd_fid_DR12)

def ersys(x, y):
    return np.sqrt(x**2 + y**2)

lcdmzh = hoverzfn_lcdm(z, h=0.68, obh2=0.0220, om=0.31)

# %%
plt.plot(z, lcdmzh)
plt.show()

# %%
file_root = dir_name + '/350/Quintom_couple_phy_SN+HD+CBAO_nested_multi'
# file_root = dir_name + '/350/Quintom_couple_phy_CBAO_nested_multi'

fig = plt.figure(figsize=(7,5), dpi=300)

samples, weights = samples_from_getdist_chains(['Om', 'Obh2', 'h','mquin', 'mphan', 'beta'], file_root, 
                                              settings={'ignore_rows':0.0})
# k = np.linspace(0,2.0,100)
k = np.arange(0,3.1, 0.05)

cbar = plot_contours(hoverzfn, k, samples, weights=weights, contour_line_levels=[1,2],  
                     colors=cmap_reversed, linewidths=[2,1.5] )
cbar = plt.colorbar(cbar,ticks=[0,1,2])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])

# plt.errorbar(0.02,  69.8,       yerr=0.8, color='green', fmt='o', markersize=5, elinewidth=1., capsize=5, capthick=2)
# plt.errorbar(0.38,  63.9,       yerr=1.0, color='green', fmt='d', markersize=5, elinewidth=1., capsize=5, capthick=2)
# plt.errorbar(0.51,  62.6,       yerr=1.0, color='green', fmt='d', markersize=5, elinewidth=1., capsize=5, capthick=2)
# plt.errorbar(0.61,  61.9,       yerr=1.0, color='green', fmt='d', markersize=5, elinewidth=1., capsize=5, capthick=2)
# plt.errorbar(2.34,  65.6,       yerr=3.3, color='green', fmt='s', markersize=5, elinewidth=1., capsize=5, capthick=2)
# plt.errorbar(2.36,  67.8,       yerr=3.4, color='green', fmt='s', markersize=5, elinewidth=1., capsize=5, capthick=2)

#https://arxiv.org/abs/1904.03430
plt.errorbar(zLyaC,  fact/9.20/(1+zLyaC),        yerr=0.36*fact/(1+zLyaC)/9.20**2,
              color='red', fmt='s', markersize=6, elinewidth=1.5)
#https://arxiv.org/abs/1904.03430
plt.errorbar(zLyaA,  fact/8.86/(1+zLyaA),        yerr=0.29*fact/(1+zLyaA)/8.86**2,
              color='red', fmt='s', markersize=6, elinewidth=1.5)

plt.errorbar(zCombBAO1,  81.21/(1+zCombBAO1),       yerr=ersys(2.17, 0.97)/(1+zCombBAO1),
              color='red', fmt='d', markersize=6, elinewidth=1.5)
plt.errorbar(zCombBAO2,  90.90/(1+zCombBAO2),       yerr=ersys(2.07, 1.08)/(1+zCombBAO1),
              color='red', fmt='d', markersize=6, elinewidth=1.5)
plt.errorbar(zCombBAO3,  98.96/(1+zCombBAO3),       yerr=ersys(2.21, 1.18)/(1+zCombBAO1),
              color='red', fmt='d', markersize=6, elinewidth=1.5)
plt.errorbar(0.01,  69.8,       yerr=0.8,
              color='red', fmt='d', markersize=6, elinewidth=1.5)

plt.errorbar(1.52,  159/(1+1.52), yerr=12/(1+1.52),
              color='red', fmt='d', markersize=6, elinewidth=1.5)


plt.plot(z, lcdmzh, color='blue', label=r'$\Lambda CDM$', lw=4,  linestyle='dashed')

# plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$w=-1$', lw=2)
plt.ylabel(r'$H(z)/(1+z)[km\;s^{-1}Mpc^{-1}]$')
# plt.ylabel(r'$\omega(z)$')
plt.xlabel(r'$z$')
plt.xlim(0,3)
plt.ylim(45,80)
plt.tight_layout()
pylab.grid(True)


plt.legend(loc='lower left')
plt.text(0.01,76, 'BAO+HD+SN', fontsize=13)
plt.savefig('img/hzfn_quintom_couple_sn+hd+cbao.png')
plt.savefig('img/hzfn_quintom_couple_sn+hd+cbao.svg')
# plt.text(0.01,76, 'CBAO', fontsize=13)
# plt.savefig('hzfn_quintom_couple_cbao.png', dpi=300)
# plt.savefig('hzfn_quintom_couple_cbao.svg')
# Out:
# chains_quintom//350/Quintom_couple_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed no burn in
# HBox(children=(FloatProgress(value=0.0, max=1407.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 11
#       8 # k = np.linspace(0,2.0,100)
#       9 k = np.arange(0,3.1, 0.05)
# ---> 11 cbar = plot_contours(hoverzfn, k, samples, weights=weights, contour_line_levels=[1,2],
#      12                      colors=cmap_reversed, linewidths=[2,1.5] )
#      13 cbar = plt.colorbar(cbar,ticks=[0,1,2])
#      14 cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])
#
# File ~/.local/lib/python3.10/site-packages/fgivenx/drivers.py:122, in plot_contours(f, x, samples, ax, **kwargs)
#     119 parallel = kwargs.pop('parallel', False)
#     120 tqdm_kwargs = kwargs.pop('tqdm_kwargs', {})
# --> 122 y, pmf = compute_pmf(f, x, samples, weights=weights, logZ=logZ,
#     123                      ntrim=ntrim, ny=ny, y=y,
#     124                      parallel=parallel, cache=cache,
#     125                      tqdm_kwargs=tqdm_kwargs)
#     126 cbar = fgivenx.plot.plot(x, y, pmf, ax, **kwargs)
#     127 return cbar
#
# File ~/.local/lib/python3.10/site-packages/fgivenx/drivers.py:437, in compute_pmf(f, x, samples, **kwargs)
#     434     if len(y.shape) != 1:
#     435         raise ValueError("y should be a 1D array")
# --> 437 fsamps = compute_samples(f, x, samples, logZ=logZ,
#     438                          weights=weights, ntrim=ntrim,
#     439                          parallel=parallel, cache=cache,
#     440                          tqdm_kwargs=tqdm_kwargs)
#     442 if y is None:
#     443     ymin = fsamps[~numpy.isnan(fsamps)].min(axis=None)
#
# File ~/.local/lib/python3.10/site-packages/fgivenx/drivers.py:350, in compute_samples(f, x, samples, **kwargs)
#     347 for i, (s, w) in enumerate(zip(samples, weights)):
#     348     samples[i] = _equally_weight_samples(s, w)
# --> 350 return fgivenx.samples.compute_samples(f, x, samples,
#     351                                        parallel=parallel, cache=cache,
#     352                                        tqdm_kwargs=tqdm_kwargs)
#
# File ~/.local/lib/python3.10/site-packages/fgivenx/samples.py:51, in compute_samples(f, x, samples, **kwargs)
#      49 for fi, s in zip(f, samples):
#      50     if len(s) > 0:
# ---> 51         fsamps = parallel_apply(fi, s, precurry=(x,), parallel=parallel,
#      52                                 tqdm_kwargs=tqdm_kwargs)
#      53         fsamps = numpy.array(fsamps).transpose().copy()
#      54         fsamples.append(fsamps)
#
# File ~/.local/lib/python3.10/site-packages/fgivenx/parallel.py:77, in parallel_apply(f, array, **kwargs)
#      75     progress = tqdm
#      76 if not parallel:
# ---> 77     return [f(*(precurry + (x,) + postcurry)) for x in
#      78             progress(array, **tqdm_kwargs)]
#      79 elif parallel is True:
#      80     parallel = cpu_count()
#
# File ~/.local/lib/python3.10/site-packages/fgivenx/parallel.py:77, in <listcomp>(.0)
#      75     progress = tqdm
#      76 if not parallel:
# ---> 77     return [f(*(precurry + (x,) + postcurry)) for x in
#      78             progress(array, **tqdm_kwargs)]
#      79 elif parallel is True:
#      80     parallel = cpu_count()
#
# Cell In[11], line 11, in hoverzfn(z, params)
#       8     obh2_.setValue(obh2)
#       9     h_.setValue(h)
# ---> 11     T.updateParams([om_, obh2_, h_, mquin_, mphan_, coupling_])
#      12 #     mphi, mphan, coupling = params
#      13 #     T = QuintomCosmology(vary_mquin=True, vary_coupling=True)
#      14 #     mquin_.setValue(mphi)
#      15 #     mphan_.setValue(mphan)
#      16 #     coupling_.setValue(coupling)
#      17 #     T.updateParams([mquin_, mphan_, coupling_])
#      18     T.call_functions()
#
# File ~/Documents/github/SimpleMC/simplemc/models/QuintomCosmology.py:87, in QuintomCosmology.updateParams(self, pars)
#      84     print ('mphi={}, mphan={}, coupling={}'.format(self.mquin, self.mphan, self.coupling))
#      86 # Main method.
# ---> 87 self.initialize()
#      89 return True
#
# File ~/Documents/github/SimpleMC/simplemc/models/QuintomCosmology.py:272, in QuintomCosmology.initialize(self)
#     269 high_guess = 2 if self.coupling >0 else 1
#     271 #It's slower than newton, but finds more solutions
# --> 272 self.phi_ini, self.solution = self.find_initial_phi(-2, high_guess)
#     274 if self.phi_ini == 0:
#     275     # Solution couldn't be found, then reject that point.
#     276     hubble = np.zeros(len(self.lna))
#
# File ~/Documents/github/SimpleMC/simplemc/models/QuintomCosmology.py:236, in QuintomCosmology.find_initial_phi(self, low_guess, high_guess, tolerance)
#     233 while (high_guess - low_guess) > tolerance:
#     234     # Compute the solution for an initial guess.
#     235     solution, current_tolerance = self.compute_omega_de(mid_guess)
# --> 236     low_tolerance = self.compute_omega_de(low_guess)[1]
#     238     if self.chatty:
#     239         print('-done- phi_0={}, error={}'.format(mid_guess, current_tolerance))
#
# File ~/Documents/github/SimpleMC/simplemc/models/QuintomCosmology.py:196, in QuintomCosmology.compute_omega_de(self, ini_guess)
#     193         phi_ini, psi_ini = 10**ini_guess, 10**ini_guess
#     195 # Find the solution for such a guess.
# --> 196 solution = self.solve_eqns(phi_ini, 0.0, psi_ini, 0.0)
#     198 # Solution at a=1.
#     199 sf_rho = self.sf_rho(solution[-1])
#
# File ~/Documents/github/SimpleMC/simplemc/models/QuintomCosmology.py:172, in QuintomCosmology.solve_eqns(self, *y0)
#     167 def solve_eqns(self, *y0):
#     168     """
#     169     Input initial conditions for [phi, dotPhi, psi, dotPhi] and returns
#     170     the solution of the Klein-Gordon equations.
#     171     """
# --> 172     solution = odeint(self.right_hand_side, y0, self.lna, h0=1E-10)
#     173     return solution
#
# File ~/.local/lib/python3.10/site-packages/scipy/integrate/_odepack_py.py:242, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     240 t = copy(t)
#     241 y0 = copy(y0)
# --> 242 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     243                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     244                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     245                          int(bool(tfirst)))
#     246 if output[-1] < 0:
#     247     warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# File ~/Documents/github/SimpleMC/simplemc/models/QuintomCosmology.py:161, in QuintomCosmology.right_hand_side(self, variables, lna)
#     157 phi, x_phi, psi, x_psi = variables
#     159 # Right hand side of the dynamical system.
#     160 rhs = [factor*x_phi/hubble,
# --> 161        -3*x_phi - self.sf_potential(phi, psi, 'phi')/(factor*hubble),
#     162        factor*x_psi/hubble,
#     163        -3*x_psi + self.sf_potential(phi, psi, 'psi')/(factor*hubble)]
#     164 return rhs
#
# File ~/Documents/github/SimpleMC/simplemc/models/QuintomCosmology.py:92, in QuintomCosmology.sf_potential(self, phi, psi, select)
#      87     self.initialize()
#      89     return True
# ---> 92 def sf_potential(self, phi, psi, select):
#      93     """ The quadratic potential.
#      94     Select:
#      95         (0) the potential,
#      96         ('phi') derivative wrt phi,
#      97         ('psi') derivative wrt psi.
#      98     """
#     100     if select == 0:
#
# KeyboardInterrupt:

# %%
# file_root = dir_name + '/350/Quintom_couple_phy_SN+HD+CBAO_nested_multi'
file_root = dir_name + '/350/Quintom_couple_phy_CBAO_nested_multi'

fig = plt.figure(figsize=(7,5), dpi=300)

samples, weights = samples_from_getdist_chains(['Om', 'Obh2', 'h','mquin', 'mphan', 'beta'], file_root, 
                                              settings={'ignore_rows':0.0})
# k = np.linspace(0,2.0,100)
k = np.arange(0,3.1, 0.05)

cbar = plot_contours(hoverzfn, k, samples, weights=weights, contour_line_levels=[1,2],  
                     colors=cmap_reversed, linewidths=[2,1.5] )
cbar = plt.colorbar(cbar,ticks=[0,1,2])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])

#https://arxiv.org/abs/1904.03430
plt.errorbar(zLyaC,  fact/9.20/(1+zLyaC),        yerr=0.36*fact/(1+zLyaC)/9.20**2,
              color='red', fmt='s', markersize=6, elinewidth=1.5)
#https://arxiv.org/abs/1904.03430
plt.errorbar(zLyaA,  fact/8.86/(1+zLyaA),        yerr=0.29*fact/(1+zLyaA)/8.86**2,
              color='red', fmt='s', markersize=6, elinewidth=1.5)

plt.errorbar(zCombBAO1,  81.21/(1+zCombBAO1),       yerr=ersys(2.17, 0.97)/(1+zCombBAO1),
              color='red', fmt='d', markersize=6, elinewidth=1.5)
plt.errorbar(zCombBAO2,  90.90/(1+zCombBAO2),       yerr=ersys(2.07, 1.08)/(1+zCombBAO1),
              color='red', fmt='d', markersize=6, elinewidth=1.5)
plt.errorbar(zCombBAO3,  98.96/(1+zCombBAO3),       yerr=ersys(2.21, 1.18)/(1+zCombBAO1),
              color='red', fmt='d', markersize=6, elinewidth=1.5)
plt.errorbar(0.01,  69.8,       yerr=0.8,
              color='red', fmt='d', markersize=6, elinewidth=1.5)

plt.errorbar(1.52,  159/(1+1.52), yerr=12/(1+1.52),
              color='red', fmt='d', markersize=6, elinewidth=1.5)

# plt.errorbar(0.02,  69.8,       yerr=0.8, color='green', fmt='o', markersize=5, elinewidth=1., capsize=5, capthick=2)
# plt.errorbar(0.38,  63.9,       yerr=1.0, color='green', fmt='d', markersize=5, elinewidth=1., capsize=5, capthick=2)
# plt.errorbar(0.51,  62.6,       yerr=1.0, color='green', fmt='d', markersize=5, elinewidth=1., capsize=5, capthick=2)
# plt.errorbar(0.61,  61.9,       yerr=1.0, color='green', fmt='d', markersize=5, elinewidth=1., capsize=5, capthick=2)
# plt.errorbar(2.34,  65.6,       yerr=3.3, color='green', fmt='s', markersize=5, elinewidth=1., capsize=5, capthick=2)
# plt.errorbar(2.36,  67.8,       yerr=3.4, color='green', fmt='s', markersize=5, elinewidth=1., capsize=5, capthick=2)


plt.plot(z, lcdmzh, color='blue', label=r'$\Lambda CDM$', lw=4,  linestyle='dashed')

# plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$w=-1$', lw=2)
plt.ylabel(r'$H(z)/(1+z)[km\;s^{-1}Mpc^{-1}]$')
# plt.ylabel(r'$\omega(z)$')
plt.xlabel(r'$z$')
plt.xlim(0,3)
plt.ylim(45,80)
plt.tight_layout()
pylab.grid(True)


plt.legend(loc='lower left')
# plt.text(0.01,76, 'SN+HD+CBAO', fontsize=13)
# plt.savefig('hzfn_quintom_couple_sn+hd+cbao.png', dpi=300)
# plt.savefig('hzfn_quintom_couple_sn+hd+cbao.svg')
plt.text(0.01,76, 'BAO', fontsize=13)
plt.savefig('img/hzfn_quintom_couple_cbao.png')
plt.savefig('img/hzfn_quintom_couple_cbao.svg')

# %%
def hfn(z, params):
    om, obh2, h, mphi, mphan, coupling = params
    T = QuintomCosmology(vary_mquin=True, vary_mphan=True, vary_coupling=True)
    mquin_.setValue(mphi)
    mphan_.setValue(mphan)
    coupling_.setValue(coupling)
    om_.setValue(om)
    obh2_.setValue(obh2)
    h_.setValue(h)

    T.updateParams([om_, obh2_, h_, mquin_, mphan_, coupling_])

    T.call_functions()
    H = T.Hubble_a(1./(1+z))
    return H

# %%
file_root = dir_name + '/350/Quintom_couple_phy_SN+HD+CBAO_nested_multi'
# file_root = dir_name + '/350/Quintom_couple_phy_CBAO_nested_multi'

samples, weights = samples_from_getdist_chains(['Om', 'Obh2', 'h','mquin', 'mphan', 'beta'], file_root)
# k = np.linspace(0,2.0,100)
k = np.arange(0, 2.5, 0.05)

cbar = plot_contours(hfn, k, samples, weights=weights, colors=cmap_reversed, linewidths=[2,1.5,1],
                    contour_line_levels=[1,2])
cbar = plt.colorbar(cbar,ticks=[0,1,2])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])

# plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$w=-1$', lw=2)
plt.ylabel(r'$H(z)[km\;s^{-1}Mpc^{-1}]$')
# plt.ylabel(r'$\omega(z)$')
plt.xlabel(r'$z$')
# plt.ylim(60,)
plt.tight_layout()
pylab.grid(True)

plt.text(0.01,250, 'SN+HD+CBAO', fontsize=13)
plt.savefig('img/hfn_quintom_couple_sn+hd+cbao.png', dpi=300)
plt.savefig('img/hfn_quintom_couple_sn+hd+cbao.svg')
# plt.text(0.01,250, 'CBAO', fontsize=13)
# plt.savefig('hfn_quintom_couple_cbao.png', dpi=300)
# plt.savefig('hfn_quintom_couple_cbao.svg')

# %%
#Planck best fit cosmology
T2 = LCDMCosmology()
x1 = [67.4*np.sqrt(T2.RHSquared_a(1./(1+z))) for z in zl]
x2 = [T2.HIOverrd(z)*z/fixer(z) for z in zl]
x3 = [T2.DaOverrd(z)/fixer(z) for z in zl]
#PLK-15
#T=LCDMCosmology(Obh2=0.02225,Om=0.3156,h=0.6727)



params1 = {'backend': 'pdf',
               'axes.labelsize': 18,
               'xtick.labelsize': 18,
               'ytick.labelsize': 18,
               'legend.fontsize': 16,
               'lines.markersize': 6,
               'font.size': 20,
               'text.usetex': True}
pylab.rcParams.update(params1)


## --- Plotting --
fig, (ax2, ax3, ax4)= plt.subplots(3, sharex=True, gridspec_kw={'hspace': 0}, figsize=(7,10))
fig.suptitle(name, fontsize=17,  y=0.95)




## -- Plot 2
ax2.plot(zl, x1 , color='k', linestyle='--')
ax2.set_ylabel('$H(z)$', fontsize=20)



## -- Plot 3
ax3.plot(zl, x2 , color='k', linestyle='--')
ax3.set_ylabel("${\\rm zD_H(z)}/r_d\\sqrt{z}$")


## -- Plot 4
ax4.plot(zl, x3, color='k', linestyle='--')
ax4.set_xlim(0.05, 3)
ax4.set_ylabel("${\\rm D_M(z)}/r_d\\sqrt{z}$")





#Axis
ax4.xaxis.set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax4.yaxis.set_major_formatter(matplotlib.ticker.ScalarFormatter())
#ax4.xaxis.set_minor_formatter(plt.ScalarFormatter())
#ax4.xaxis.set_major_locator(plt.FixedLocator([0.1,1.0]))
#ax4.xaxis.set_minor_locator(plt.FixedLocator([0.2,0.5,2]))
ax4.set_xlabel("$z$")


#pylab.savefig("Fig1_"+fname+".pdf", bbox_inches='tight')
pylab.show()

# %%
z = np.linspace(0, 3, 100)
rd_fid_DR12 = 147.78

zLyaA = 2.37
zLyaC = 2.35
zCombBAO1 = 0.38
zCombBAO2 = 0.51
zCombBAO3 = 0.61
fact = (300000./rd_fid_DR12)

def ersys(x, y):
    return np.sqrt(x**2 + y**2)

#https://arxiv.org/abs/1904.03430
plt.errorbar(zLyaC,  fact/9.20/(1+zLyaC),        yerr=0.36*fact/(1+zLyaC)/9.20**2,
              color='red', fmt='s', markersize=6, elinewidth=1.5)
#https://arxiv.org/abs/1904.03430
plt.errorbar(zLyaA,  fact/8.86/(1+zLyaA),        yerr=0.29*fact/(1+zLyaA)/8.86**2,
              color='red', fmt='s', markersize=6, elinewidth=1.5)

plt.errorbar(zCombBAO1,  81.21/(1+zCombBAO1),       yerr=ersys(2.17, 0.97)/(1+zCombBAO1),
              color='red', fmt='d', markersize=6, elinewidth=1.5)
plt.errorbar(zCombBAO2,  90.90/(1+zCombBAO2),       yerr=ersys(2.07, 1.08)/(1+zCombBAO1),
              color='red', fmt='d', markersize=6, elinewidth=1.5)
plt.errorbar(zCombBAO3,  98.96/(1+zCombBAO3),       yerr=ersys(2.21, 1.18)/(1+zCombBAO1),
              color='red', fmt='d', markersize=6, elinewidth=1.5)
plt.errorbar(0.01,  69.8,       yerr=0.8,
              color='red', fmt='d', markersize=6, elinewidth=1.5)

# plt.plot(z, [100*0.682*(0.30*(1+zi)**3 + (1-0.30))**0.5/(1+zi) for zi in z], 'red', lw=1.5)
#plt.ylim(55, 80)
plt.ylim(50, 85)
plt.plot(z, lcdmzh)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Separating the values of $\beta < 0$

# %%
# 0 weights, 1 Om, 2 Ombh2, 3 h, 4 'mquin', 5 'mphan', 6 'beta'
chain_data_all = np.loadtxt(dir_name + '/350/Quintom_couple_phy_SN+HD+CBAO_nested_multi_1.txt', usecols=[0,2,3,4,5,6,7])
weights_chain_all = chain_data_all[:, 0]
samples_chain_all = chain_data_all[:, 1:]

# %%
chain_data_betaneg_all = chain_data_all[[chain_data_all[:,-1]<0]]
samples_betaneg_all = chain_data_betaneg_all[:, 1:]
weights_betaneg_all = chain_data_betaneg_all[:, 0]

chain_data_betapos_all = chain_data_all[[chain_data_all[:,-1]>0]]
samples_betapos_all = chain_data_betapos_all[:, 1:]
weights_betapos_all = chain_data_betapos_all[:, 0]

# %%
subsamples = [samples_betaneg_all, weights_betaneg_all, samples_betapos_all, weights_betapos_all]
for s in subsamples:
    print(np.shape(s))

# %%
k = np.arange(0, 3.1, 0.05)
cbar = plot_contours(eos, k, samples_betaneg_all, weights=weights_betaneg_all, 
                     colors=plt.cm.Greens_r, lines=False, contour_line_levels=[1,2], 
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2],  )
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])
plt.hlines(-1, xmin=0, xmax=3, colors='blue',  linestyles='dashed', label='$w=-1$', lw=4)

# plt.ylabel(r'$H(z)/(1+z)[km\;s^{-1}Mpc^{-1}]$')
plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')
plt.ylim(-2,0)
plt.xlim(0, 3)
plt.tight_layout()
plt.grid()

# plt.legend(loc='lower left')
# plt.text(0.01,-1.7, 'SN+HD+CBAO', fontsize=13)
plt.text(0.01,-1.7, ' BAO+HD+SN witn $\\beta < 0$', fontsize=13)
plt.savefig('img/eos_quintom_couple_sn+hd+cbao_negative.png', dpi=300)
plt.savefig('img/eos_quintom_couple_sn+hd+cbao_negative.svg')

# %%
k = np.arange(0, 3.1, 0.05)
cbar = plot_contours(eos, k, samples_betapos_all, weights=weights_betapos_all, 
                     colors=plt.cm.Greens_r, lines=False, contour_line_levels=[1,2], 
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2],  )
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])
plt.hlines(-1, xmin=0, xmax=3, colors='blue',  linestyles='dashed', label='$w=-1$', lw=4)

# plt.ylabel(r'$H(z)/(1+z)[km\;s^{-1}Mpc^{-1}]$')
plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')
plt.ylim(-2,0)
plt.xlim(0, 3)
plt.tight_layout()
plt.grid()

# plt.legend(loc='lower left')
# plt.text(0.01,-1.7, 'SN+HD+CBAO', fontsize=13)
plt.text(0.01,-1.7, ' BAO+HD+SN with $\\beta > 0$', fontsize=13)
plt.savefig('img/eos_quintom_couple_sn+hd+cbao_positive.png', dpi=300)
plt.savefig('img/eos_quintom_couple_sn+hd+cbao_positive.svg')

# %% [markdown]
# Solo BAO

# %%
# 0 weights, 1 Om, 2 Ombh2, 3 h, 4 'mquin', 5 'mphan', 6 'beta'
chain_data_bao = np.loadtxt(dir_name + '/350/Quintom_couple_phy_CBAO_nested_multi_1.txt', usecols=[0,2,3,4,5,6,7])
weights_chain_bao = chain_data_bao[:, 0]
samples_chain_bao = chain_data_bao[:, 1:]

# %%
chain_data_betaneg_bao = chain_data_bao[[chain_data_bao[:,-1]<0]]
samples_betaneg_bao = chain_data_betaneg_bao[:, 1:]
weights_betaneg_bao = chain_data_betaneg_bao[:, 0]

chain_data_betapos_bao = chain_data_bao[[chain_data_bao[:,-1]>0]]
samples_betapos_bao = chain_data_betapos_bao[:, 1:]
weights_betapos_bao = chain_data_betapos_bao[:, 0]

# %%
subsamples = [samples_betaneg_bao, weights_betaneg_bao, samples_betapos_bao, weights_betapos_bao]
for s in subsamples:
    print(np.shape(s))

# %%
k = np.arange(0, 3.1, 0.05)
cbar = plot_contours(eos, k, samples_betaneg_bao, weights=weights_betaneg_bao, 
                     colors=plt.cm.Greens_r, lines=False, contour_line_levels=[1,2], 
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2],  )
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])
plt.hlines(-1, xmin=0, xmax=3, colors='blue',  linestyles='dashed', label='$w=-1$', lw=4)

# plt.ylabel(r'$H(z)/(1+z)[km\;s^{-1}Mpc^{-1}]$')
plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')
plt.ylim(-2,0)
plt.xlim(0, 3)
plt.tight_layout()
plt.grid()

# plt.legend(loc='lower left')
# plt.text(0.01,-1.7, 'SN+HD+CBAO', fontsize=13)
plt.text(0.01,-1.7, 'BAO with $\\beta < 0$', fontsize=13)
plt.savefig('img/eos_quintom_couple_bao_negative.png', dpi=300)
plt.savefig('img/eos_quintom_couple_bao_negative.svg')

# %%
k = np.arange(0, 3.1, 0.05)
cbar = plot_contours(eos, k, samples_betapos_bao, weights=weights_betapos_bao, 
                     colors=plt.cm.Greens_r, lines=False, contour_line_levels=[1,2], 
                     linewidths=[2,1.5])

cbar = plt.colorbar(cbar,ticks=[0,1,2],  )
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$'])
plt.hlines(-1, xmin=0, xmax=3, colors='blue',  linestyles='dashed', label='$w=-1$', lw=4)

# plt.ylabel(r'$H(z)/(1+z)[km\;s^{-1}Mpc^{-1}]$')
plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')
plt.ylim(-2,0)
plt.xlim(0, 3)
plt.tight_layout()
plt.grid()

# plt.legend(loc='lower left')
# plt.text(0.01,-1.7, 'SN+HD+CBAO', fontsize=13)
plt.text(0.01,-1.7, ' BAO with $\\beta > 0$', fontsize=13)
plt.savefig('img/eos_quintom_couple_bao_positive.png', dpi=300)
plt.savefig('img/eos_quintom_couple_bao_positive.svg')

# %%
lcdm = []
for ii in range(100):
    lcdm += [(68*(0.3*((1+z[ii])*3)+(0.7))*0.5)/(1+z[ii])]
rd_fid_DR12 = 147.78
zLyaA = 2.37
zLyaC = 2.35
fact = (300000./rd_fid_DR12)
def ersys(x, y):
    return np.sqrt(x*2 + y*2)
#https://arxiv.org/abs/1904.03430
plt.errorbar(zLyaC,  fact/9.20/(1+zLyaC),        yerr=0.36*fact/(1+zLyaC)/9.20**2,
              color='red', fmt='s', markersize=6, elinewidth=1.5)
#https://arxiv.org/abs/1904.03430
plt.errorbar(zLyaA,  fact/8.86/(1+zLyaA),        yerr=0.29*fact/(1+zLyaA)/8.86**2,
              color='red', fmt='s', markersize=6, elinewidth=1.5)
plt.errorbar(0.01,  69.8,       yerr=0.8,
              color='red', fmt='d', markersize=6, elinewidth=1.5)
def cte(x):
    return (300000/(147.78*(1+x)))
z_new = [0.38,0.51,0.70,1.48]
datos = [25,22.33,19.33,13.26]
errores = [0.76, 0.58, 0.53, 0.55]
Hz_new = []
errores_new = []
for ii in range(len(z_new)):
    Hz_new+= [cte(z_new[ii])/datos[ii]]
    errores_new+= [Hz_new[ii]*errores[ii]/datos[ii]]
plt.errorbar(z_new,  Hz_new, yerr = errores_new,
              color='red', fmt='d', markersize=6, elinewidth=1.5)
