# %% [markdown]
# # Notebook useful for several papers, i.e. Quintom, Horndeski

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots
# import planckStyle
import pylab
import numpy as np

params1 = {'backend': 'pdf',
               'axes.labelsize': 10,
               'xtick.labelsize': 10,
               'ytick.labelsize': 10,
               'legend.fontsize': 16,
               'lines.markersize': 6,
               'font.size': 25,
               'text.usetex': True}#
pylab.rcParams.update(params1)

# %%
# dir_name = '/Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/'
dir_name = '/home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/'
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom

# %% [markdown]
# ## Quintess

# %%
#roots = ['Quintom_all_phy_BBAO+Planck_15', 'Quintom_all_phy_BBAO+Planck_15+HD']
#roots = ['Quintom_coupling_phy_BBAO','Quintom_coupling_phy_BBAO+HD', 'Quintom_coupling_phy_BBAO+Planck_15', 'Quintom_coupling_phy_BBAO+Planck_15+HD'] #, 'Quintom_phy_BBAO+Planck_15',  'Quintom_phy_BBAO+Planck_15+HD'] 
#roots = ['Quintom_phy_BBAO', 'Quintom_phy_BBAO+HD', 'Quintom_phy_BBAO+Planck_15',  'Quintom_phy_BBAO+Planck_15+HD'] 
#roots = ['Phantom_phy_BBAO', 'Phantom_phy_BBAO+HD',  'Phantom_phy_BBAO+Planck_15+HD'] 
#roots = ['Quintess_phy_BBAO', 'Quintess_phy_BBAO+HD',  'Quintess_phy_BBAO+Planck_15+HD'] 
roots = [
#           'Quintom_couple_phy_HD_nested_multi',
#           'Quintom_couple_phy_SN_nested_multi',
            'Quintom_couple_phy_CBAO_nested_multi',
#           'Quintom_couple_phy_SN+HD_nested_multi',
          'Quintom_couple_phy_HD+CBAO_nested_multi',
#             'Quintom_couple_phy_SN+CBAO_nested_multi',
            'Quintom_couple_phy_SN+HD+CBAO_nested_multi',
            ]

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
#g.plots_2d(roots, param_pairs=[['mquin','h']], nx=1, filled=True, legend_labels=False, lims=[0.0, 2., None, None])
#            line_args={'lw':2,  'ls':'-'},  
#           colors = ['blue','red','green'], alphas=[.9,0.7,0.5])
#g.add_legend(['BAO+HD', 'BBAO+PLK+HD', 'BAO','BAO+PLK'], 
#             colored_text=True,  legend_loc='lower left')  
#g.export('Quintess_2d.pdf')
#g.plot_1d(roots, param='mquin')
g.triangle_plot(roots, ['Om','h', 'mquin'],  
                analysis_settings={'smooth_scale_1D': .1, 'ignore_rows': 0.}, # plot_3d_with_param='beta',
                  width_inch=10, line_args={'lw':2,  'ls':'-'}, 
               legend_labels=['BAO', 'SN+BAO', 'HD+SN+BAO'])
#g.add_legend(['BAO+HD', 'BBAO+PLK+HD', 'BAO','BAO+PLK'], legend_loc='upper left')
#g.export('Quintom_coupling.pdf')
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintom_couple_phy_CBAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintom_couple_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed 0.1 as burn in

# %%
roots = ['Phantom_phy_CBAO_nested_multi', 'Phantom_phy_HD+CBAO_nested_multi',  'Phantom_phy_SN+HD+CBAO_nested_multi']  
#  'Quintom_couple_phy_CBAO_nested_multi'

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+HD+SN'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')

g.subplots[1,0].grid(True)

g.subplots[1,0].set_ylim(-0.5, 1.5)
# 
g.subplots[1,1].set_xlim(-0.05, 1.8)

g.subplots[0,0].set_title('Phantom', fontsize=20)
g.export('Phantom2.pdf')
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Phantom_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed 0.1 as burn in

# %%
roots = ['Quintess_phy_CBAO_nested_multi', 'Quintess_phy_HD+CBAO_nested_multi',  'Quintess_phy_SN+HD+CBAO_nested_multi'] 
#  'Quintom_couple_phy_CBAO_nested_multi'

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+HD+SN'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
    
g.subplots[1,0].grid(True)
g.subplots[1,0].set_ylim(0, 1.8)

# g.subplots[1,1].set_xlim(0.2, 0.75)

g.subplots[0,0].set_title('Quintessence', fontsize=20)
g.export('Quintess2.pdf')
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintess_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed 0.1 as burn in

# %%
roots = ['Quintom_phy_CBAO_nested_multi', 'Quintom_phy_HD+CBAO_nested_multi',  'Quintom_phy_SN+HD+CBAO_nested_multi']

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=8, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+HD+SN'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')

# g.subplots[0,0].set_ylim(0, 1.2)
g.subplots[2,1].set_ylim(0, 2)
g.subplots[1,0].set_ylim(0, 3.5)
# g.subplots[1,1].set_xlim(0, 2.6)
# g.subplots[2,1].set_xlim(0, 2.6)
# g.subplots[2,1].set_ylim(0, 2.)
# g.subplots[2,2].set_xlim(0, 2.)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)

g.subplots[0,0].set_title('Quintom', fontsize=20)
g.export('Quintom2.pdf')
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintom_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed 0.1 as burn in

# %%
roots = ['Quintom_couple_phy_CBAO_nested_multi','Quintom_couple_phy_HD+CBAO_nested_multi', 'Quintom_couple_phy_SN+HD+CBAO_nested_multi'] 


g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=9, 
                            analysis_settings={'smooth_scale_2D': 0.9, 'smooth_scale_1D': 0.9, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan', 'beta'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+HD+SN'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
# g.subplots[1,0].set_ylim(0, 2.6)
# g.subplots[1,1].set_xlim(0, 2.8)
# g.subplots[2,0].set_ylim(0, 2.)
# g.subplots[2,1].set_xlim(0, 2.8)
# g.subplots[2,1].set_ylim(0, 2.)
# g.subplots[2,2].set_xlim(0, 2.)
# g.subplots[3,0].set_ylim(0, 10.)
# g.subplots[3,1].set_xlim(0, 2.8)
# g.subplots[3,1].set_ylim(0, 10)
# g.subplots[3,2].set_xlim(0, 2.)
# g.subplots[3,2].set_ylim(0, 10.)
# g.subplots[3,3].set_xlim(0, 10.)
g.subplots[2,1].set_ylim(0, 2)
g.subplots[1,0].set_ylim(0, 3.5)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)
g.subplots[3,0].grid(True)
g.subplots[3,1].grid(True)
g.subplots[3,2].grid(True)

g.subplots[0,0].set_title('Quintom + $\\beta$', fontsize=20)
g.export('Quintom_coupling2.pdf')

# %%
# roots = ['Quintom_cos_beta_delta_phy_BBAO+Planck_15+HD+SN'] 


# g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=9, 
#                             analysis_settings={'smooth_scale_2D': 0.9, 'smooth_scale_1D': 0.9, 'ignore_rows': 0.1})
# g.settings.axes_fontsize = 15
# g.settings.lab_fontsize = 20
# g.settings.colorbar_axes_fontsize=20
# g.settings.colorbar_label_rotation= 0
# g.settings.alpha_filled_add =0.9
# g.settings.scatter_size = 9
# g.settings.lw_contour=3
# g.settings.colormap_scatter= 'hsv'
# g.triangle_plot(roots, 
#                 ['h','mquin', 'mphan', 'beta', 'delta'], 
#                 contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
#                               {'lw':2, 'color':'red', 'ls':'-'}, 
#                               {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
#                 alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+HD+PLK'], 
#                 line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
#                 {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
#                 #,plot_3d_with_param='alpha')

# %%
# samples = g.sampleAnalyser.samplesForRoot('LCDM_phy_Planck_15+BBAO+SN+HD')
# for i,j,k in zip(samples.paramNames.list(), samples.means, samples.sddev):
#     print i,'\t \t',j,k

# %%
# g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
#                             analysis_settings={'smooth_scale_2D': -1., 'ignore_rows': 0.1})

# roots0 = ['LCDM_phy_BBAO', 'LCDM_phy_BBAO+HD',  'LCDM_phy_BBAO+Planck_15+HD']
# roots1 = ['Quintess_phy_BBAO', 'Quintess_phy_BBAO+HD',  'Quintess_phy_BBAO+Planck_15+HD'] 
# roots2 = ['Phantom_phy_BBAO', 'Phantom_phy_BBAO+HD',  'Phantom_phy_BBAO+Planck_15+HD']  
# roots3 = ['Quintom_phy_BBAO', 'Quintom_phy_BBAO+HD',  'Quintom_phy_BBAO+Planck_15+HD']
# roots4 = ['Quintom_coupling_phy_BBAO','Quintom_coupling_phy_BBAO+HD', 'Quintom_coupling_phy_BBAO+Planck_15+HD'] 


# for a in roots0:
#     f= open(a+".txt","w+") 
#     samples = g.sampleAnalyser.samplesForRoot(a)
#     for i,j,k in zip(samples.paramNames.list(), samples.means, samples.sddev):
#         if ('like' not in i) and ('prior' not in i) and ('Obh2' not in i): f.write(('%s,%f,%f \n')%(i.strip(),j,k))
#     f.close()
    
#     h= open(a+".stats","w+")
#     h.write('{}'.format(samples.likeStats))
#     print '{}'.format(samples.likeStats)
#     h.close()

#p = samples.getParams()
#print 'mean, err = ', samples.mean(p.Om), samples.std(p.Om)
#print '95% limits: ',samples.twoTailLimits(p.Om, 0.95)

# %%
# '{}'.format(samples.likeStats)

# %%
# for i,j,k in zip(samples.paramNames.list(), samples.means, samples.sddev):
#     print i,'\t \t',j,k

# %% [markdown]
# ## Quintess

# %%
roots = ['Quintess_phy_CBAO_nested_multi', 'Quintess_phy_SN+HD+CBAO_nested_multi']

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_1D': -1., 'ignore_rows': 0.2})
g.plots_1d(roots, params=['mquin'], nx=2,legend_labels=['CBAO', 'SN+HD+CBAO'], colors = ['blue','red','green'], xlims=[[0.0,1.5]])
g.add_legend(['$w_i$'], legend_loc='upper right')

# BAO si se ve el pico
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintess_phy_CBAO_nested_multi_1.txt
# Removed 0.2 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintess_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed 0.2 as burn in

# %%
samples = g.sampleAnalyser.samplesForRoot('Quintess_phy_SN+HD+CBAO_nested_multi')

p = samples.getParams()
print('mean, err = ', samples.mean(p.mquin), samples.std(p.mquin))
print('95% limits: ',samples.twoTailLimits(p.mquin, 0.95))
print(samples.likeStats)
# Out:
# WARNING:root:sampleAnalyser is deprecated, use sample_analyser
# WARNING:root:samplesForRoot is deprecated, use samples_for_root
# mean, err =  0.394666625857975 0.2253654976572171
# 95% limits:  [0.01944358 0.81907946]
# Best fit sample -log(Like) = 29.252380
# Ln(mean 1/like) = 33.933373
# mean(-Ln(like)) = 31.280004
# -Ln(mean like)  = 30.636334
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  3.0423067E-01  3.3731956E-01 2.8803150E-316  3.4811142E-01  0.0000000E+00   \Omega_m
# Obh2                2.2064300E-02  2.3000950E-02  5.0000000E-01  2.3311830E-02  1.0000000E+00   \Omega_{b}h^2
# h                   6.8044477E-01  6.9960389E-01 2.3016985E-316  7.0434611E-01  0.0000000E+00   h
# mquin               4.4773840E-01  8.5697724E-01  0.0000000E+00  9.3919672E-01  0.0000000E+00   m_{\phi}
# BetouleSN_like     -1.6743876E+01 -1.6440493E+01  0.0000000E+00 -1.6394074E+01  0.0000000E+00   BetouleSN
# ...

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_2D': -1., 'ignore_rows': 0.2})
g.plots_2d(roots, param_pairs=[['mquin','Om'], ['mquin','h']], nx=2, filled=True, 
           lims=[0.0, 1.5, None, None],
            line_args={'lw':2,  'ls':'-'},  
           colors = ['blue','red','green'], alphas=[.9,0.7,0.5], legend_labels=['CBAO', 'SN+HD+CBAO'])
g.add_legend(['Planck+BBAO','Planck+SN'], 
             colored_text=True,  legend_loc='lower left')  
g.export('Quintess_2d.pdf')

# %%
# g.triangle_plot(['Quintess_phy_Planck_15+BBAO'], ['Om','h', 'mquin'],  
#                 analysis_settings={'smooth_scale_1D': .1, 'ignore_rows': 0.},
#                 plot_3d_with_param='h',  width_inch=10, 
#                legend_labels=['Simulation'])
# g.add_legend(['Planck+BBAO'],  legend_loc='best') 
# g.export('Quintess_3d.pdf')

# %% [markdown]
# ## Phantom

# %%
roots = ['Phantom_phy_CBAO_nested_multi', 'Phantom_phy_SN+HD+CBAO_nested_multi']

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_1D': -1., 'ignore_rows': 0.2})
g.plots_1d(roots, params=['mphan'], nx=2,legend_labels=['CBAO', 'SN+HD+CBAO'], 
                            colors = ['blue', 'red','green'], xlims=[[0.0,1.5]])
g.add_legend(['$w_i$'], legend_loc='upper right')

# El pico tal vez con HD
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Phantom_phy_CBAO_nested_multi_1.txt
# Removed 0.2 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Phantom_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed 0.2 as burn in

# %%
samples = g.sampleAnalyser.samplesForRoot('Phantom_phy_Planck_15+BBAO')

p = samples.getParams()
# print"mean, err = ', samples.mean(p.mphan), samples.std(p.mphan)
# print '95% limits: ',samples.twoTailLimits(p.mphan, 0.95)
# print samples.likeStats
# Out:
# WARNING:root:sampleAnalyser is deprecated, use sample_analyser
# WARNING:root:samplesForRoot is deprecated, use samples_for_root
# ---------------------------------------------------------------------------
# GetDistPlotError                          Traceback (most recent call last)
# <ipython-input-26-0c1cac2ea1cf> in <module>
# ----> 1 samples = g.sampleAnalyser.samplesForRoot('Phantom_phy_Planck_15+BBAO')
#       2
#       3 p = samples.getParams()
#       4 # print"mean, err = ', samples.mean(p.mphan), samples.std(p.mphan)
#       5 # print '95% limits: ',samples.twoTailLimits(p.mphan, 0.95)
#
# ~/.local/lib/python3.8/site-packages/getdist/plots.py in samples_for_root(self, root, file_root, cache, settings)
#     520
#     521         if not file_root:
# --> 522             raise GetDistPlotError('chain not found: ' + root)
#     523         if not self.chain_settings_have_priority:
#     524             dist_settings.update(self.ini.params)
#
# ...

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_2D': -1., 'ignore_rows': 0.2})
g.plots_2d(roots, param_pairs=[['mphan','Om'], ['mphan','h']], nx=2, filled=True, 
           lims=[0.0, 1.1, None, None],
           legend_labels=False, line_args={'lw':2,  'ls':'-'},  
           colors = ['blue','red','green'], alphas=[0.8,0.8,0.8])
g.add_legend(['Planck+BBAO','Planck+SN'], 
             colored_text=True,  legend_loc='upper left')  
g.export('Phantom_2d.pdf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-cac00fd8fb17> in <module>
#       1 g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10,
#       2                             analysis_settings={'smooth_scale_2D': -1., 'ignore_rows': 0.2})
# ----> 3 g.plots_2d(roots, param_pairs=[['mphan','Om'], ['mphan','h']], nx=2, filled=True,
#       4            lims=[0.0, 1.1, None, None],
#       5            legend_labels=False, line_args={'lw':2,  'ls':'-'},
#
# ~/.local/lib/python3.8/site-packages/getdist/plots.py in plots_2d(self, roots, param1, params2, param_pairs, nx, legend_labels, legend_ncol, label_order, filled, shaded, **kwargs)
#    2177                          add_legend_proxy=i == 0, ax=ax, _no_finish=True, **kwargs)
#    2178
# -> 2179         self.finish_plot(self._default_legend_labels(legend_labels, roots), legend_ncol=legend_ncol,
# ...

# %%
g.triangle_plot([dir_name+'Phantom_phy_SN+HD+CBAO_nested_multi'], ['Om','h', 'mphan'], 
                plot_3d_with_param='h', 
                legend_labels=['Simulation'])
g.add_legend(['HD+SN+CBAO'],  legend_loc='best') 
# g.export('Phantom_3d.pdf')

# %% [markdown]
# ## Quintom

# %%
roots = ['Quintom_phy_CBAO_nested_multi', 'Quintom_phy_SN+HD+CBAO_nested_multi']

# %%
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_1D ': -1., 'ignore_rows': 0.2})
g.plots_1d(roots, params=['mquin', 'mphan'], nx=2,legend_labels=['CBAO', 'HD+SN+CBAO'], colors = ['blue','red','green','orange'],
           xlims=[[0.0,3], [0.0,3]])
g.add_legend(['$w_i$'], legend_loc='upper right')

#el pico se con BAO phi, psi
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintom_phy_CBAO_nested_multi_1.txt
# Removed 0.2 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintom_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed 0.2 as burn in

# %%
samples = g.sampleAnalyser.samplesForRoot(dir_name+'Quintom_phy_SN+HD+CBAO_nested_multi')

p = samples.getParams()
print('mean, err = ', samples.mean(p.Om), samples.std(p.Om))
print('95% limits: ',samples.twoTailLimits(p.Om, 0.95))
print(samples.likeStats)
# Out:
# WARNING:root:sampleAnalyser is deprecated, use sample_analyser
# WARNING:root:samplesForRoot is deprecated, use samples_for_root
# mean, err =  0.3024980637091239 0.014383502927867078
# 95% limits:  [0.2726814  0.32986799]
# Best fit sample -log(Like) = 28.579044
# Ln(mean 1/like) = 34.103290
# mean(-Ln(like)) = 30.926333
# -Ln(mean like)  = 30.321886
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  2.9668589E-01  3.3380078E-01 4.4300282E-316  3.4094784E-01  0.0000000E+00   \Omega_m
# Obh2                2.1988790E-02  2.2980490E-02  0.0000000E+00  2.3429590E-02  0.0000000E+00   \Omega_{b}h^2
# h                   6.5771206E-01  7.0721745E-01  0.0000000E+00  7.2244933E-01  0.0000000E+00   h
# mquin               1.7922308E+00  2.2525973E+00  0.0000000E+00  2.4040319E+00  0.0000000E+00   m_{\phi}
# mphan               1.1687238E+00  1.3625047E+00  0.0000000E+00  1.4047920E+00  0.0000000E+00   m_{\psi}
# ...

# %%
g.triangle_plot([dir_name+'Quintom_phy_SN+HD+CBAO_nested_multi'], ['Om','h','mquin', 'mphan'], 
               # plot_3d_with_param='h', 
                filled=True,
                legend_labels=['Simulation'],
                analysis_settings={'smooth_scale_2D ': -1., 'ignore_rows': 0.2})
g.add_legend(['SN+HD+CBAO'], 
             colored_text=True,  legend_loc='upper left')  
g.export('Quintom_3d.pdf')

# %%
g.triangle_plot([dir_name+'Quintom_phy_SN+HD+CBAO_nested_multi'], ['Om','h', 'mquin','mphan'], 
                plot_3d_with_param='h', 
                legend_labels=['Simulation'])
g.add_legend(['HD+SN+CBAO'],  legend_loc='upper right') 
#g.export('Quintom_3d.pdf')

# %%
# dir_name = '/Users/josevazquezgonzalez/Desktop/GM_Sampler/trunk/chains'

# %%
# #L=-23.510, 3chains-2300,  ---- L=-23.510, 7G, N500, varcov 
# roots = ['LCDM_phy_BBAO+SN+Planck', 'gms_LCDM_phy_BBAO+SN+Planck']
# g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=12, 
#                             analysis_settings={'smooth_scale_1D ': 0.99,  'smooth_scale_2D ': -1,'ignore_rows': 0.0})
# #g.triangle_plot(roots, params=['Om', 'h', 'Obh2'])
# g.plots_1d(roots, params=['Om', 'h', 'Obh2'], nx=3,legend_labels=False, colors = ['blue','red','green','orange'])

# %%
# #L=-23.353, 3chains-1300, -----L=-23.323, 12G, N500, varcov 
# roots = ['wCDM_phy_BBAO+SN+Planck',  'gms_wCDM_phy_BBAO+SN+Planck'] #'gms_fix_owaCDM_phy_BBAO+SN+Planck',
# g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=12, 
#                             analysis_settings={'smooth_scale_1D ': 0.99, 'smooth_scale_2D ': .99, 'ignore_rows': 0.})
# #g.triangle_plot(roots, params=['Om', 'h', 'Obh2', 'Ok', 'w', 'wa'])
# g.plots_1d(roots, params=['Om', 'h', 'Obh2', 'w'], nx=4, legend_labels=False, colors = ['blue','red','green','orange'])

# %%
#L=-23.433, 3chains 3400 ------ L-23.3884, 15G, N=200, iblow=500, varcov
# roots = ['waCDM_phy_BBAO+SN+Planck',  'gms_waCDM_phy_BBAO+SN+Planck'] #'gms_fix_owaCDM_phy_BBAO+SN+Planck',
# g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
#                             analysis_settings={'smooth_scale_1D ': 0.99, 'smooth_scale_2D ': .99, 'ignore_rows': 0.2})
# #g.triangle_plot(roots, params=['Om', 'h', 'Obh2', 'Ok', 'w', 'wa'])
# g.plots_1d(roots, params=['Om', 'h', 'Obh2', 'w', 'wa'], nx=3, legend_labels=False, colors = ['blue','red','green','orange'])

# %%
roots = ['LCDM_phy_SN_nested_multi', 
        'LCDM_phy_SN+CBAO_nested_multi', 
        'LCDM_phy_SN+HD+CBAO_nested_multi']
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=12, 
                            analysis_settings={'smooth_scale_1D ': 0.99,  'smooth_scale_2D ': -1,'ignore_rows': 0.0})
g.plots_1d(roots, params=['Om', 'h', 'Obh2'], nx=3,legend_labels=['SN', 'SN+CBAO', 'HD+SN+CBAO'], colors = ['blue','red','green','orange'])
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/LCDM_phy_SN_nested_multi_1.txt
# Removed no burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/LCDM_phy_SN+CBAO_nested_multi_1.txt
# Removed no burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/LCDM_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed no burn in
# (3, 1)

# %%
for root in roots:
    samples = g.sampleAnalyser.samplesForRoot(root)
    print samples.likeStats
# Out:
#   File "<ipython-input-39-9935669aafe0>", line 3
#     print samples.likeStats
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(samples.likeStats)?

# %%
roots = ['Quintess_phy_CBAO_nested_multi', 'Quintess_phy_SN+CBAO_nested_multi', 
         'Quintess_phy_SN+HD+CBAO_nested_multi']

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': -1, 'smooth_scale_1D': -1, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['SN', 'SN+CBAO', 'HD+SN+CBAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].grid(True)
g.subplots[1,0].set_ylim(0, 2.1)

g.subplots[1,1].set_xlim(0, 2.1)

g.subplots[0,0].set_title('Quintessence', fontsize=20)
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintess_phy_CBAO_nested_multi_1.txt
# Removed no burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintess_phy_SN+CBAO_nested_multi_1.txt
# Removed no burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintess_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed no burn in
# Text(0.5, 1.0, 'Quintessence')

# %%
#for root in roots:
#    samples = g.sampleAnalyser.samplesForRoot(root)
#    print samples.likeStats

# %%
roots = ['Phantom_phy_CBAO_nested_multi',
         'Phantom_phy_SN+CBAO_nested_multi', 
         'Phantom_phy_SN+HD+CBAO_nested_multi',  
         ]  

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': -1, 'smooth_scale_1D': -1, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['SN', 'SN+CBAO', 'HD+SN+CBAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].grid(True)
g.subplots[1,0].set_ylim(0, 2.8)

g.subplots[1,1].set_xlim(0, 2.8)

g.subplots[0,0].set_title('Phantom', fontsize=20)
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Phantom_phy_CBAO_nested_multi_1.txt
# Removed no burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Phantom_phy_SN+CBAO_nested_multi_1.txt
# Removed no burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Phantom_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed no burn in
# Text(0.5, 1.0, 'Phantom')

# %%
#for root in roots:
#    samples = g.sampleAnalyser.samplesForRoot(root)
#    print samples.likeStats

# %%
roots = ['Quintom_phy_CBAO_nested_multi',
         'Quintom_phy_SN+CBAO_nested_multi',
         'Quintom_phy_SN+HD+CBAO_nested_multi'
        ] #, 'Quintom_phy_BBAO+HD',  'Quintom_phy_BBAO+Planck_15+HD']

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=8, 
                            analysis_settings={'smooth_scale_2D': -1, 'smooth_scale_1D': -1, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['SN', 'HD', 'BAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')

g.subplots[1,0].set_ylim(0, 3.6)
g.subplots[2,0].set_ylim(0, 3.)
g.subplots[1,1].set_xlim(0, 3.6)
g.subplots[2,1].set_xlim(0, 3.6)
g.subplots[2,1].set_ylim(0, 3.)
g.subplots[2,2].set_xlim(0, 3.)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)

g.subplots[0,0].set_title('Quintom', fontsize=20)
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintom_phy_CBAO_nested_multi_1.txt
# Removed no burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintom_phy_SN+CBAO_nested_multi_1.txt
# Removed no burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintom_phy_SN+HD+CBAO_nested_multi_1.txt
# Removed no burn in
# Text(0.5, 1.0, 'Quintom')

# %%
#for root in roots:
#    samples = g.sampleAnalyser.samplesForRoot(root)
#    print samples.likeStats

# %%
roots = ['Quintom_couple_phy_CBAO_nested_multi',
         'Quintom_couple_phy_SN+CBAO_nested_multi',
         'Quintom_couple_phy_SN+HD+CBAO_nested_multi'
        ]

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=9, 
                            analysis_settings={'smooth_scale_2D': -1, 'smooth_scale_1D': -1, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan', 'beta'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'SN+BAO', 'HD+SN+BAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].set_ylim(0, 4.6)
g.subplots[1,1].set_xlim(0, 4.8)
g.subplots[2,0].set_ylim(0, 4.)
g.subplots[2,1].set_xlim(0, 4.8)
g.subplots[2,1].set_ylim(0, 4.)
g.subplots[2,2].set_xlim(0, 4.)
g.subplots[3,0].set_ylim(-15, 15.)
g.subplots[3,1].set_xlim(0, 4.8)
g.subplots[3,1].set_ylim(-15, 15)
g.subplots[3,2].set_xlim(0, 2.)
g.subplots[3,2].set_ylim(-15, 15.)
g.subplots[3,3].set_xlim(-15, 15.)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)
g.subplots[3,0].grid(True)
g.subplots[3,1].grid(True)
g.subplots[3,2].grid(True)

g.subplots[0,0].set_title('Quintom + $\\beta$', fontsize=20)
#g.export('Quintom_coupling.pdf')
# Out:
# Text(0.5, 1.0, 'Quintom + $\\beta$')

# %%
#for root in roots:
#    samples = g.sampleAnalyser.samplesForRoot(root)
#    print samples.likeStats

# %%
roots = ['Quintess_phy_CBAO_nested_multi',  'Phantom_phy_CBAO_nested_multi',
        'Quintom_phy_CBAO_nested_multi']
g = plots.getSubplotPlotter(chain_dir= dir_name, width_inch=10, 
                            analysis_settings={'smooth_scale_1D ': 1, 'smooth_scale_2D ': 1, 'ignore_rows': 0.1})
g.plots_1d(roots, params=['DR14LyaAuto_like', 'DR14LyaCross_like', 'BAODR12_like'], nx=3,legend_labels=['SN', 'SN+CBAO', 'HD+SN+CBAO'], colors = ['blue','red','green','orange'])
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintess_phy_CBAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Phantom_phy_CBAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom/Quintom_phy_CBAO_nested_multi_1.txt
# Removed 0.1 as burn in
# (3, 1)
