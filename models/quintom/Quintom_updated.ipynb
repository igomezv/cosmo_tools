# %% [markdown]
# # Quintom_updated

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots
# import planckStyle
import pylab
import numpy as np

params1 = {'backend': 'pdf',
               'axes.labelsize': 10,
               'xtick.labelsize': 10,
               'ytick.labelsize': 10,
               'legend.fontsize': 16,
               'lines.markersize': 6,
               'font.size': 25,
               'text.usetex': True}#
pylab.rcParams.update(params1)

# %%
# dir_name = '/Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/'
dir_name = '/home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/'
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom

# %% [markdown]
# ## Quintess

# %%
# CBAO-> DR16BAO+HD23
# SN+CBAO -> PantheonPlus+DR16BAO
# SN+HD -> PantheonPlus+HD23
# SN+HD23+CBAO -> HD23+PantheonPlus+DR16BAO

roots = [
            'Quintom_couple_phy_DR16BAO_nested_multi',
#           'Quintom_couple_phy_PantheonPlus+HD23_nested_multi',
          'Quintom_couple_phy_DR16BAO+HD23_nested_multi',
            'Quintom_couple_phy_PantheonPlus+DR16BAO_nested_multi',
            'Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi',
            ]

# %%
roots = ['Phantom_phy_DR16BAO_nested_multi', 'Phantom_phy_DR16BAO+HD23_nested_multi', 'Phantom_phy_PantheonPlus+DR16BAO_nested_multi', 'Phantom_phy_HD23+PantheonPlus+DR16BAO_nested_multi']  
#  'Quintom_couple_phy_DR16BAO_nested_multi'

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'},
                              {'lw':2, 'color':'gray', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.8, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+SN', 'BAO+HD+SN'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}, {'lw':2, 'color':'gray'}], contour_colors=['blue','red', 'green', 'gray'])
                #,plot_3d_with_param='alpha')

g.subplots[1,0].grid(True)

g.subplots[1,0].set_ylim(-0.5, 1.5)
# 
g.subplots[1,1].set_xlim(-0.05, 2)

g.subplots[0,0].set_title('Phantom', fontsize=20)
g.export('Phantom2_updated.pdf')

# %%
roots = ['Quintess_phy_DR16BAO_nested_multi', 'Quintess_phy_DR16BAO+HD23_nested_multi',  'Quintess_phy_PantheonPlus+DR16BAO_nested_multi', 'Quintess_phy_HD23+PantheonPlus+DR16BAO_nested_multi'] 
#  'Quintom_couple_phy_DR16BAO_nested_multi'

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin'], 
                 contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'},
                              {'lw':2, 'color':'gray', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.8, 0.9], legend_labels= ['BAO', 'BAO+HD23', 'BAO+PantheonPlus', 'BAO+HD23+PantheonPlus'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}, {'lw':2, 'color':'gray'}], contour_colors=['blue','red', 'green', 'gray'])
                #,plot_3d_with_param='alpha')
    
g.subplots[1,0].grid(True)
g.subplots[1,0].set_ylim(0, 1.5)

# g.subplots[1,1].set_xlim(0.2, 0.75)

g.subplots[0,0].set_title('Quintessence', fontsize=20)
g.export('Quintess2_updated.pdf')

# %%
roots = ['Quintom_phy_DR16BAO_nested_multi', 'Quintom_phy_DR16BAO+HD23_nested_multi',  'Quintom_phy_PantheonPlus+DR16BAO_nested_multi', 'Quintom_phy_HD23+PantheonPlus+DR16BAO_nested_multi']

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=8, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'},
                              {'lw':2, 'color':'gray', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.8, 0.9], legend_labels= ['BAO', 'BAO+HD23', 'BAO+PantheonPlus', 'BAO+HD23+PantheonPlus'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}, {'lw':2, 'color':'gray'}], contour_colors=['blue','red', 'green', 'gray'])
                #,plot_3d_with_param='alpha')

# g.subplots[0,0].set_ylim(0, 1.2)
g.subplots[2,1].set_ylim(0, 2.5)
g.subplots[1,0].set_ylim(0, 4)
# g.subplots[1,1].set_xlim(0, 2.6)
# g.subplots[2,1].set_xlim(0, 2.6)
# g.subplots[2,1].set_ylim(0, 2.)
# g.subplots[2,2].set_xlim(0, 2.)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)

g.subplots[0,0].set_title('Quintom', fontsize=20)
g.export('Quintom2_updated.pdf')

# %%
roots = ['Quintom_couple_phy_DR16BAO_nested_multi','Quintom_couple_phy_DR16BAO+HD23_nested_multi', 'Quintom_couple_phy_PantheonPlus+DR16BAO_nested_multi','Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi'] 


g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=9, 
                            analysis_settings={'smooth_scale_2D': 0.9, 'smooth_scale_1D': 0.9, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan', 'beta'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'},
                              {'lw':2, 'color':'gray', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.8, 0.9], legend_labels= ['BAO', 'BAO+HD23', 'BAO+PantheonPlus', 'BAO+HD23+PantheonPlus'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}, {'lw':2, 'color':'gray'}], contour_colors=['blue','red', 'green', 'gray'])
                #,plot_3d_with_param='alpha')
# g.subplots[1,0].set_ylim(0, 2.6)
# g.subplots[1,1].set_xlim(0, 2.8)
# g.subplots[2,0].set_ylim(0, 2.)
# g.subplots[2,1].set_xlim(0, 2.8)
# g.subplots[2,1].set_ylim(0, 2.)
# g.subplots[2,2].set_xlim(0, 2.)
# g.subplots[3,0].set_ylim(0, 10.)
# g.subplots[3,1].set_xlim(0, 2.8)
# g.subplots[3,1].set_ylim(0, 10)
# g.subplots[3,2].set_xlim(0, 2.)
# g.subplots[3,2].set_ylim(0, 10.)
# g.subplots[3,3].set_xlim(0, 10.)
g.subplots[2,1].set_ylim(0, 2.5)
g.subplots[1,0].set_ylim(0, 4)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)
g.subplots[3,0].grid(True)
g.subplots[3,1].grid(True)
g.subplots[3,2].grid(True)

g.subplots[0,0].set_title('Quintom + $\\beta$', fontsize=20)
g.export('Quintom_coupling2_updated.pdf')

# %% [markdown]
# ## Quintess

# %%
samples = g.sampleAnalyser.samplesForRoot('Quintess_phy_HD23+PantheonPlus+DR16BAO_nested_multi')

p = samples.getParams()
print('mean, err = ', samples.mean(p.mquin), samples.std(p.mquin))
print('95% limits: ',samples.twoTailLimits(p.mquin, 0.95))
print(samples.likeStats)
# Out:
# WARNING:root:sampleAnalyser is deprecated, use sample_analyser
# WARNING:root:samplesForRoot is deprecated, use samples_for_root
# mean, err =  0.47263996259539864 0.1941242663128151
# 95% limits:  [0.03532056 0.77851795]
# Best fit sample -log(Like) = 709.292548
# mean(-Ln(like)) = 711.249845
# -Ln(mean like)  = 710.692575
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  2.9741123E-01  3.2680748E-01 3.3048704E-316  3.4436973E-01  0.0000000E+00   \Omega_m
# Obh2                2.2017230E-02  2.2948810E-02 9.0018761E-320  2.3302210E-02  0.0000000E+00   \Omega_{b}h^2
# h                   6.7355400E-01  7.2098323E-01 6.9389153E-310  7.3894374E-01 6.9389153E-310   h
# mquin               5.7478541E-01  7.8926875E-01 6.9389153E-310  8.4408158E-01 6.9389153E-310   m_{\phi}
# Ol                  6.9957616E-01  7.3351535E-01 6.9389153E-310  7.3803959E-01 6.9389153E-310   \Omega_\Lambda*
# H0                  6.7143823E+01  7.2723703E+01 6.9389153E-310  7.3894374E+01 6.9389153E-310   H_0*
# Age                 1.3853482E+01  1.4943660E+01 6.9389153E-310  1.5089366E+01 6.9389153E-310   Age[Gyr]*
# Omrad               5.4850120E-05  6.2638466E-05 6.9389153E-310  6.3462443E-05 6.9389153E-310   \Omega_r
# Omh12               1.4646044E-01  1.6949838E-01 6.9389153E-310  1.7909435E-01 6.9389153E-310   Omh2(z1;z2)*
# Omh13               1.3680575E-01  1.6567460E-01 6.9389153E-310  1.7445274E-01 6.9389153E-310   Omh2(z1;z3)*
# Omh23               1.3597592E-01  1.6542665E-01 7.6723454E-320  1.7432630E-01  0.0000000E+00   Omh2(z2;z3)*
# Orc                 1.2235170E-01  1.3451119E-01 6.9389153E-310  1.3617561E-01 6.9389153E-310   \Omega_{rc}*
# HD23_like          -3.2205673E+00 -3.0840320E+00 6.9389153E-310 -3.0627072E+00 6.9389153E-310   HD23
# PantheonPlus_like  -7.0149462E+02 -7.0143741E+02 4.8670407E-320 -7.0143741E+02  0.0000000E+00   PantheonPlus
# DR16BAO_like       -4.5928367E+00 -4.5347824E+00 6.9389153E-310 -4.5347824E+00 6.9389153E-310   DR16BAO
# theory_prior       -3.1579158E-04 -7.0428727E-08 6.9389153E-310 -7.0428727E-08 6.9389153E-310   None

# %% [markdown]
# ## Quintom

# %%
samples = g.sampleAnalyser.samplesForRoot(dir_name+'Quintom_phy_HD23+PantheonPlus+DR16BAO_nested_multi')

p = samples.getParams()
print('mean, err = ', samples.mean(p.Om), samples.std(p.Om))
print('95% limits: ',samples.twoTailLimits(p.Om, 0.95))
print(samples.likeStats)
# Out:
# WARNING:root:sampleAnalyser is deprecated, use sample_analyser
# WARNING:root:samplesForRoot is deprecated, use samples_for_root
# mean, err =  0.29780374274642507 0.016046528172440854
# 95% limits:  [0.26803611 0.33049749]
# Best fit sample -log(Like) = 709.046659
# mean(-Ln(like)) = 711.252714
# -Ln(mean like)  = 710.630733
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  2.8547912E-01  3.2853477E-01 3.0529919E-316  3.4523324E-01  0.0000000E+00   \Omega_m
# Obh2                2.2021710E-02  2.2964140E-02 7.4529803E-320  2.3319310E-02  0.0000000E+00   \Omega_{b}h^2
# h                   6.6820107E-01  7.2082388E-01 6.9389153E-310  7.4516931E-01 6.9389153E-310   h
# mquin               1.5150367E+00  2.0525651E+00 6.9389153E-310  2.1904326E+00 6.9389153E-310   m_{\phi}
# mphan               1.0287145E+00  1.2241826E+00 6.9389153E-310  1.3040535E+00 6.9389153E-310   m_{\psi}
# Ol                  7.1007629E-01  7.4537110E-01 6.9389153E-310  7.5162934E-01 6.9389153E-310   \Omega_\Lambda*
# H0                  6.7218397E+01  7.2082388E+01 6.9389153E-310  7.4516931E+01 6.9389153E-310   H_0*
# Age                 1.3997443E+01  1.5512337E+01 6.9389153E-310  1.5961071E+01 6.9389153E-310   Age[Gyr]*
# Omrad               5.4728483E-05  6.5304216E-05 6.9389153E-310  6.8350222E-05 6.9389153E-310   \Omega_r
# Omh12               1.4602489E-01  1.6907726E-01 6.9389153E-310  1.7835266E-01 6.9389153E-310   Omh2(z1;z2)*
# Omh13               1.3365110E-01  1.6511984E-01 6.9389153E-310  1.7914744E-01 6.9389153E-310   Omh2(z1;z3)*
# Omh23               1.3258755E-01  1.6502970E-01 6.9389153E-310  1.7941705E-01 6.9389153E-310   Omh2(z2;z3)*
# Orc                 1.2605208E-01  1.3889452E-01 6.9389153E-310  1.4123667E-01 6.9389153E-310   \Omega_{rc}*
# HD23_like          -3.2290366E+00 -3.0975529E+00 6.9389153E-310 -3.0643217E+00 6.9389153E-310   HD23
# PantheonPlus_like  -7.0138855E+02 -7.0131513E+02 6.9389153E-310 -7.0131513E+02 6.9389153E-310   PantheonPlus
# DR16BAO_like       -4.4437179E+00 -4.2073557E+00 6.9389153E-310 -4.2073557E+00 6.9389153E-310   DR16BAO
# theory_prior       -7.7145074E-03 -3.8781270E-08 6.9389153E-310 -3.8781270E-08 6.9389153E-310   None

# %%
roots = ['Quintess_phy_DR16BAO_nested_multi', 'Quintess_phy_DR16BAO+HD23_nested_multi',  'Quintess_phy_PantheonPlus+DR16BAO_nested_multi', 'Quintess_phy_HD23+PantheonPlus+DR16BAO_nested_multi'] 

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': 0.5, 'smooth_scale_1D': 0.5, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['SN', 'SN+BAO', 'HD+SN+BAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].grid(True)
g.subplots[1,0].set_ylim(0, 2.1)

g.subplots[1,1].set_xlim(0, 2.1)

g.subplots[0,0].set_title('Quintessence', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Quintessence')

# %%
roots = ['Phantom_phy_DR16BAO_nested_multi',
         'Phantom_phy_PantheonPlus+DR16BAO_nested_multi', 
         'Phantom_phy_HD23+PantheonPlus+DR16BAO_nested_multi',  
         ]  

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': 0.5, 'smooth_scale_1D': 0.5, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['SN', 'SN+BAO', 'HD23+SN+BAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].grid(True)
g.subplots[1,0].set_ylim(0, 2.8)

g.subplots[1,1].set_xlim(0, 2.8)

g.subplots[0,0].set_title('Phantom', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Phantom')

# %%
roots = ['Quintom_phy_DR16BAO_nested_multi',
         'Quintom_phy_PantheonPlus+DR16BAO_nested_multi',
         'Quintom_phy_HD23+PantheonPlus+DR16BAO_nested_multi'
        ] #, 'Quintom_phy_BBAO+HD23',  'Quintom_phy_BBAO+Planck_15+HD23']

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=8, 
                            analysis_settings={'smooth_scale_2D': 0.5, 'smooth_scale_1D': 0.5, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['SN', 'HD', 'BAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')

g.subplots[1,0].set_ylim(0, 3.6)
g.subplots[2,0].set_ylim(0, 3.)
g.subplots[1,1].set_xlim(0, 3.6)
g.subplots[2,1].set_xlim(0, 3.6)
g.subplots[2,1].set_ylim(0, 3.)
g.subplots[2,2].set_xlim(0, 3.)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)

g.subplots[0,0].set_title('Quintom', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Quintom')

# %%
roots = ['Quintom_couple_phy_DR16BAO_nested_multi',
         'Quintom_couple_phy_PantheonPlus+DR16BAO_nested_multi',
         'Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi'
        ]

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=9, 
                            analysis_settings={'smooth_scale_2D': 0.5, 'smooth_scale_1D': 0.5, 'ignore_rows': 0.0})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan', 'beta'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.9], legend_labels= ['BAO', 'SN+BAO', 'HD+SN+BAO'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}], contour_colors=['blue','red','green'])
                #,plot_3d_with_param='alpha')
g.subplots[1,0].set_ylim(0, 4.6)
g.subplots[1,1].set_xlim(0, 4.8)
g.subplots[2,0].set_ylim(0, 4.)
g.subplots[2,1].set_xlim(0, 4.8)
g.subplots[2,1].set_ylim(0, 4.)
g.subplots[2,2].set_xlim(0, 4.)
g.subplots[3,0].set_ylim(-15, 15.)
g.subplots[3,1].set_xlim(0, 4.8)
g.subplots[3,1].set_ylim(-15, 15)
g.subplots[3,2].set_xlim(0, 2.)
g.subplots[3,2].set_ylim(-15, 15.)
g.subplots[3,3].set_xlim(-15, 15.)

g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)
g.subplots[3,0].grid(True)
g.subplots[3,1].grid(True)
g.subplots[3,2].grid(True)

g.subplots[0,0].set_title('Quintom + $\\beta$', fontsize=20)
g.export('Quintom_coupling_updated.pdf')
