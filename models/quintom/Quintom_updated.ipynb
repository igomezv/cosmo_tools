# %% [markdown]
# # Quintom_updated

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots
# import planckStyle
import pylab
import numpy as np

params1 = {'backend': 'pdf',
               'axes.labelsize': 10,
               'xtick.labelsize': 10,
               'ytick.labelsize': 10,
               'legend.fontsize': 16,
               'lines.markersize': 6,
               'font.size': 25,
               'text.usetex': True}#
pylab.rcParams.update(params1)

# %%
# dir_name = '/Users/josevazquezgonzalez/Desktop/SimpleMC/SimpleMC/trunk/chains/'
dir_name = '/home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/'
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom

# %% [markdown]
# ## Quintess

# %%
# CBAO-> DR16BAO+HD23
# SN+CBAO -> PantheonPlus+DR16BAO
# SN+HD -> PantheonPlus+HD23
# SN+HD23+CBAO -> HD23+PantheonPlus+DR16BAO

roots = [
            'Quintom_couple_phy_DR16BAO_nested_multi',
#           'Quintom_couple_phy_PantheonPlus+HD23_nested_multi',
          'Quintom_couple_phy_DR16BAO+HD23_nested_multi',
            'Quintom_couple_phy_PantheonPlus+DR16BAO_nested_multi',
            'Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi',
            ]

# %%
roots = ['Phantom_phy_DR16BAO_nested_multi', 'Phantom_phy_DR16BAO+HD23_nested_multi', 'Phantom_phy_PantheonPlus+DR16BAO_nested_multi', 'Phantom_phy_HD23+PantheonPlus+DR16BAO_nested_multi']  
#  'Quintom_couple_phy_DR16BAO_nested_multi'

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'},
                              {'lw':2, 'color':'gray', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.8, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+SN', 'BAO+HD+SN'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}, {'lw':2, 'color':'gray'}], contour_colors=['blue','red', 'green', 'gray'])
                #,plot_3d_with_param='alpha')

g.subplots[1,0].grid(True)

g.subplots[1,1].set_xlim(0, 2.05)

g.subplots[0,0].set_title('Phantom', fontsize=20)
g.export('Phantom2_updated.pdf')
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Phantom_phy_DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Phantom_phy_DR16BAO+HD23_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Phantom_phy_PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Phantom_phy_HD23+PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in

# %%
roots = ['Quintess_phy_DR16BAO_nested_multi', 'Quintess_phy_DR16BAO+HD23_nested_multi',  'Quintess_phy_PantheonPlus+DR16BAO_nested_multi', 'Quintess_phy_HD23+PantheonPlus+DR16BAO_nested_multi'] 
#  'Quintom_couple_phy_DR16BAO_nested_multi'

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=7, 
                            analysis_settings={'smooth_scale_2D': 0.8, 'smooth_scale_1D': 0.8, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin'], 
                 contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'},
                              {'lw':2, 'color':'gray', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.8, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+SN', 'BAO+HD+SN'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}, {'lw':2, 'color':'gray'}], contour_colors=['blue','red', 'green', 'gray'])
                #,plot_3d_with_param='alpha')
    
g.subplots[1,0].grid(True)
g.subplots[1,0].set_ylim(0, 1.5)

# g.subplots[1,1].set_xlim(0.2, 0.75)

g.subplots[0,0].set_title('Quintessence', fontsize=20)
g.export('Quintess2_updated.pdf')
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintess_phy_DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintess_phy_DR16BAO+HD23_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintess_phy_PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintess_phy_HD23+PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in

# %%
roots = ['Quintom_phy_DR16BAO_nested_multi', 'Quintom_phy_DR16BAO+HD23_nested_multi',  'Quintom_phy_PantheonPlus+DR16BAO_nested_multi', 'Quintom_phy_HD23+PantheonPlus+DR16BAO_nested_multi']

g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=8, 
                            analysis_settings={'smooth_scale_2D': 0.7, 'smooth_scale_1D': 0.7, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'},
                              {'lw':2, 'color':'gray', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.8, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+SN', 'BAO+HD+SN'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}, {'lw':2, 'color':'gray'}], contour_colors=['blue','red', 'green', 'gray'])
                #,plot_3d_with_param='alpha')


g.subplots[1,0].set_ylim(0, 4.1)
g.subplots[2,0].set_ylim(0, 2.6)
g.subplots[2,0].set_xlim(0.52, 1)
# g.subplots[3,0].set_ylim(0, 10.)
    
g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)

g.subplots[0,0].set_title('Quintom', fontsize=20)
g.export('Quintom2_updated.pdf')
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_phy_DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_phy_DR16BAO+HD23_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_phy_PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_phy_HD23+PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in

# %%
roots = ['Quintom_couple_phy_DR16BAO_nested_multi','Quintom_couple_phy_DR16BAO+HD23_nested_multi', 'Quintom_couple_phy_PantheonPlus+DR16BAO_nested_multi','Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi'] 


g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=9, 
                            analysis_settings={'smooth_scale_2D': 0.7, 'smooth_scale_1D': 0.7, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan', 'beta'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'},
                              {'lw':2, 'color':'gray', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.8, 0.9], legend_labels= ['BAO', 'BAO+HD', 'BAO+SN', 'BAO+HD+SN'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}, {'lw':2, 'color':'gray'}], contour_colors=['blue','red', 'green', 'gray'])
                #,plot_3d_with_param='alpha')
    
g.subplots[1,0].set_ylim(0, 4.1)
g.subplots[2,0].set_ylim(0, 2.6)
g.subplots[3,0].set_xlim(0.52, 1)
# g.subplots[3,0].set_ylim(0, 10.)


g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)
g.subplots[3,0].grid(True)
g.subplots[3,1].grid(True)
g.subplots[3,2].grid(True)

g.subplots[0,0].set_title('Quintom + $\\beta$', fontsize=20)
g.export('Quintom_coupling2_updated.pdf')
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_DR16BAO+HD23_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintom_couple_phy_HD23+PantheonPlus+DR16BAO_nested_multi_1.txt
# Removed 0.1 as burn in

# %%
roots = ['Quintom_couple_phy_HD23+PantheonPlus+DR16BAO+Planck_15_nested_multi']



g= plots.getSubplotPlotter(chain_dir = dir_name,width_inch=9, 
                            analysis_settings={'smooth_scale_2D': 0.7, 'smooth_scale_1D': 0.7, 'ignore_rows': 0.1})
g.settings.axes_fontsize = 15
g.settings.lab_fontsize = 20
g.settings.colorbar_axes_fontsize=20
g.settings.colorbar_label_rotation= 0
g.settings.alpha_filled_add =0.9
g.settings.scatter_size = 9
g.settings.lw_contour=3
g.settings.colormap_scatter= 'hsv'
g.triangle_plot(roots, 
                ['h','mquin', 'mphan', 'beta'], 
                contour_args=[{'lw':3, 'color':'blue', 'ls':'-'}, 
                              {'lw':2, 'color':'red', 'ls':'-'}, 
                              {'lw':2, 'color':'green', 'ls':'-'},
                              {'lw':2, 'color':'gray', 'ls':'-'}], filled=True,
                alphas=[0.5, 0.7, 0.8, 0.9], legend_labels= ['BAO+HD+SN+Planck15'], 
                line_args=[{'lw':2, 'color':'blue'}, {'lw':2, 'color':'red', 'ls':'-'}, 
                {'lw':2, 'color':'green'}, {'lw':2, 'color':'gray'}], contour_colors=['blue','red', 'green', 'gray'])
                #,plot_3d_with_param='alpha')
    
g.subplots[1,0].set_ylim(0, 4.1)
g.subplots[2,0].set_ylim(0, 2.6)
g.subplots[3,0].set_xlim(0.52, 1)
# g.subplots[3,0].set_ylim(0, 10.)


g.subplots[1,0].grid(True)
g.subplots[2,0].grid(True)
g.subplots[2,1].grid(True)
g.subplots[3,0].grid(True)
g.subplots[3,1].grid(True)
g.subplots[3,2].grid(True)

g.subplots[0,0].set_title('Quintom + $\\beta$', fontsize=20)
g.export('Quintom_coupling2_plk15_updated.pdf')

# %% [markdown]
# ## Quintess

# %%
samples = g.sampleAnalyser.samplesForRoot('Quintess_phy_HD23+PantheonPlus+DR16BAO_nested_multi')

p = samples.getParams()
print('mean, err = ', samples.mean(p.mquin), samples.std(p.mquin))
print('95% limits: ',samples.twoTailLimits(p.mquin, 0.95))
print(samples.likeStats)
# Out:
# WARNING:root:sampleAnalyser is deprecated, use sample_analyser
# WARNING:root:samplesForRoot is deprecated, use samples_for_root
# mean, err =  0.47263996259539864 0.1941242663128151
# 95% limits:  [0.03532056 0.77851795]
# Best fit sample -log(Like) = 709.292548
# mean(-Ln(like)) = 711.249845
# -Ln(mean like)  = 710.692575
#
# parameter           bestfit        lower1         upper1         lower2         upper2
# Om                  2.9741123E-01  3.2680748E-01 5.3616727E-316  3.4436973E-01  0.0000000E+00   \Omega_m
# Obh2                2.2017230E-02  2.2948810E-02 1.3086811E-319  2.3302210E-02  0.0000000E+00   \Omega_{b}h^2
# h                   6.7355400E-01  7.2098323E-01 6.9389153E-310  7.3894374E-01 6.9389153E-310   h
# mquin               5.7478541E-01  7.8926875E-01 6.9389153E-310  8.4408158E-01 6.9389153E-310   m_{\phi}
# Ol                  6.9957616E-01  7.3351535E-01 6.9389153E-310  7.3803959E-01 6.9389153E-310   \Omega_\Lambda*
# H0                  6.7143823E+01  7.2723703E+01 9.1219340E-320  7.3894374E+01  0.0000000E+00   H_0*
# Age                 1.3853482E+01  1.4943660E+01 6.9389153E-310  1.5089366E+01 6.9389153E-310   Age[Gyr]*
# Omrad               5.4850120E-05  6.2638466E-05 6.9389153E-310  6.3462443E-05 6.9389153E-310   \Omega_r
# Omh12               1.4646044E-01  1.6949838E-01 1.1086833E-319  1.7909435E-01  0.0000000E+00   Omh2(z1;z2)*
# Omh13               1.3680575E-01  1.6567460E-01 6.9389153E-310  1.7445274E-01 6.9389153E-310   Omh2(z1;z3)*
# Omh23               1.3597592E-01  1.6542665E-01 6.9389153E-310  1.7432630E-01 6.9389153E-310   Omh2(z2;z3)*
# Orc                 1.2235170E-01  1.3451119E-01 6.9389153E-310  1.3617561E-01 6.9389153E-310   \Omega_{rc}*
# HD23_like          -3.2205673E+00 -3.0840320E+00 6.9389153E-310 -3.0627072E+00 6.9389153E-310   HD23
# PantheonPlus_like  -7.0149462E+02 -7.0143741E+02 9.8081912E-320 -7.0143741E+02  0.0000000E+00   PantheonPlus
# DR16BAO_like       -4.5928367E+00 -4.5347824E+00 6.9389153E-310 -4.5347824E+00 6.9389153E-310   DR16BAO
# theory_prior       -3.1579158E-04 -7.0428727E-08 6.9389153E-310 -7.0428727E-08 6.9389153E-310   None

# %% [markdown]
# ## Quintom

# %%
samples = g.sampleAnalyser.samplesForRoot(dir_name+'Quintess_phy_HD23_nested_multi')

p = samples.getParams()
print('mean, err = ', samples.mean(p.Om), samples.std(p.Om))
print('95% limits: ',samples.twoTailLimits(p.Om, 0.95))
print(samples.likeStats)
# Out:
# WARNING:root:sampleAnalyser is deprecated, use sample_analyser
# WARNING:root:samplesForRoot is deprecated, use samples_for_root
# /home/isidro/Documents/github/cosmo_tools/models/quintom/chains_quintom_updated/Quintess_phy_HD23_nested_multi_1.txt
# Removed 0.1 as burn in
# mean, err =  0.36165049125653154 0.1198313152208738
# 95% limits:  [0.14602953 0.63410222]
# Best fit sample -log(Like) = 3.055979
# Ln(mean 1/like) = 7.420076
# mean(-Ln(like)) = 4.896398
# -Ln(mean like)  = 4.330271
#
# parameter      bestfit        lower1         upper1         lower2         upper2
# Om             3.3571006E-01  5.7168280E-01  8.0000000E+00  7.2444024E-01  1.4000000E+01   \Omega_m
# Obh2           2.2014170E-02  2.2822150E-02 1.3401583E-316  2.3252120E-02  0.0000000E+00   \Omega_{b}h^2
# h              6.7036632E-01  7.6430989E-01 6.9119331E-310  8.2726299E-01 3.1532020E-316   h
# mquin          1.2806375E-01  1.8625942E+00 6.9119331E-310  2.0749068E+00 3.4393878E-316   m_{\phi}
# Ol             6.6840773E-01  8.1794024E-01 6.9119331E-310  9.4626286E-01 2.3244785E-316   \Omega_\Lambda*
# H0             6.7790580E+01  7.6430989E+01 6.9119331E-310  8.2726299E+01 4.2773872E-316   H_0*
# Age            1.3522449E+01  1.5842126E+01 6.9119331E-310  1.9449768E+01 3.4379957E-316   Age[Gyr]*
# Omrad          5.3808516E-05  8.9289875E-05 6.9119331E-310  1.1563893E-04 2.7613108E-316   \Omega_r
# Omh12          1.5305009E-01  2.5004617E-01 6.9119331E-310  2.8291538E-01 6.9119331E-310   Omh2(z1;z2)*
# Omh13          1.5251858E-01  2.0998385E-01 6.7558536E-320  2.3567778E-01  0.0000000E+00   Omh2(z1;z3)*
# Omh23          1.5247289E-01  2.0998309E-01 6.9119331E-310  2.3562884E-01 2.5311149E-316   Omh2(z2;z3)*
# Orc            1.1169222E-01  1.6725656E-01 6.9119331E-310  2.2385335E-01 6.9119331E-310   \Omega_{rc}*
# HD23_like     -3.0718863E+00 -3.0576837E+00 9.3650143E-320 -3.0576837E+00  0.0000000E+00   HD23
# theory_prior  -2.5178319E-03 -6.9147088E-07 6.9119331E-310 -6.9147088E-07 2.6579902E-316   None

# %%
3.055979*2
# Out:
# 6.111958
