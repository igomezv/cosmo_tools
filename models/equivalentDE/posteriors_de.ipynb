# %%
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
from getdist import *

# import planckStyle
import pylab
import numpy as np

import tkinter
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker
import matplotlib

import corner 
import fgivenx
from fgivenx import plot_contours, samples_from_getdist_chains
# matplotlib.use('TkAgg')
# %matplotlib inline

# %%
dir_name = '/home/isidro/Documents/github/cosmo_tools/models/equivalentDE/chains/'

roots1 = [
         'LCDM_phy_HD+CBAO+PantheonPlus_nested_multi',
  ]

roots2 = [
         'wCDM_phy_HD+CBAO+PantheonPlus_nested_multi',
  ]

roots3 = ['LHCDM_phy_HD+CBAO+PantheonPlus_nested_multi']
roots4 = ['IDE_phy_HD+CBAO+PantheonPlus_nested_multi']

roots_all = ['LCDM_phy_HD+CBAO+PantheonPlus_nested_multi', 'wCDM_phy_HD+CBAO+PantheonPlus_nested_multi',
             'LHCDM_phy_HD+CBAO+PantheonPlus_nested_multi', 'IDE_phy_HD+CBAO+PantheonPlus_nested_multi']


# 
# roots_bao = ['NLED_phy_CBAO_nested_multi', 'NLED_phy_HD+SN+CBAO_nested_multi']

# %%
# 3rd model

g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.7,
                                             'smooth_scale_1D': 0.7, 
                                             'ignore_rows': 0.01})

fig = plt.figure(figsize=(15, 15))
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
g.settings.lw1 = 3
g.settings.linewidth_contour = 2


g.triangle_plot(roots3, ['Om','h', 'alpha_1'],               
                diag1d_kwargs={'colors':['blue', 'red'], 
                               'alphas':[1, 1, 1]},
                colors=['blue', 'red'],
                alphas = [1, 1, 1],
                legend_labels=['Pantheon+BAO+HD'],
                legend_loc='upper right',
                filled = True,
                normalized=False, 
                shaded=False, 
                # param_limits={'h': [0.4, 0.9], 'Om':[0.1, 0.6]},                
                
           )

# g.add_text('Quintom with $\\beta$', x= 0.35, y= 2.5, fontsize=14)
#            \n 350 live points \n 0.2 burn', 0.1, 2)        
# plt.savefig('nled_250lp.png', dpi=300)
plt.savefig('img/LHCDM.png', dpi=300)
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/equivalentDE/chains/LHCDM_phy_HD+CBAO+PantheonPlus_nested_multi_1.txt
# Removed 0.01 as burn in

# %%
# 3rd model

g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.7,
                                             'smooth_scale_1D': 0.7, 
                                             'ignore_rows': 0.01})

fig = plt.figure(figsize=(15, 15))
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
g.settings.lw1 = 3
g.settings.linewidth_contour = 2


g.triangle_plot(roots4, ['Om','h', 'gamma_ide'],               
                diag1d_kwargs={'colors':['blue', 'red'], 
                               'alphas':[1, 1, 1]},
                colors=['blue', 'red'],
                alphas = [1, 1, 1],
                legend_labels=['Pantheon+BAO+HD'],
                legend_loc='upper right',
                filled = True,
                normalized=False, 
                shaded=False, 
                # param_limits={'h': [0.4, 0.9], 'Om':[0.1, 0.6]},                
                
           )

   
# plt.savefig('nled_250lp.png', dpi=300)
plt.savefig('img/IDE.png', dpi=300)
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/equivalentDE/chains/IDE_phy_HD+CBAO+PantheonPlus_nested_multi_1.txt
# Removed 0.01 as burn in

# %%
# 3rd model

g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.7,
                                             'smooth_scale_1D': 0.7, 
                                             'ignore_rows': 0.01})

fig = plt.figure(figsize=(15, 15))
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
g.settings.lw1 = 3
g.settings.linewidth_contour = 2


g.triangle_plot(roots1, ['Om','h'],               
                diag1d_kwargs={'colors':['blue', 'red'], 
                               'alphas':[1, 1, 1]},
                colors=['blue', 'red'],
                alphas = [1, 1, 1],
                legend_labels=['Pantheon+BAO+HD'],
                legend_loc='upper right',
                filled = True,
                normalized=False, 
                shaded=False, 
                # param_limits={'h': [0.4, 0.9], 'Om':[0.1, 0.6]},                
                
           )

   
# plt.savefig('nled_250lp.png', dpi=300)
plt.savefig('img/LCDM.png', dpi=300)
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/equivalentDE/chains/LCDM_phy_HD+CBAO+PantheonPlus_nested_multi_1.txt
# Removed 0.01 as burn in

# %%
# 3rd model

g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.7,
                                             'smooth_scale_1D': 0.7, 
                                             'ignore_rows': 0.01})

fig = plt.figure(figsize=(15, 15))
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
g.settings.lw1 = 3
g.settings.linewidth_contour = 2


g.triangle_plot(roots2, ['Om','h', 'w'],               
                diag1d_kwargs={'colors':['blue', 'red'], 
                               'alphas':[1, 1, 1]},
                colors=['blue', 'red'],
                alphas = [1, 1, 1],
                legend_labels=['Pantheon+BAO+HD'],
                legend_loc='upper right',
                filled = True,
                normalized=False, 
                shaded=False, 
                # param_limits={'h': [0.4, 0.9], 'Om':[0.1, 0.6]},                
                
           )

   
# plt.savefig('nled_250lp.png', dpi=300)
# plt.grid()
plt.savefig('img/wCDM.png', dpi=300)

# %%
plt.figure(figsize=(12, 10), dpi=200)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.8,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 15
gg.settings.axes_fontsize = 18 
gg.settings.linewidth_meanlikes = 5
gg.settings.linewidth_contour = 1


# plt.figure(figsize=(10,8))
gg.plot_2d(roots_all, 'h', 'Om', colors=['red','gray', 'green', 'blue'], 
          filled=True, alphas = [0.6, 0.9, 0.5, 0.5], 
          legend_loc='upper right')

# gg.add_text('Quintom with $\\beta$', 0.05, 0.06, fontsize=25)    

# gg.add_y_marker(0, color='green', lw=3.0)
# gg.add_x_marker(0.7324, color='purple', lw=3.0, ls='dotted')
# gg.add_x_marker(0.674, color='brown', lw=3.0, ls='dashdot')

# plt.text(0.32, 12, '·-·- $H_0 = 67.4$', fontsize=22, color='brown')
# plt.text(0.32, 10.5, '··· $H_0 = 73.24$', fontsize=22, color='purple')
# plt.text(0.32, 9, '--- $\\beta = 0$', fontsize=22, color='green')

gg.add_legend(['$\Lambda$CDM', 'wCDM', '$\Lambda$(H)CDM', 'IDE'])
# plt.xlim(0.3, 1.18)
# plt.ylim(-14, 14)
plt.grid()
plt.savefig('img/hvsOm.png')
# Out:
# /home/isidro/Documents/github/cosmo_tools/models/equivalentDE/chains/LCDM_phy_HD+CBAO+PantheonPlus_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/equivalentDE/chains/wCDM_phy_HD+CBAO+PantheonPlus_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/equivalentDE/chains/LHCDM_phy_HD+CBAO+PantheonPlus_nested_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/github/cosmo_tools/models/equivalentDE/chains/IDE_phy_HD+CBAO+PantheonPlus_nested_multi_1.txt
# Removed 0.1 as burn in

# %% [markdown]
# ## LCDM

# %%
samples = g.sampleAnalyser.samplesForRoot(roots1[0])

p = samples.getParams()
print("LCDM")
print('mean, err = ', samples.mean(p.Om), samples.std(p.Om))
print('95% limits: ',samples.twoTailLimits(p.Om, 0.95))
# print(samples.likeStats)

print('mean, err = ', samples.mean(p.h), samples.std(p.h))
print('95% limits: ',samples.twoTailLimits(p.h, 0.95))
# Out:
# WARNING:root:sampleAnalyser is deprecated, use sample_analyser
# WARNING:root:samplesForRoot is deprecated, use samples_for_root
# /home/isidro/Documents/github/cosmo_tools/models/equivalentDE/chains/LCDM_phy_HD+CBAO+PantheonPlus_nested_multi_1.txt
# Removed 0.01 as burn in
# LCDM
# mean, err =  0.31889052606565527 0.01217900294111005
# 95% limits:  [0.29583542 0.34241335]
# mean, err =  0.682601917551942 0.008097405777610681
# 95% limits:  [0.6646883  0.69783454]

# %% [markdown]
# ### wCDM

# %%
samples = g.sampleAnalyser.samplesForRoot(roots2[0])

p = samples.getParams()
print("wCDM")
print('mean, err = ', samples.mean(p.Om), samples.std(p.Om))
print('95% limits: ',samples.twoTailLimits(p.Om, 0.95))
# print(samples.likeStats)

print('mean, err = ', samples.mean(p.h), samples.std(p.h))
print('95% limits: ',samples.twoTailLimits(p.h, 0.95))

print('mean, err = ', samples.mean(p.w), samples.std(p.w))
print('95% limits: ',samples.twoTailLimits(p.w, 0.95))
# Out:
# WARNING:root:sampleAnalyser is deprecated, use sample_analyser
# WARNING:root:samplesForRoot is deprecated, use samples_for_root
# wCDM
# mean, err =  0.3045526904526285 0.015271604192414084
# 95% limits:  [0.27580189 0.3342536 ]
# mean, err =  0.6638421979731128 0.0155173741674798
# 95% limits:  [0.63099663 0.69374953]
# mean, err =  -0.9230375789356182 0.052181568436694345
# 95% limits:  [-1.03021025 -0.82172256]

# %% [markdown]
# ## $\Lambda$(H)CDM

# %%
samples = g.sampleAnalyser.samplesForRoot(roots3[0])

p = samples.getParams()
print("L(H)CDM")
print('mean, err = ', samples.mean(p.Om), samples.std(p.Om))
print('95% limits: ',samples.twoTailLimits(p.Om, 0.95))
# print(samples.likeStats)

print('mean, err = ', samples.mean(p.h), samples.std(p.h))
print('95% limits: ',samples.twoTailLimits(p.h, 0.95))

print('mean, err = ', samples.mean(p.alpha_1), samples.std(p.alpha_1))
print('95% limits: ',samples.twoTailLimits(p.alpha_1, 0.95))
# Out:
# WARNING:root:sampleAnalyser is deprecated, use sample_analyser
# WARNING:root:samplesForRoot is deprecated, use samples_for_root
# /home/isidro/Documents/github/cosmo_tools/models/equivalentDE/chains/LHCDM_phy_HD+CBAO+PantheonPlus_nested_multi_1.txt
# Removed 0.01 as burn in
# L(H)CDM
# mean, err =  0.34112287135922836 0.01815287298572159
# 95% limits:  [0.30593314 0.37658006]
# mean, err =  0.7055084875722973 0.015706829133145122
# 95% limits:  [0.67423481 0.73507611]
# mean, err =  0.048838902917469076 0.028810334767564404
# 95% limits:  [-0.00792604  0.10613221]

# %% [markdown]
# ## IDE

# %%
samples = g.sampleAnalyser.samplesForRoot(roots4[0])

p = samples.getParams()
print("IDE")
print('mean, err = ', samples.mean(p.Om), samples.std(p.Om))
print('95% limits: ',samples.twoTailLimits(p.Om, 0.95))
# print(samples.likeStats)

print('mean, err = ', samples.mean(p.h), samples.std(p.h))
print('95% limits: ',samples.twoTailLimits(p.h, 0.95))

print('mean, err = ', samples.mean(p.gamma_ide), samples.std(p.gamma_ide))
print('95% limits: ',samples.twoTailLimits(p.gamma_ide, 0.95))
# Out:
# WARNING:root:sampleAnalyser is deprecated, use sample_analyser
# WARNING:root:samplesForRoot is deprecated, use samples_for_root
# /home/isidro/Documents/github/cosmo_tools/models/equivalentDE/chains/IDE_phy_HD+CBAO+PantheonPlus_nested_multi_1.txt
# Removed 0.01 as burn in
# IDE
# mean, err =  0.3404827221536681 0.017680132475990575
# 95% limits:  [0.3058997  0.37546668]
# mean, err =  0.7048679417300145 0.015610295927006525
# 95% limits:  [0.67485029 0.73495389]
# mean, err =  0.04417035870827245 0.025858564105787143
# 95% limits:  [-0.00701236  0.09504866]
