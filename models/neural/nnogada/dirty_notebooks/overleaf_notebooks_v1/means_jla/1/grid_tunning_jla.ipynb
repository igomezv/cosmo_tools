# %%
# %load_ext tensorboard
# Clear any logs from previous runs
# !rm -rf ./logs/

# %%
import numpy as np
import pandas as pd
import time, os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import to_categorical
from tensorboard.plugins.hparams import api as hp

from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Model

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split as split

import random
from math import floor
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from scipy.integrate import odeint
import scipy
import pandas as pd
np.random.seed(0)
# Out:
# 2022-12-16 10:57:45.800517: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-16 10:57:46.299344: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-16 10:57:46.299359: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-16 10:57:47.566835: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-16 10:57:47.566916: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-16 10:57:47.566924: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
url = 'https://raw.githubusercontent.com/igomezv/nnogada/main/data/jla.csv'
df=pd.read_csv(url)
N = len(df.values)
randomize = np.random.permutation(N)
data = df.values[randomize]
N = len(df.values)
z = data[:,0] 
y = data[:,1:3] ### coge el resto de variables a predecir 
y[:,1] = y[:,1]**2+data[:,2]
np.shape(y)
# Out:
# (740, 2)

# %%
scalerz = StandardScaler()
scalerz.fit(z.reshape(-1,1))
z = scalerz.transform(z.reshape(-1,1))

# %%
### Modificar para incluir phanteon como test
split = 0.8
ntrain = int(split * len(z))
indx = [ntrain]
X_train, X_test = np.split(z, indx)
Y_train, Y_test = np.split(y, indx)
np.shape(X_train), np.shape(X_test), Y_train.shape, Y_test.shape
# Out:
# ((592, 1), (148, 1), (592, 2), (148, 2))

# %%
# loss -> val_loss
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min',
                                   min_delta=0.0,
                                   patience=200,
                                   restore_best_weights=True, verbose=True)
                                   ]

n_cols = 1

# %%
HP_BATCHSIZE = hp.HParam('batch_size', hp.Discrete([2, 4, 8, 16]))
HP_LAYERS =    hp.HParam('layers', hp.Discrete([1, 2, 3, 4]))
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([50, 100, 150, 200]))
HP_LEARNING  = hp.HParam('learning_rate', hp.Discrete([1e-4,1e-3]))
# HP_NUM_UNITS3 = hp.HParam('num_units3', hp.Discrete([50, 100, 150, 200]))
# HP_NUM_UNITS4 = hp.HParam('num_units4', hp.Discrete([2, 5, 10]))
# HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.0, 0.2))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'Adadelta']))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam']))

# %%
epochs=200

# %%
# sess = tf.Session()
# writer = tf.summary.FileWriter("/tmp/tfvgg", sess.graph)
# init = tf.initialize_all_variables()
# sess.run(init)
# with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
#     hp.hparams_config(
#         hparams=[HP_NUM_UNITS1, HP_NUM_UNITS2, HP_NUM_UNITS3, HP_NUM_UNITS4,
#                  HP_OPTIMIZER, HP_BATCHSIZE],
#         metrics=[hp.Metric('loss', display_name="Loss")])

# %%
# METRIC_ACCURACY = 'accuracy'
with tf.summary.create_file_writer('logs/hparam_tuning3').as_default():
# with tf.summary.FileWriter('logs/hparam_tuning', sess.graph):
#     init = tf.initialize_all_variables()
#     sess.run(init)
    hp.hparams_config(
        hparams=[HP_LAYERS,
                 HP_NUM_UNITS,
                 HP_LEARNING, 
                 HP_BATCHSIZE],
        metrics=[hp.Metric('loss', display_name="Loss")])
# Out:
# 2022-12-16 10:57:49.650973: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 10:57:49.651151: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-16 10:57:49.651217: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 10:57:49.651269: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 10:57:49.651320: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-12-16 10:57:49.651370: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-12-16 10:57:49.651420: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 10:57:49.651470: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 10:57:49.651519: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-12-16 10:57:49.651526: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-12-16 10:57:49.652296: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def train_test_model(hparams):    
    
    # Train LSTM model and predict on validation set
    model = tf.keras.Sequential()
    model.add(Dense(int(X_train.shape[1])))
#     model.add(Dense(hparams[HP_NUM_UNITS], input_shape=(int(X_train.shape[1]),)))
    
    for i in range(hparams[HP_LAYERS]):        
        model.add(Dense(hparams[HP_NUM_UNITS], activation='relu'))
    model.add(Dense(2, activation='linear'))
     
    optimizer = tf.keras.optimizers.Adam(learning_rate=hparams[HP_LEARNING], beta_1=0.9, beta_2=0.999, epsilon=1e-3)
    model.compile(
            optimizer=optimizer,
            loss='mse', 
            metrics=['mean_squared_error'])
    
    # Run with 1 epoch to speed things up for demo purposes

    model.fit(X_train, Y_train, epochs=epochs, validation_data=(X_test, Y_test),
              callbacks=callbacks, batch_size=hparams[HP_BATCHSIZE], shuffle=False, verbose=0)

    _, loss = model.evaluate(X_test, Y_test)
    
    return loss

# %%
def run(run_dir, hparams):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        loss = train_test_model(hparams)
        tf.summary.scalar("loss", loss, step=1)
        return loss

# %%
session_num = 0
datos = []

for deep_layers in HP_LAYERS.domain.values:
    for num_units in HP_NUM_UNITS.domain.values:
        for learning_rate in HP_LEARNING.domain.values:
            for batch_size in HP_BATCHSIZE.domain.values:
                t = time.time()
                hparams = {

                    HP_LAYERS: deep_layers,
                    HP_NUM_UNITS: num_units,
                    HP_LEARNING: learning_rate,
                    HP_BATCHSIZE: batch_size,
                }
                run_name = "run-%d" % session_num
                print('\n--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                score = run('logs/hparam_tuning3/' + run_name, hparams)
                t = time.time()-t
                session_num += 1
                print("Loss:", score, "Tiempo transcurrido:", t)
            
            datos.append([deep_layers, num_units, learning_rate, batch_size, score, t])

print(session_num)
# Out:
# --- Starting trial: run-0
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1621 - mean_squared_error: 0.1621
# Loss: 0.16207535564899445 Tiempo transcurrido: 85.58347129821777
#
# --- Starting trial: run-1
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0906 - mean_squared_error: 0.0906
# Loss: 0.09063239395618439 Tiempo transcurrido: 52.16171956062317
#
# --- Starting trial: run-2
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2101 - mean_squared_error: 0.2101
# Loss: 0.2100738286972046 Tiempo transcurrido: 29.75093722343445
#
# --- Starting trial: run-3
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6748 - mean_squared_error: 0.6748
# Loss: 0.6747888922691345 Tiempo transcurrido: 20.082947731018066
#
# --- Starting trial: run-4
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0295 - mean_squared_error: 0.0295
# Loss: 0.0295110996812582 Tiempo transcurrido: 94.26076149940491
#
# --- Starting trial: run-5
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0354 - mean_squared_error: 0.0354
# Loss: 0.035449814051389694 Tiempo transcurrido: 46.20261883735657
#
# --- Starting trial: run-6
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0360 - mean_squared_error: 0.0360
# Loss: 0.03603781387209892 Tiempo transcurrido: 32.81961750984192
#
# --- Starting trial: run-7
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0507 - mean_squared_error: 0.0507
# Loss: 0.050700534135103226 Tiempo transcurrido: 21.01045823097229
#
# --- Starting trial: run-8
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0651 - mean_squared_error: 0.0651
# Loss: 0.06506006419658661 Tiempo transcurrido: 99.91768479347229
#
# --- Starting trial: run-9
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0827 - mean_squared_error: 0.0827
# Loss: 0.08272241801023483 Tiempo transcurrido: 53.55602192878723
#
# --- Starting trial: run-10
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5004 - mean_squared_error: 0.5004
# Loss: 0.5004274249076843 Tiempo transcurrido: 32.3732545375824
#
# --- Starting trial: run-11
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4979 - mean_squared_error: 0.4979
# Loss: 0.49785128235816956 Tiempo transcurrido: 20.052420616149902
#
# --- Starting trial: run-12
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0317 - mean_squared_error: 0.0317
# Loss: 0.03174538537859917 Tiempo transcurrido: 143.02642130851746
#
# --- Starting trial: run-13
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0306 - mean_squared_error: 0.0306
# Loss: 0.030566846951842308 Tiempo transcurrido: 83.0237295627594
#
# --- Starting trial: run-14
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372
# Loss: 0.03719376027584076 Tiempo transcurrido: 29.879772424697876
#
# --- Starting trial: run-15
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0417 - mean_squared_error: 0.0417
# Loss: 0.04168462008237839 Tiempo transcurrido: 20.64176654815674
#
# --- Starting trial: run-16
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0466 - mean_squared_error: 0.0466
# Loss: 0.04661671072244644 Tiempo transcurrido: 96.38106918334961
#
# --- Starting trial: run-17
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0605 - mean_squared_error: 0.0605
# Loss: 0.060483817011117935 Tiempo transcurrido: 52.98663640022278
#
# --- Starting trial: run-18
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0904 - mean_squared_error: 0.0904
# Loss: 0.0903744101524353 Tiempo transcurrido: 32.413302183151245
#
# --- Starting trial: run-19
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2904 - mean_squared_error: 0.2904
# Loss: 0.29044848680496216 Tiempo transcurrido: 19.528263092041016
#
# --- Starting trial: run-20
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0333 - mean_squared_error: 0.0333
# Loss: 0.03330691531300545 Tiempo transcurrido: 97.36753964424133
#
# --- Starting trial: run-21
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0327 - mean_squared_error: 0.0327
# Loss: 0.03271554410457611 Tiempo transcurrido: 54.49463510513306
#
# --- Starting trial: run-22
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0382 - mean_squared_error: 0.0382
# Loss: 0.03822993114590645 Tiempo transcurrido: 28.66469430923462
#
# --- Starting trial: run-23
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0369 - mean_squared_error: 0.0369
# Loss: 0.0368724949657917 Tiempo transcurrido: 19.644713401794434
#
# --- Starting trial: run-24
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0555 - mean_squared_error: 0.0555
# Loss: 0.05552061274647713 Tiempo transcurrido: 99.25733065605164
#
# --- Starting trial: run-25
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0534 - mean_squared_error: 0.0534
# Loss: 0.05340448021888733 Tiempo transcurrido: 83.7329478263855
#
# --- Starting trial: run-26
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4403 - mean_squared_error: 0.4403
# Loss: 0.44027844071388245 Tiempo transcurrido: 42.108070850372314
#
# --- Starting trial: run-27
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1829 - mean_squared_error: 0.1829
# Loss: 0.1828925609588623 Tiempo transcurrido: 21.285539150238037
#
# --- Starting trial: run-28
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0330 - mean_squared_error: 0.0330
# Loss: 0.03297889232635498 Tiempo transcurrido: 110.94048857688904
#
# --- Starting trial: run-29
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0301 - mean_squared_error: 0.0301
# Loss: 0.030077893286943436 Tiempo transcurrido: 58.52268028259277
#
# --- Starting trial: run-30
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0386 - mean_squared_error: 0.0386
# Loss: 0.038620445877313614 Tiempo transcurrido: 32.661566495895386
#
# --- Starting trial: run-31
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0359 - mean_squared_error: 0.0359
# Loss: 0.03590170294046402 Tiempo transcurrido: 22.35865545272827
#
# --- Starting trial: run-32
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0361 - mean_squared_error: 0.0361
# Loss: 0.036050062626600266 Tiempo transcurrido: 105.55082678794861
#
# --- Starting trial: run-33
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0370 - mean_squared_error: 0.0370
# Loss: 0.03696604073047638 Tiempo transcurrido: 84.14861989021301
#
# --- Starting trial: run-34
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0589 - mean_squared_error: 0.0589
# Loss: 0.05890773981809616 Tiempo transcurrido: 35.488221645355225
#
# --- Starting trial: run-35
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1623 - mean_squared_error: 0.1623
# Loss: 0.1623266339302063 Tiempo transcurrido: 22.763189792633057
#
# --- Starting trial: run-36
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0372 - mean_squared_error: 0.0372
# Loss: 0.0371556356549263 Tiempo transcurrido: 119.07641553878784
#
# --- Starting trial: run-37
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0429 - mean_squared_error: 0.0429
# Loss: 0.04286956042051315 Tiempo transcurrido: 59.37783741950989
#
# --- Starting trial: run-38
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0305 - mean_squared_error: 0.0305
# Loss: 0.030511392280459404 Tiempo transcurrido: 32.706568002700806
#
# --- Starting trial: run-39
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0335 - mean_squared_error: 0.0335
# Loss: 0.03349487856030464 Tiempo transcurrido: 20.16007661819458
#
# --- Starting trial: run-40
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Loss: 0.03289436176419258 Tiempo transcurrido: 105.9015600681305
#
# --- Starting trial: run-41
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0362 - mean_squared_error: 0.0362
# Loss: 0.03621143102645874 Tiempo transcurrido: 62.31502032279968
#
# --- Starting trial: run-42
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0427 - mean_squared_error: 0.0427
# Loss: 0.04269575700163841 Tiempo transcurrido: 39.56815981864929
#
# --- Starting trial: run-43
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0622 - mean_squared_error: 0.0622
# Loss: 0.06222619116306305 Tiempo transcurrido: 24.993367433547974
#
# --- Starting trial: run-44
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0534 - mean_squared_error: 0.0534
# Loss: 0.05335201323032379 Tiempo transcurrido: 104.90640091896057
#
# --- Starting trial: run-45
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0548 - mean_squared_error: 0.0548
# Loss: 0.05475077033042908 Tiempo transcurrido: 54.23085403442383
#
# --- Starting trial: run-46
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0311 - mean_squared_error: 0.0311
# Loss: 0.03106502816081047 Tiempo transcurrido: 37.43631291389465
#
# --- Starting trial: run-47
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0415 - mean_squared_error: 0.0415
# Loss: 0.04149025306105614 Tiempo transcurrido: 24.195645570755005
#
# --- Starting trial: run-48
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0310 - mean_squared_error: 0.0310
# Loss: 0.030964786186814308 Tiempo transcurrido: 109.22421383857727
#
# --- Starting trial: run-49
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0365 - mean_squared_error: 0.0365
# Loss: 0.03654501587152481 Tiempo transcurrido: 42.57226085662842
#
# --- Starting trial: run-50
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0378 - mean_squared_error: 0.0378
# Loss: 0.037832166999578476 Tiempo transcurrido: 28.352640628814697
#
# --- Starting trial: run-51
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0577 - mean_squared_error: 0.0577
# Loss: 0.05771207809448242 Tiempo transcurrido: 16.223655462265015
#
# --- Starting trial: run-52
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0661 - mean_squared_error: 0.0661
# Loss: 0.06610176712274551 Tiempo transcurrido: 79.42123103141785
#
# --- Starting trial: run-53
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0471 - mean_squared_error: 0.0471
# Loss: 0.04707580804824829 Tiempo transcurrido: 41.15524458885193
#
# --- Starting trial: run-54
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0336 - mean_squared_error: 0.0336
# Loss: 0.033607665449380875 Tiempo transcurrido: 25.094595193862915
#
# --- Starting trial: run-55
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0497 - mean_squared_error: 0.0497
# Loss: 0.0496506541967392 Tiempo transcurrido: 16.40100622177124
#
# --- Starting trial: run-56
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0316 - mean_squared_error: 0.0316
# Loss: 0.03164996579289436 Tiempo transcurrido: 82.07596182823181
#
# --- Starting trial: run-57
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0331 - mean_squared_error: 0.0331
# Loss: 0.033130086958408356 Tiempo transcurrido: 48.476890325546265
#
# --- Starting trial: run-58
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0365 - mean_squared_error: 0.0365
# Loss: 0.03654077276587486 Tiempo transcurrido: 28.836591482162476
#
# --- Starting trial: run-59
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0542 - mean_squared_error: 0.0542
# Loss: 0.05421514809131622 Tiempo transcurrido: 19.078627347946167
#
# --- Starting trial: run-60
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0780 - mean_squared_error: 0.0780
# Loss: 0.07803217321634293 Tiempo transcurrido: 84.13573026657104
#
# --- Starting trial: run-61
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0503 - mean_squared_error: 0.0503
# Loss: 0.0502522736787796 Tiempo transcurrido: 35.85625910758972
#
# --- Starting trial: run-62
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0346 - mean_squared_error: 0.0346
# Loss: 0.03463679179549217 Tiempo transcurrido: 20.605703353881836
#
# --- Starting trial: run-63
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0533 - mean_squared_error: 0.0533
# Loss: 0.05326063185930252 Tiempo transcurrido: 13.901073694229126
#
# --- Starting trial: run-64
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0321 - mean_squared_error: 0.0321
# Loss: 0.032090310007333755 Tiempo transcurrido: 59.04089856147766
#
# --- Starting trial: run-65
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0335 - mean_squared_error: 0.0335
# Loss: 0.03351682797074318 Tiempo transcurrido: 32.369972944259644
#
# --- Starting trial: run-66
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0499 - mean_squared_error: 0.0499
# Loss: 0.049873992800712585 Tiempo transcurrido: 19.627285718917847
#
# --- Starting trial: run-67
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0571 - mean_squared_error: 0.0571
# Loss: 0.0570623055100441 Tiempo transcurrido: 12.765395641326904
#
# --- Starting trial: run-68
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0728 - mean_squared_error: 0.0728
# Loss: 0.07277636229991913 Tiempo transcurrido: 57.91586256027222
#
# --- Starting trial: run-69
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0394 - mean_squared_error: 0.0394
# Loss: 0.039376698434352875 Tiempo transcurrido: 31.51176118850708
#
# --- Starting trial: run-70
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0331 - mean_squared_error: 0.0331
# Loss: 0.0330669991672039 Tiempo transcurrido: 19.71602964401245
#
# --- Starting trial: run-71
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0557 - mean_squared_error: 0.0557
# Loss: 0.05565165355801582 Tiempo transcurrido: 12.421947479248047
#
# --- Starting trial: run-72
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0328 - mean_squared_error: 0.0328
# Loss: 0.03282978758215904 Tiempo transcurrido: 60.10623288154602
#
# --- Starting trial: run-73
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0317 - mean_squared_error: 0.0317
# Loss: 0.031704723834991455 Tiempo transcurrido: 32.81765580177307
#
# --- Starting trial: run-74
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0402 - mean_squared_error: 0.0402
# Loss: 0.040235765278339386 Tiempo transcurrido: 19.93371605873108
#
# --- Starting trial: run-75
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0408 - mean_squared_error: 0.0408
# Loss: 0.04075385630130768 Tiempo transcurrido: 13.117502450942993
#
# --- Starting trial: run-76
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0703 - mean_squared_error: 0.0703
# Loss: 0.07026504725217819 Tiempo transcurrido: 61.26757287979126
#
# --- Starting trial: run-77
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0449 - mean_squared_error: 0.0449
# Loss: 0.04491230100393295 Tiempo transcurrido: 33.28037905693054
#
# --- Starting trial: run-78
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0384 - mean_squared_error: 0.0384
# Loss: 0.038371097296476364 Tiempo transcurrido: 19.94906210899353
#
# --- Starting trial: run-79
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0363 - mean_squared_error: 0.0363
# Loss: 0.03625680133700371 Tiempo transcurrido: 12.99648642539978
#
# --- Starting trial: run-80
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0340 - mean_squared_error: 0.0340
# Loss: 0.03397754579782486 Tiempo transcurrido: 63.7682318687439
#
# --- Starting trial: run-81
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0325 - mean_squared_error: 0.0325
# Loss: 0.032508790493011475 Tiempo transcurrido: 34.723546266555786
#
# --- Starting trial: run-82
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0378 - mean_squared_error: 0.0378
# Loss: 0.03779307007789612 Tiempo transcurrido: 20.99923586845398
#
# --- Starting trial: run-83
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0380 - mean_squared_error: 0.0380
# Loss: 0.03798560053110123 Tiempo transcurrido: 14.251318216323853
#
# --- Starting trial: run-84
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0958 - mean_squared_error: 0.0958
# Loss: 0.09579574316740036 Tiempo transcurrido: 64.3015627861023
#
# --- Starting trial: run-85
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0320 - mean_squared_error: 0.0320
# Loss: 0.032044604420661926 Tiempo transcurrido: 35.56920051574707
#
# --- Starting trial: run-86
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0483 - mean_squared_error: 0.0483
# Loss: 0.04827295243740082 Tiempo transcurrido: 21.22739005088806
#
# --- Starting trial: run-87
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0501 - mean_squared_error: 0.0501
# Loss: 0.050069697201251984 Tiempo transcurrido: 13.808478832244873
#
# --- Starting trial: run-88
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0352 - mean_squared_error: 0.0352
# Loss: 0.03523107245564461 Tiempo transcurrido: 71.60552144050598
#
# --- Starting trial: run-89
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0305 - mean_squared_error: 0.0305
# Loss: 0.030513834208250046 Tiempo transcurrido: 39.05541658401489
#
# --- Starting trial: run-90
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0509 - mean_squared_error: 0.0509
# Loss: 0.05085808038711548 Tiempo transcurrido: 23.168670654296875
#
# --- Starting trial: run-91
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0407 - mean_squared_error: 0.0407
# Loss: 0.040683940052986145 Tiempo transcurrido: 15.608770370483398
#
# --- Starting trial: run-92
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0648 - mean_squared_error: 0.0648
# Loss: 0.06476007401943207 Tiempo transcurrido: 74.44279742240906
#
# --- Starting trial: run-93
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0335 - mean_squared_error: 0.0335
# Loss: 0.03347741439938545 Tiempo transcurrido: 40.526780128479004
#
# --- Starting trial: run-94
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0339 - mean_squared_error: 0.0339
# Loss: 0.033890943974256516 Tiempo transcurrido: 23.58235788345337
#
# --- Starting trial: run-95
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0344 - mean_squared_error: 0.0344
# Loss: 0.03441515564918518 Tiempo transcurrido: 15.493597030639648
#
# --- Starting trial: run-96
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0323 - mean_squared_error: 0.0323
# Loss: 0.032276637852191925 Tiempo transcurrido: 62.80933618545532
#
# --- Starting trial: run-97
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0318 - mean_squared_error: 0.0318
# Loss: 0.03181598335504532 Tiempo transcurrido: 34.58854413032532
#
# --- Starting trial: run-98
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0347 - mean_squared_error: 0.0347
# Loss: 0.0346992090344429 Tiempo transcurrido: 20.759657382965088
#
# --- Starting trial: run-99
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0408 - mean_squared_error: 0.0408
# Loss: 0.040788065642118454 Tiempo transcurrido: 13.392043352127075
#
# --- Starting trial: run-100
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0657 - mean_squared_error: 0.0657
# Loss: 0.06566622108221054 Tiempo transcurrido: 60.20026135444641
#
# --- Starting trial: run-101
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0661 - mean_squared_error: 0.0661
# Loss: 0.06612656265497208 Tiempo transcurrido: 33.11065125465393
#
# --- Starting trial: run-102
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0332 - mean_squared_error: 0.0332
# Loss: 0.03316415473818779 Tiempo transcurrido: 20.078022956848145
#
# --- Starting trial: run-103
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0643 - mean_squared_error: 0.0643
# Loss: 0.0642831027507782 Tiempo transcurrido: 13.496427297592163
#
# --- Starting trial: run-104
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0363 - mean_squared_error: 0.0363
# Loss: 0.03625714033842087 Tiempo transcurrido: 63.86274313926697
#
# --- Starting trial: run-105
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0337 - mean_squared_error: 0.0337
# Loss: 0.03368999809026718 Tiempo transcurrido: 34.918193101882935
#
# --- Starting trial: run-106
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0425 - mean_squared_error: 0.0425
# Loss: 0.04252535104751587 Tiempo transcurrido: 21.07878088951111
#
# --- Starting trial: run-107
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0393 - mean_squared_error: 0.0393
# Loss: 0.03932839632034302 Tiempo transcurrido: 13.857679605484009
#
# --- Starting trial: run-108
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0862 - mean_squared_error: 0.0862
# Loss: 0.08615043759346008 Tiempo transcurrido: 64.49364829063416
#
# --- Starting trial: run-109
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0310 - mean_squared_error: 0.0310
# Loss: 0.030958833172917366 Tiempo transcurrido: 35.94407773017883
#
# --- Starting trial: run-110
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0375 - mean_squared_error: 0.0375
# Loss: 0.037456102669239044 Tiempo transcurrido: 21.087176084518433
#
# --- Starting trial: run-111
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0403 - mean_squared_error: 0.0403
# Loss: 0.040304768830537796 Tiempo transcurrido: 13.773977041244507
#
# --- Starting trial: run-112
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0338 - mean_squared_error: 0.0338
# Loss: 0.033792439848184586 Tiempo transcurrido: 69.0784502029419
#
# --- Starting trial: run-113
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0330 - mean_squared_error: 0.0330
# Loss: 0.03299622982740402 Tiempo transcurrido: 38.14686965942383
#
# --- Starting trial: run-114
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Loss: 0.033387377858161926 Tiempo transcurrido: 22.83222794532776
#
# --- Starting trial: run-115
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0343 - mean_squared_error: 0.0343
# Loss: 0.03434179350733757 Tiempo transcurrido: 15.64032506942749
#
# --- Starting trial: run-116
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0964 - mean_squared_error: 0.0964
# Loss: 0.09638013690710068 Tiempo transcurrido: 70.07760500907898
#
# --- Starting trial: run-117
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0420 - mean_squared_error: 0.0420
# Loss: 0.04198914021253586 Tiempo transcurrido: 38.30648732185364
#
# --- Starting trial: run-118
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0414 - mean_squared_error: 0.0414
# Loss: 0.04143521189689636 Tiempo transcurrido: 22.830046892166138
#
# --- Starting trial: run-119
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0517 - mean_squared_error: 0.0517
# Loss: 0.05173071473836899 Tiempo transcurrido: 14.846390724182129
#
# --- Starting trial: run-120
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0343 - mean_squared_error: 0.0343
# Loss: 0.03434856981039047 Tiempo transcurrido: 79.85061955451965
#
# --- Starting trial: run-121
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0393 - mean_squared_error: 0.0393
# Loss: 0.03930369019508362 Tiempo transcurrido: 44.46606206893921
#
# --- Starting trial: run-122
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0322 - mean_squared_error: 0.0322
# Loss: 0.03219766914844513 Tiempo transcurrido: 26.13921594619751
#
# --- Starting trial: run-123
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0373 - mean_squared_error: 0.0373
# Loss: 0.03725558519363403 Tiempo transcurrido: 18.177032232284546
#
# --- Starting trial: run-124
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0806 - mean_squared_error: 0.0806
# Loss: 0.08062094449996948 Tiempo transcurrido: 88.03357672691345
#
# --- Starting trial: run-125
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0465 - mean_squared_error: 0.0465
# Loss: 0.04653951898217201 Tiempo transcurrido: 46.53761672973633
#
# --- Starting trial: run-126
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0460 - mean_squared_error: 0.0460
# Loss: 0.046008650213479996 Tiempo transcurrido: 27.703664779663086
#
# --- Starting trial: run-127
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0769 - mean_squared_error: 0.0769
# Loss: 0.07686024159193039 Tiempo transcurrido: 17.914536237716675
# 128

# %%
filename = "historial_jla_tunning.txt"
df = pd.DataFrame(datos, columns = ["Deep size", "Num units", "Learning rate", "Batch size", "MSE", "Tiempo de ejecución"])

df.sort_values(by=["MSE", "Tiempo de ejecución"], ascending=[True, True], ignore_index=True, inplace=True)

df.to_csv(filename, header=True, index=False, sep='\t', mode='w') # a=append, w=overwrite

# %%
df.head(2)
# Out:
#    Deep size  Num units  Learning rate  Batch size       MSE  \
# 0          2         50         0.0010          16  0.033495
# 1          4        150         0.0001          16  0.034342
#
#    Tiempo de ejecución
# 0            20.160077
# 1            15.640325

# %%
total_time = float(np.sum(df[["Tiempo de ejecución"]])/60)

print("Elapsed time {:.3f} minutes".format(total_time))
# Out:
# Elapsed time 9.231 minutes

# %%
df["Tiempo de ejecución"]
# Out:
# 0     20.160077
# 1     15.640325
# 2     15.493597
# 3     22.358655
# 4     12.996486
# 5     19.644713
# 6     18.177032
# 7     14.251318
# 8     13.857680
# 9     13.773977
# 10    15.608770
# 11    13.117502
# 12    13.392043
# 13    24.195646
# 14    20.641767
# 15    16.401006
# 16    13.808479
# 17    21.010458
# 18    14.846391
# 19    13.901074
# 20    19.078627
# 21    12.421947
# 22    12.765396
# 23    16.223655
# 24    24.993367
# 25    13.496427
# 26    17.914536
# 27    22.763190
# 28    21.285539
# 29    19.528263
# 30    20.052421
# 31    20.082948
# Name: Tiempo de ejecución, dtype: float64
