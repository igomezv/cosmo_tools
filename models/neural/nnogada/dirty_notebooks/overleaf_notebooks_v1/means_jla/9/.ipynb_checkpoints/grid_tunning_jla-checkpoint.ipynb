# %%
# %load_ext tensorboard
# Clear any logs from previous runs
# !rm -rf ./logs/

# %%
import numpy as np
import pandas as pd
import time, os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import to_categorical
from tensorboard.plugins.hparams import api as hp

from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Model

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split as split

import random
from math import floor
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from scipy.integrate import odeint
import scipy
import pandas as pd
np.random.seed(0)
# Out:
# 2022-12-16 20:40:41.234553: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-16 20:40:41.374477: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-16 20:40:41.374498: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-16 20:40:42.311484: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-16 20:40:42.311565: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-16 20:40:42.311575: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
url = 'https://raw.githubusercontent.com/igomezv/nnogada/main/data/jla.csv'
df=pd.read_csv(url)
N = len(df.values)
randomize = np.random.permutation(N)
data = df.values[randomize]
N = len(df.values)
z = data[:,0] 
y = data[:,1:3] ### coge el resto de variables a predecir 
y[:,1] = y[:,1]**2+data[:,2]
np.shape(y)
# Out:
# (740, 2)

# %%
scalerz = StandardScaler()
scalerz.fit(z.reshape(-1,1))
z = scalerz.transform(z.reshape(-1,1))

# %%
### Modificar para incluir phanteon como test
split = 0.8
ntrain = int(split * len(z))
indx = [ntrain]
X_train, X_test = np.split(z, indx)
Y_train, Y_test = np.split(y, indx)
np.shape(X_train), np.shape(X_test), Y_train.shape, Y_test.shape
# Out:
# ((592, 1), (148, 1), (592, 2), (148, 2))

# %%
# loss -> val_loss
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min',
                                   min_delta=0.0,
                                   patience=200,
                                   restore_best_weights=True, verbose=True)
                                   ]

n_cols = 1

# %%
HP_BATCHSIZE = hp.HParam('batch_size', hp.Discrete([2, 4, 8, 16]))
HP_LAYERS =    hp.HParam('layers', hp.Discrete([1, 2, 3, 4]))
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([50, 100, 150, 200]))
HP_LEARNING  = hp.HParam('learning_rate', hp.Discrete([1e-4,1e-3]))
# HP_NUM_UNITS3 = hp.HParam('num_units3', hp.Discrete([50, 100, 150, 200]))
# HP_NUM_UNITS4 = hp.HParam('num_units4', hp.Discrete([2, 5, 10]))
# HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.0, 0.2))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'Adadelta']))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam']))

# %%
epochs=200

# %%
# sess = tf.Session()
# writer = tf.summary.FileWriter("/tmp/tfvgg", sess.graph)
# init = tf.initialize_all_variables()
# sess.run(init)
# with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
#     hp.hparams_config(
#         hparams=[HP_NUM_UNITS1, HP_NUM_UNITS2, HP_NUM_UNITS3, HP_NUM_UNITS4,
#                  HP_OPTIMIZER, HP_BATCHSIZE],
#         metrics=[hp.Metric('loss', display_name="Loss")])

# %%
# METRIC_ACCURACY = 'accuracy'
with tf.summary.create_file_writer('logs/hparam_tuning3').as_default():
# with tf.summary.FileWriter('logs/hparam_tuning', sess.graph):
#     init = tf.initialize_all_variables()
#     sess.run(init)
    hp.hparams_config(
        hparams=[HP_LAYERS,
                 HP_NUM_UNITS,
                 HP_LEARNING, 
                 HP_BATCHSIZE],
        metrics=[hp.Metric('loss', display_name="Loss")])
# Out:
# 2022-12-16 20:40:43.650344: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 20:40:43.650548: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-16 20:40:43.650621: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 20:40:43.650671: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 20:40:43.650721: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-12-16 20:40:43.650780: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-12-16 20:40:43.650871: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 20:40:43.650933: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 20:40:43.650996: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-12-16 20:40:43.651008: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-12-16 20:40:43.651257: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def train_test_model(hparams):    
    
    # Train LSTM model and predict on validation set
    model = tf.keras.Sequential()
    model.add(Dense(int(X_train.shape[1])))
#     model.add(Dense(hparams[HP_NUM_UNITS], input_shape=(int(X_train.shape[1]),)))
    
    for i in range(hparams[HP_LAYERS]):        
        model.add(Dense(hparams[HP_NUM_UNITS], activation='relu'))
    model.add(Dense(2, activation='linear'))
     
    optimizer = tf.keras.optimizers.Adam(learning_rate=hparams[HP_LEARNING], beta_1=0.9, beta_2=0.999, epsilon=1e-3)
    model.compile(
            optimizer=optimizer,
            loss='mse', 
            metrics=['mean_squared_error'])
    
    # Run with 1 epoch to speed things up for demo purposes

    model.fit(X_train, Y_train, epochs=epochs, validation_data=(X_test, Y_test),
              callbacks=callbacks, batch_size=hparams[HP_BATCHSIZE], shuffle=False, verbose=0)

    _, loss = model.evaluate(X_test, Y_test)
    
    return loss

# %%
def run(run_dir, hparams):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        loss = train_test_model(hparams)
        tf.summary.scalar("loss", loss, step=1)
        return loss

# %%
session_num = 0
datos = []

for deep_layers in HP_LAYERS.domain.values:
    for num_units in HP_NUM_UNITS.domain.values:
        for learning_rate in HP_LEARNING.domain.values:
            for batch_size in HP_BATCHSIZE.domain.values:
                t = time.time()
                hparams = {

                    HP_LAYERS: deep_layers,
                    HP_NUM_UNITS: num_units,
                    HP_LEARNING: learning_rate,
                    HP_BATCHSIZE: batch_size,
                }
                run_name = "run-%d" % session_num
                print('\n--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                score = run('logs/hparam_tuning3/' + run_name, hparams)
                t = time.time()-t
                session_num += 1
                print("Loss:", score, "Tiempo transcurrido:", t)
            
            datos.append([deep_layers, num_units, learning_rate, batch_size, score, t])

print(session_num)
# Out:
# --- Starting trial: run-0
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0574 - mean_squared_error: 0.0574
# Loss: 0.05740416422486305 Tiempo transcurrido: 127.0494499206543
#
# --- Starting trial: run-1
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1413 - mean_squared_error: 0.1413
# Loss: 0.14133864641189575 Tiempo transcurrido: 67.93081998825073
#
# --- Starting trial: run-2
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3216 - mean_squared_error: 0.3216
# Loss: 0.3216099143028259 Tiempo transcurrido: 43.722179651260376
#
# --- Starting trial: run-3
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 15.3541 - mean_squared_error: 15.3541
# Loss: 15.354073524475098 Tiempo transcurrido: 26.82124090194702
#
# --- Starting trial: run-4
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0311 - mean_squared_error: 0.0311
# Loss: 0.031059687957167625 Tiempo transcurrido: 125.69681024551392
#
# --- Starting trial: run-5
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0330 - mean_squared_error: 0.0330
# Loss: 0.032971594482660294 Tiempo transcurrido: 83.1703040599823
#
# --- Starting trial: run-6
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0406 - mean_squared_error: 0.0406
# Loss: 0.04060615599155426 Tiempo transcurrido: 47.91621804237366
#
# --- Starting trial: run-7
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0742 - mean_squared_error: 0.0742
# Loss: 0.07416000217199326 Tiempo transcurrido: 29.092899560928345
#
# --- Starting trial: run-8
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0545 - mean_squared_error: 0.0545
# Loss: 0.054494459182024 Tiempo transcurrido: 126.88085842132568
#
# --- Starting trial: run-9
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0767 - mean_squared_error: 0.0767
# Loss: 0.07667792588472366 Tiempo transcurrido: 74.06866574287415
#
# --- Starting trial: run-10
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1192 - mean_squared_error: 0.1192
# Loss: 0.11923456192016602 Tiempo transcurrido: 42.01743984222412
#
# --- Starting trial: run-11
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0542 - mean_squared_error: 1.0542
# Loss: 1.0542018413543701 Tiempo transcurrido: 27.259734630584717
#
# --- Starting trial: run-12
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0301 - mean_squared_error: 0.0301
# Loss: 0.03005828708410263 Tiempo transcurrido: 136.44019603729248
#
# --- Starting trial: run-13
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0361 - mean_squared_error: 0.0361
# Loss: 0.036140572279691696 Tiempo transcurrido: 83.11717772483826
#
# --- Starting trial: run-14
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0419 - mean_squared_error: 0.0419
# Loss: 0.04191065579652786 Tiempo transcurrido: 41.95825934410095
#
# --- Starting trial: run-15
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0449 - mean_squared_error: 0.0449
# Loss: 0.04486319050192833 Tiempo transcurrido: 41.979474782943726
#
# --- Starting trial: run-16
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0470 - mean_squared_error: 0.0470
# Loss: 0.0469944104552269 Tiempo transcurrido: 137.78664875030518
#
# --- Starting trial: run-17
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0628 - mean_squared_error: 0.0628
# Loss: 0.06280266493558884 Tiempo transcurrido: 83.2320990562439
#
# --- Starting trial: run-18
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0944 - mean_squared_error: 0.0944
# Loss: 0.09440933912992477 Tiempo transcurrido: 43.660648822784424
#
# --- Starting trial: run-19
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2638 - mean_squared_error: 0.2638
# Loss: 0.26380833983421326 Tiempo transcurrido: 42.13178730010986
#
# --- Starting trial: run-20
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0320 - mean_squared_error: 0.0320
# Loss: 0.03199642151594162 Tiempo transcurrido: 143.26323294639587
#
# --- Starting trial: run-21
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0311 - mean_squared_error: 0.0311
# Loss: 0.031083406880497932 Tiempo transcurrido: 83.26469039916992
#
# --- Starting trial: run-22
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0381 - mean_squared_error: 0.0381
# Loss: 0.0380781851708889 Tiempo transcurrido: 83.05505657196045
#
# --- Starting trial: run-23
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0407 - mean_squared_error: 0.0407
# Loss: 0.040661733597517014 Tiempo transcurrido: 24.859198570251465
#
# --- Starting trial: run-24
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0434 - mean_squared_error: 0.0434
# Loss: 0.04344017803668976 Tiempo transcurrido: 138.123544216156
#
# --- Starting trial: run-25
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1530 - mean_squared_error: 0.1530
# Loss: 0.15297608077526093 Tiempo transcurrido: 83.96889114379883
#
# --- Starting trial: run-26
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0967 - mean_squared_error: 0.0967
# Loss: 0.09670278429985046 Tiempo transcurrido: 48.70325255393982
#
# --- Starting trial: run-27
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2238 - mean_squared_error: 0.2238
# Loss: 0.223775714635849 Tiempo transcurrido: 27.796449899673462
#
# --- Starting trial: run-28
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Loss: 0.03293851763010025 Tiempo transcurrido: 134.4551203250885
#
# --- Starting trial: run-29
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0304 - mean_squared_error: 0.0304
# Loss: 0.030439963564276695 Tiempo transcurrido: 82.44626259803772
#
# --- Starting trial: run-30
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0407 - mean_squared_error: 0.0407
# Loss: 0.0406997948884964 Tiempo transcurrido: 43.15287160873413
#
# --- Starting trial: run-31
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0428 - mean_squared_error: 0.0428
# Loss: 0.0428055003285408 Tiempo transcurrido: 31.323854446411133
#
# --- Starting trial: run-32
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0335 - mean_squared_error: 0.0335
# Loss: 0.033454254269599915 Tiempo transcurrido: 203.59039497375488
#
# --- Starting trial: run-33
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0439 - mean_squared_error: 0.0439
# Loss: 0.043935876339673996 Tiempo transcurrido: 144.27740216255188
#
# --- Starting trial: run-34
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0514 - mean_squared_error: 0.0514
# Loss: 0.05139383673667908 Tiempo transcurrido: 44.86208534240723
#
# --- Starting trial: run-35
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1008 - mean_squared_error: 0.1008
# Loss: 0.10079481452703476 Tiempo transcurrido: 27.86067247390747
#
# --- Starting trial: run-36
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0467 - mean_squared_error: 0.0467
# Loss: 0.046677347272634506 Tiempo transcurrido: 147.15982961654663
#
# --- Starting trial: run-37
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0394 - mean_squared_error: 0.0394
# Loss: 0.03936304897069931 Tiempo transcurrido: 143.65104699134827
#
# --- Starting trial: run-38
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0338 - mean_squared_error: 0.0338
# Loss: 0.03379127010703087 Tiempo transcurrido: 83.42872357368469
#
# --- Starting trial: run-39
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0349 - mean_squared_error: 0.0349
# Loss: 0.03490980342030525 Tiempo transcurrido: 22.89469265937805
#
# --- Starting trial: run-40
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0315 - mean_squared_error: 0.0315
# Loss: 0.03152039647102356 Tiempo transcurrido: 146.95803713798523
#
# --- Starting trial: run-41
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0375 - mean_squared_error: 0.0375
# Loss: 0.03750491887331009 Tiempo transcurrido: 66.6370918750763
#
# --- Starting trial: run-42
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0396 - mean_squared_error: 0.0396
# Loss: 0.03963842615485191 Tiempo transcurrido: 83.23355031013489
#
# --- Starting trial: run-43
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0880 - mean_squared_error: 0.0880
# Loss: 0.08801662921905518 Tiempo transcurrido: 27.237677574157715
#
# --- Starting trial: run-44
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0555 - mean_squared_error: 0.0555
# Loss: 0.05548905208706856 Tiempo transcurrido: 143.56754994392395
#
# --- Starting trial: run-45
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0396 - mean_squared_error: 0.0396
# Loss: 0.03963734209537506 Tiempo transcurrido: 83.46127963066101
#
# --- Starting trial: run-46
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0431 - mean_squared_error: 0.0431
# Loss: 0.04307631403207779 Tiempo transcurrido: 33.196449279785156
#
# --- Starting trial: run-47
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0370 - mean_squared_error: 0.0370
# Loss: 0.03699195012450218 Tiempo transcurrido: 21.781946897506714
#
# --- Starting trial: run-48
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0311 - mean_squared_error: 0.0311
# Loss: 0.031058739870786667 Tiempo transcurrido: 144.09151554107666
#
# --- Starting trial: run-49
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0361 - mean_squared_error: 0.0361
# Loss: 0.03607163950800896 Tiempo transcurrido: 77.83908867835999
#
# --- Starting trial: run-50
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0395 - mean_squared_error: 0.0395
# Loss: 0.03950833901762962 Tiempo transcurrido: 42.24567103385925
#
# --- Starting trial: run-51
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0624 - mean_squared_error: 0.0624
# Loss: 0.06244681403040886 Tiempo transcurrido: 42.48824405670166
#
# --- Starting trial: run-52
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0653 - mean_squared_error: 0.0653
# Loss: 0.06531179696321487 Tiempo transcurrido: 143.61168885231018
#
# --- Starting trial: run-53
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0474 - mean_squared_error: 0.0474
# Loss: 0.04736141860485077 Tiempo transcurrido: 83.58278703689575
#
# --- Starting trial: run-54
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0342 - mean_squared_error: 0.0342
# Loss: 0.034202732145786285 Tiempo transcurrido: 43.80041241645813
#
# --- Starting trial: run-55
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0409 - mean_squared_error: 0.0409
# Loss: 0.040903206914663315 Tiempo transcurrido: 27.301329851150513
#
# --- Starting trial: run-56
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0318 - mean_squared_error: 0.0318
# Loss: 0.03181782364845276 Tiempo transcurrido: 130.9029517173767
#
# --- Starting trial: run-57
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0354 - mean_squared_error: 0.0354
# Loss: 0.03542732074856758 Tiempo transcurrido: 68.36952781677246
#
# --- Starting trial: run-58
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0365 - mean_squared_error: 0.0365
# Loss: 0.036470551043748856 Tiempo transcurrido: 35.63579273223877
#
# --- Starting trial: run-59
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0540 - mean_squared_error: 0.0540
# Loss: 0.05403374135494232 Tiempo transcurrido: 20.523112058639526
#
# --- Starting trial: run-60
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0646 - mean_squared_error: 0.0646
# Loss: 0.06461308896541595 Tiempo transcurrido: 103.19279885292053
#
# --- Starting trial: run-61
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0476 - mean_squared_error: 0.0476
# Loss: 0.047594182193279266 Tiempo transcurrido: 55.73152685165405
#
# --- Starting trial: run-62
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Loss: 0.03289567306637764 Tiempo transcurrido: 29.16360092163086
#
# --- Starting trial: run-63
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0445 - mean_squared_error: 0.0445
# Loss: 0.044504035264253616 Tiempo transcurrido: 20.64635992050171
#
# --- Starting trial: run-64
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0435 - mean_squared_error: 0.0435
# Loss: 0.04352468252182007 Tiempo transcurrido: 88.9227283000946
#
# --- Starting trial: run-65
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0352 - mean_squared_error: 0.0352
# Loss: 0.03518025577068329 Tiempo transcurrido: 48.11421585083008
#
# --- Starting trial: run-66
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0378 - mean_squared_error: 0.0378
# Loss: 0.037788521498441696 Tiempo transcurrido: 29.591660022735596
#
# --- Starting trial: run-67
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0557 - mean_squared_error: 0.0557
# Loss: 0.05569760873913765 Tiempo transcurrido: 18.925462007522583
#
# --- Starting trial: run-68
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0783 - mean_squared_error: 0.0783
# Loss: 0.07829104363918304 Tiempo transcurrido: 79.59299683570862
#
# --- Starting trial: run-69
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0346 - mean_squared_error: 0.0346
# Loss: 0.034591082483530045 Tiempo transcurrido: 37.04993724822998
#
# --- Starting trial: run-70
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0371 - mean_squared_error: 0.0371
# Loss: 0.03708663210272789 Tiempo transcurrido: 23.85208010673523
#
# --- Starting trial: run-71
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0479 - mean_squared_error: 0.0479
# Loss: 0.04790452495217323 Tiempo transcurrido: 15.366910696029663
#
# --- Starting trial: run-72
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0322 - mean_squared_error: 0.0322
# Loss: 0.032223328948020935 Tiempo transcurrido: 74.03992056846619
#
# --- Starting trial: run-73
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0304 - mean_squared_error: 0.0304
# Loss: 0.030386963859200478 Tiempo transcurrido: 39.99282503128052
#
# --- Starting trial: run-74
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0362 - mean_squared_error: 0.0362
# Loss: 0.03623216599225998 Tiempo transcurrido: 24.24729561805725
#
# --- Starting trial: run-75
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0413 - mean_squared_error: 0.0413
# Loss: 0.041278667747974396 Tiempo transcurrido: 15.856955528259277
#
# --- Starting trial: run-76
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0923 - mean_squared_error: 0.0923
# Loss: 0.09227349609136581 Tiempo transcurrido: 74.51797795295715
#
# --- Starting trial: run-77
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0410 - mean_squared_error: 0.0410
# Loss: 0.04104304313659668 Tiempo transcurrido: 40.53010034561157
#
# --- Starting trial: run-78
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0404 - mean_squared_error: 0.0404
# Loss: 0.04038581624627113 Tiempo transcurrido: 24.702245950698853
#
# --- Starting trial: run-79
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.1013 - mean_squared_error: 0.1013
# Loss: 0.10133591294288635 Tiempo transcurrido: 16.125906467437744
#
# --- Starting trial: run-80
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0333 - mean_squared_error: 0.0333
# Loss: 0.03331718593835831 Tiempo transcurrido: 81.63749933242798
#
# --- Starting trial: run-81
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0297 - mean_squared_error: 0.0297
# Loss: 0.029699616134166718 Tiempo transcurrido: 44.370102882385254
#
# --- Starting trial: run-82
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0383 - mean_squared_error: 0.0383
# Loss: 0.03830702230334282 Tiempo transcurrido: 26.752492904663086
#
# --- Starting trial: run-83
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0394 - mean_squared_error: 0.0394
# Loss: 0.039413124322891235 Tiempo transcurrido: 18.044692754745483
#
# --- Starting trial: run-84
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1237 - mean_squared_error: 0.1237
# Loss: 0.12367698550224304 Tiempo transcurrido: 81.39290356636047
#
# --- Starting trial: run-85
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0369 - mean_squared_error: 0.0369
# Loss: 0.03688596561551094 Tiempo transcurrido: 43.94980216026306
#
# --- Starting trial: run-86
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0349 - mean_squared_error: 0.0349
# Loss: 0.034855496138334274 Tiempo transcurrido: 27.679342031478882
#
# --- Starting trial: run-87
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0440 - mean_squared_error: 0.0440
# Loss: 0.04399031028151512 Tiempo transcurrido: 17.826624155044556
#
# --- Starting trial: run-88
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0336 - mean_squared_error: 0.0336
# Loss: 0.03356907144188881 Tiempo transcurrido: 106.19485855102539
#
# --- Starting trial: run-89
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0335 - mean_squared_error: 0.0335
# Loss: 0.03346485272049904 Tiempo transcurrido: 55.863600730895996
#
# --- Starting trial: run-90
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0517 - mean_squared_error: 0.0517
# Loss: 0.05172337219119072 Tiempo transcurrido: 32.70180821418762
#
# --- Starting trial: run-91
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0408 - mean_squared_error: 0.0408
# Loss: 0.040751732885837555 Tiempo transcurrido: 20.484509706497192
#
# --- Starting trial: run-92
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1186 - mean_squared_error: 0.1186
# Loss: 0.11861839890480042 Tiempo transcurrido: 105.04803252220154
#
# --- Starting trial: run-93
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0374 - mean_squared_error: 0.0374
# Loss: 0.03740484267473221 Tiempo transcurrido: 55.0097553730011
#
# --- Starting trial: run-94
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0409 - mean_squared_error: 0.0409
# Loss: 0.04090539738535881 Tiempo transcurrido: 29.225852966308594
#
# --- Starting trial: run-95
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0473 - mean_squared_error: 0.0473
# Loss: 0.047349534928798676 Tiempo transcurrido: 18.401761770248413
#
# --- Starting trial: run-96
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0322 - mean_squared_error: 0.0322
# Loss: 0.032160889357328415 Tiempo transcurrido: 72.58106660842896
#
# --- Starting trial: run-97
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0324 - mean_squared_error: 0.0324
# Loss: 0.032389987260103226 Tiempo transcurrido: 39.95138669013977
#
# --- Starting trial: run-98
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0353 - mean_squared_error: 0.0353
# Loss: 0.03527503088116646 Tiempo transcurrido: 24.476296424865723
#
# --- Starting trial: run-99
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0393 - mean_squared_error: 0.0393
# Loss: 0.03934091329574585 Tiempo transcurrido: 15.931040048599243
#
# --- Starting trial: run-100
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0851 - mean_squared_error: 0.0851
# Loss: 0.08505301922559738 Tiempo transcurrido: 72.22783732414246
#
# --- Starting trial: run-101
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0398 - mean_squared_error: 0.0398
# Loss: 0.03983359411358833 Tiempo transcurrido: 40.12755346298218
#
# --- Starting trial: run-102
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0382 - mean_squared_error: 0.0382
# Loss: 0.038239918649196625 Tiempo transcurrido: 24.34310245513916
#
# --- Starting trial: run-103
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0954 - mean_squared_error: 0.0954
# Loss: 0.09536951035261154 Tiempo transcurrido: 16.81439733505249
#
# --- Starting trial: run-104
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0357 - mean_squared_error: 0.0357
# Loss: 0.03571983426809311 Tiempo transcurrido: 79.90304136276245
#
# --- Starting trial: run-105
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0337 - mean_squared_error: 0.0337
# Loss: 0.03369487449526787 Tiempo transcurrido: 43.361241579055786
#
# --- Starting trial: run-106
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0416 - mean_squared_error: 0.0416
# Loss: 0.0415673665702343 Tiempo transcurrido: 25.66598916053772
#
# --- Starting trial: run-107
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0391 - mean_squared_error: 0.0391
# Loss: 0.03913794830441475 Tiempo transcurrido: 17.146223783493042
#
# --- Starting trial: run-108
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.1189 - mean_squared_error: 0.1189
# Loss: 0.11890513449907303 Tiempo transcurrido: 79.90684628486633
#
# --- Starting trial: run-109
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0344 - mean_squared_error: 0.0344
# Loss: 0.03442634269595146 Tiempo transcurrido: 44.01538395881653
#
# --- Starting trial: run-110
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0375 - mean_squared_error: 0.0375
# Loss: 0.03747624158859253 Tiempo transcurrido: 26.45199751853943
#
# --- Starting trial: run-111
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Loss: 0.03290309011936188 Tiempo transcurrido: 17.4954936504364
#
# --- Starting trial: run-112
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0341 - mean_squared_error: 0.0341
# Loss: 0.034068018198013306 Tiempo transcurrido: 91.7989592552185
#
# --- Starting trial: run-113
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0342 - mean_squared_error: 0.0342
# Loss: 0.03421494737267494 Tiempo transcurrido: 49.3228805065155
#
# --- Starting trial: run-114
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Loss: 0.03344878926873207 Tiempo transcurrido: 29.060468196868896
#
# --- Starting trial: run-115
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0335 - mean_squared_error: 0.0335
# Loss: 0.03354216367006302 Tiempo transcurrido: 19.585322618484497
#
# --- Starting trial: run-116
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0999 - mean_squared_error: 0.0999
# Loss: 0.09990103542804718 Tiempo transcurrido: 90.7434139251709
#
# --- Starting trial: run-117
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0469 - mean_squared_error: 0.0469
# Loss: 0.04693305864930153 Tiempo transcurrido: 48.29687285423279
#
# --- Starting trial: run-118
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0344 - mean_squared_error: 0.0344
# Loss: 0.03436177968978882 Tiempo transcurrido: 30.080609560012817
#
# --- Starting trial: run-119
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0413 - mean_squared_error: 0.0413
# Loss: 0.041266169399023056 Tiempo transcurrido: 19.39561915397644
#
# --- Starting trial: run-120
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0333 - mean_squared_error: 0.0333
# Loss: 0.03333942964673042 Tiempo transcurrido: 125.51337313652039
#
# --- Starting trial: run-121
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0343 - mean_squared_error: 0.0343
# Loss: 0.034316837787628174 Tiempo transcurrido: 63.032302141189575
#
# --- Starting trial: run-122
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Loss: 0.03337719663977623 Tiempo transcurrido: 34.87337899208069
#
# --- Starting trial: run-123
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0375 - mean_squared_error: 0.0375
# Loss: 0.037541188299655914 Tiempo transcurrido: 22.22290062904358
#
# --- Starting trial: run-124
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0803 - mean_squared_error: 0.0803
# Loss: 0.08028696477413177 Tiempo transcurrido: 143.62593793869019
#
# --- Starting trial: run-125
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0331 - mean_squared_error: 0.0331
# Loss: 0.0331297293305397 Tiempo transcurrido: 66.74383473396301
#
# --- Starting trial: run-126
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0410 - mean_squared_error: 0.0410
# Loss: 0.040991876274347305 Tiempo transcurrido: 30.403875827789307
#
# --- Starting trial: run-127
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0716 - mean_squared_error: 0.0716
# Loss: 0.07162315398454666 Tiempo transcurrido: 15.569457054138184
# 128

# %%
filename = "historial_jla_tunning.txt"
df = pd.DataFrame(datos, columns = ["Deep size", "Num units", "Learning rate", "Batch size", "MSE", "Tiempo de ejecución"])

df.sort_values(by=["MSE", "Tiempo de ejecución"], ascending=[True, True], ignore_index=True, inplace=True)

df.to_csv(filename, header=True, index=False, sep='\t', mode='w') # a=append, w=overwrite

# %%
df.head(2)
# Out:
#    Deep size  Num units  Learning rate  Batch size       MSE  \
# 0          4        100         0.0010          16  0.032903
# 1          4        150         0.0001          16  0.033542
#
#    Tiempo de ejecución
# 0            17.495494
# 1            19.585323

# %%
total_time = float(np.sum(df[["Tiempo de ejecución"]])/60)

print("Elapsed time {:.3f} minutes".format(total_time))
# Out:
# Elapsed time 12.453 minutes

# %%
df["Tiempo de ejecución"]
# Out:
# 0     17.495494
# 1     19.585323
# 2     22.894693
# 3     21.781947
# 4     22.222901
# 5     17.146224
# 6     15.931040
# 7     18.044693
# 8     24.859199
# 9     20.484510
# 10    27.301330
# 11    19.395619
# 12    15.856956
# 13    31.323854
# 14    17.826624
# 15    20.646360
# 16    41.979475
# 17    18.401762
# 18    15.366911
# 19    20.523112
# 20    18.925462
# 21    42.488244
# 22    15.569457
# 23    29.092900
# 24    27.237678
# 25    16.814397
# 26    27.860672
# 27    16.125906
# 28    27.796450
# 29    42.131787
# 30    27.259735
# 31    26.821241
# Name: Tiempo de ejecución, dtype: float64
