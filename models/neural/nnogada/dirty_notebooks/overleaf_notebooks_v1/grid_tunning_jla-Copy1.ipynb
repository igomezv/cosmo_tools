# %%
# %load_ext tensorboard
# Clear any logs from previous runs
# !rm -rf ./logs/

# %%
import numpy as np
import pandas as pd
import time, os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import to_categorical
from tensorboard.plugins.hparams import api as hp

from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Model

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split as split

import random
from math import floor
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from scipy.integrate import odeint
import scipy
import pandas as pd
np.random.seed(0)

# %%
url = 'https://raw.githubusercontent.com/igomezv/nnogada/main/data/jla.csv'
df=pd.read_csv(url)
N = len(df.values)
randomize = np.random.permutation(N)
data = df.values[randomize]
N = len(df.values)
z = data[:,0] 
y = data[:,1:3] ### coge el resto de variables a predecir 
y[:,1] = y[:,1]**2+data[:,2]
np.shape(y)
# Out:
# (740, 2)

# %%
scalerz = StandardScaler()
scalerz.fit(z.reshape(-1,1))
z = scalerz.transform(z.reshape(-1,1))

# %%
### Modificar para incluir phanteon como test
split = 0.8
ntrain = int(split * len(z))
indx = [ntrain]
X_train, X_test = np.split(z, indx)
Y_train, Y_test = np.split(y, indx)
np.shape(X_train), np.shape(X_test), Y_train.shape, Y_test.shape
# Out:
# ((592, 1), (148, 1), (592, 2), (148, 2))

# %%
# loss -> val_loss
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min',
                                   min_delta=0.0,
                                   patience=200,
                                   restore_best_weights=True, verbose=True)
                                   ]

n_cols = 1

# %%
HP_BATCHSIZE = hp.HParam('batch_size', hp.Discrete([2, 4, 8, 16]))
HP_LAYERS =    hp.HParam('layers', hp.Discrete([1, 2, 3, 4]))
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([50, 100, 150, 200]))
HP_LEARNING  = hp.HParam('learning_rate', hp.Discrete([1e-4,1e-3]))
# HP_NUM_UNITS3 = hp.HParam('num_units3', hp.Discrete([50, 100, 150, 200]))
# HP_NUM_UNITS4 = hp.HParam('num_units4', hp.Discrete([2, 5, 10]))
# HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.0, 0.2))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'Adadelta']))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam']))

# %%
epochs=200

# %%
# sess = tf.Session()
# writer = tf.summary.FileWriter("/tmp/tfvgg", sess.graph)
# init = tf.initialize_all_variables()
# sess.run(init)
# with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
#     hp.hparams_config(
#         hparams=[HP_NUM_UNITS1, HP_NUM_UNITS2, HP_NUM_UNITS3, HP_NUM_UNITS4,
#                  HP_OPTIMIZER, HP_BATCHSIZE],
#         metrics=[hp.Metric('loss', display_name="Loss")])

# %%
# METRIC_ACCURACY = 'accuracy'
with tf.summary.create_file_writer('logs/hparam_tuning3').as_default():
# with tf.summary.FileWriter('logs/hparam_tuning', sess.graph):
#     init = tf.initialize_all_variables()
#     sess.run(init)
    hp.hparams_config(
        hparams=[HP_LAYERS,
                 HP_NUM_UNITS,
                 HP_LEARNING, 
                 HP_BATCHSIZE],
        metrics=[hp.Metric('loss', display_name="Loss")])

# %%
def train_test_model(hparams):    
    
    # Train LSTM model and predict on validation set
    model = tf.keras.Sequential()
    model.add(Dense(int(X_train.shape[1])))
#     model.add(Dense(hparams[HP_NUM_UNITS], input_shape=(int(X_train.shape[1]),)))
    
    for i in range(hparams[HP_LAYERS]):        
        model.add(Dense(hparams[HP_NUM_UNITS], activation='relu'))
    model.add(Dense(2, activation='linear'))
     
    optimizer = tf.keras.optimizers.Adam(learning_rate=hparams[HP_LEARNING], beta_1=0.9, beta_2=0.999, epsilon=1e-3)
    model.compile(
            optimizer=optimizer,
            loss='mse', 
            metrics=['mean_squared_error'])
    
    # Run with 1 epoch to speed things up for demo purposes

    model.fit(X_train, Y_train, epochs=epochs, validation_data=(X_test, Y_test),
              callbacks=callbacks, batch_size=hparams[HP_BATCHSIZE], shuffle=False, verbose=0)

    _, loss = model.evaluate(X_test, Y_test)
    
    return loss

# %%
def run(run_dir, hparams):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        loss = train_test_model(hparams)
        tf.summary.scalar("loss", loss, step=1)
        return loss

# %%
session_num = 0
datos = []

for deep_layers in HP_LAYERS.domain.values:
    for num_units in HP_NUM_UNITS.domain.values:
        for learning_rate in HP_LEARNING.domain.values:
            for batch_size in HP_BATCHSIZE.domain.values:
                t = time.time()
                hparams = {

                    HP_LAYERS: deep_layers,
                    HP_NUM_UNITS: num_units,
                    HP_LEARNING: learning_rate,
                    HP_BATCHSIZE: batch_size,
                }
                run_name = "run-%d" % session_num
                print('\n--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                score = run('logs/hparam_tuning3/' + run_name, hparams)
                t = time.time()-t
                session_num += 1
                print("Loss:", score, "Tiempo transcurrido:", t)
            
            datos.append([deep_layers, num_units, learning_rate, batch_size, score, t])

print(session_num)
# Out:
# --- Starting trial: run-0
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0721 - mean_squared_error: 0.0721
# Loss: 0.07212551683187485 Tiempo transcurrido: 78.68402576446533
#
# --- Starting trial: run-1
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1107 - mean_squared_error: 0.1107
# Loss: 0.11066646873950958 Tiempo transcurrido: 41.7295126914978
#
# --- Starting trial: run-2
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4998 - mean_squared_error: 0.4998
# Loss: 0.49984678626060486 Tiempo transcurrido: 24.287182331085205
#
# --- Starting trial: run-3
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6527 - mean_squared_error: 0.6527
# Loss: 0.652683436870575 Tiempo transcurrido: 15.540129899978638
#
# --- Starting trial: run-4
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0386 - mean_squared_error: 0.0386
# Loss: 0.03857904672622681 Tiempo transcurrido: 96.48856496810913
#
# --- Starting trial: run-5
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0366 - mean_squared_error: 0.0366
# Loss: 0.036550190299749374 Tiempo transcurrido: 56.45351219177246
#
# --- Starting trial: run-6
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0362 - mean_squared_error: 0.0362
# Loss: 0.03624691814184189 Tiempo transcurrido: 23.011370182037354
#
# --- Starting trial: run-7
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0488 - mean_squared_error: 0.0488
# Loss: 0.04879673570394516 Tiempo transcurrido: 15.7549569606781
#
# --- Starting trial: run-8
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0541 - mean_squared_error: 0.0541
# Loss: 0.05405520275235176 Tiempo transcurrido: 97.8530912399292
#
# --- Starting trial: run-9
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0780 - mean_squared_error: 0.0780
# Loss: 0.0779939517378807 Tiempo transcurrido: 49.10921621322632
#
# --- Starting trial: run-10
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1504 - mean_squared_error: 0.1504
# Loss: 0.1503899097442627 Tiempo transcurrido: 28.703277111053467
#
# --- Starting trial: run-11
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6632 - mean_squared_error: 0.6632
# Loss: 0.6632260084152222 Tiempo transcurrido: 17.854442358016968
#
# --- Starting trial: run-12
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0307 - mean_squared_error: 0.0307
# Loss: 0.03067394159734249 Tiempo transcurrido: 79.59300780296326
#
# --- Starting trial: run-13
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0313 - mean_squared_error: 0.0313
# Loss: 0.03130951151251793 Tiempo transcurrido: 40.268564224243164
#
# --- Starting trial: run-14
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0369 - mean_squared_error: 0.0369
# Loss: 0.036921482533216476 Tiempo transcurrido: 23.95343804359436
#
# --- Starting trial: run-15
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0404 - mean_squared_error: 0.0404
# Loss: 0.04037284851074219 Tiempo transcurrido: 14.458308458328247
#
# --- Starting trial: run-16
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0490 - mean_squared_error: 0.0490
# Loss: 0.048950400203466415 Tiempo transcurrido: 88.86067986488342
#
# --- Starting trial: run-17
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0595 - mean_squared_error: 0.0595
# Loss: 0.05946772173047066 Tiempo transcurrido: 48.29806208610535
#
# --- Starting trial: run-18
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1054 - mean_squared_error: 0.1054
# Loss: 0.1053873747587204 Tiempo transcurrido: 26.738584995269775
#
# --- Starting trial: run-19
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3039 - mean_squared_error: 0.3039
# Loss: 0.3039456903934479 Tiempo transcurrido: 16.587430000305176
#
# --- Starting trial: run-20
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0338 - mean_squared_error: 0.0338
# Loss: 0.03378327563405037 Tiempo transcurrido: 86.42607855796814
#
# --- Starting trial: run-21
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0303 - mean_squared_error: 0.0303
# Loss: 0.030289124697446823 Tiempo transcurrido: 57.25353455543518
#
# --- Starting trial: run-22
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0317 - mean_squared_error: 0.0317
# Loss: 0.03165381774306297 Tiempo transcurrido: 26.079777240753174
#
# --- Starting trial: run-23
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0417 - mean_squared_error: 0.0417
# Loss: 0.04171447083353996 Tiempo transcurrido: 21.077508687973022
#
# --- Starting trial: run-24
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0442 - mean_squared_error: 0.0442
# Loss: 0.0441991351544857 Tiempo transcurrido: 86.04293537139893
#
# --- Starting trial: run-25
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0569 - mean_squared_error: 0.0569
# Loss: 0.05688618868589401 Tiempo transcurrido: 52.60281252861023
#
# --- Starting trial: run-26
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1169 - mean_squared_error: 0.1169
# Loss: 0.11694888770580292 Tiempo transcurrido: 39.33336639404297
#
# --- Starting trial: run-27
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1977 - mean_squared_error: 0.1977
# Loss: 0.19766341149806976 Tiempo transcurrido: 21.453212022781372
#
# --- Starting trial: run-28
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0362 - mean_squared_error: 0.0362
# Loss: 0.036158595234155655 Tiempo transcurrido: 110.8752088546753
#
# --- Starting trial: run-29
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0394 - mean_squared_error: 0.0394
# Loss: 0.03940998390316963 Tiempo transcurrido: 39.471877336502075
#
# --- Starting trial: run-30
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0387 - mean_squared_error: 0.0387
# Loss: 0.03874253109097481 Tiempo transcurrido: 26.013757944107056
#
# --- Starting trial: run-31
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0362 - mean_squared_error: 0.0362
# Loss: 0.0361664779484272 Tiempo transcurrido: 16.691831350326538
#
# --- Starting trial: run-32
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0326 - mean_squared_error: 0.0326
# Loss: 0.03261382505297661 Tiempo transcurrido: 141.90365052223206
#
# --- Starting trial: run-33
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0371 - mean_squared_error: 0.0371
# Loss: 0.037094373255968094 Tiempo transcurrido: 83.53283858299255
#
# --- Starting trial: run-34
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0945 - mean_squared_error: 0.0945
# Loss: 0.09448590874671936 Tiempo transcurrido: 41.56967639923096
#
# --- Starting trial: run-35
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0822 - mean_squared_error: 0.0822
# Loss: 0.08224458247423172 Tiempo transcurrido: 17.79561448097229
#
# --- Starting trial: run-36
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0390 - mean_squared_error: 0.0390
# Loss: 0.03900272771716118 Tiempo transcurrido: 148.40622639656067
#
# --- Starting trial: run-37
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0386 - mean_squared_error: 0.0386
# Loss: 0.038632966578006744 Tiempo transcurrido: 57.93295502662659
#
# --- Starting trial: run-38
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0336 - mean_squared_error: 0.0336
# Loss: 0.03356241434812546 Tiempo transcurrido: 41.840627908706665
#
# --- Starting trial: run-39
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0314 - mean_squared_error: 0.0314
# Loss: 0.03144213184714317 Tiempo transcurrido: 23.04468584060669
#
# --- Starting trial: run-40
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0306 - mean_squared_error: 0.0306
# Loss: 0.030559852719306946 Tiempo transcurrido: 114.64366459846497
#
# --- Starting trial: run-41
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0361 - mean_squared_error: 0.0361
# Loss: 0.03609081730246544 Tiempo transcurrido: 73.29237341880798
#
# --- Starting trial: run-42
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0420 - mean_squared_error: 0.0420
# Loss: 0.04198944941163063 Tiempo transcurrido: 34.47288703918457
#
# --- Starting trial: run-43
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0888 - mean_squared_error: 0.0888
# Loss: 0.08876428008079529 Tiempo transcurrido: 18.70680332183838
#
# --- Starting trial: run-44
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0606 - mean_squared_error: 0.0606
# Loss: 0.06064024567604065 Tiempo transcurrido: 104.52319359779358
#
# --- Starting trial: run-45
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0347 - mean_squared_error: 0.0347
# Loss: 0.03470143675804138 Tiempo transcurrido: 51.69290566444397
#
# --- Starting trial: run-46
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0349 - mean_squared_error: 0.0349
# Loss: 0.034910812973976135 Tiempo transcurrido: 29.531396627426147
#
# --- Starting trial: run-47
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0487 - mean_squared_error: 0.0487
# Loss: 0.04868512600660324 Tiempo transcurrido: 20.853781938552856
#
# --- Starting trial: run-48
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0315 - mean_squared_error: 0.0315
# Loss: 0.03147668391466141 Tiempo transcurrido: 137.44228267669678
#
# --- Starting trial: run-49
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0362 - mean_squared_error: 0.0362
# Loss: 0.03621302545070648 Tiempo transcurrido: 70.57902884483337
#
# --- Starting trial: run-50
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0383 - mean_squared_error: 0.0383
# Loss: 0.038319263607263565 Tiempo transcurrido: 36.77545166015625
#
# --- Starting trial: run-51
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0582 - mean_squared_error: 0.0582
# Loss: 0.058155376464128494 Tiempo transcurrido: 21.18000078201294
#
# --- Starting trial: run-52
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0505 - mean_squared_error: 0.0505
# Loss: 0.05050010234117508 Tiempo transcurrido: 121.24310541152954
#
# --- Starting trial: run-53
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0530 - mean_squared_error: 0.0530
# Loss: 0.05304587259888649 Tiempo transcurrido: 69.30222415924072
#
# --- Starting trial: run-54
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0341 - mean_squared_error: 0.0341
# Loss: 0.03412497416138649 Tiempo transcurrido: 36.06308364868164
#
# --- Starting trial: run-55
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0531 - mean_squared_error: 0.0531
# Loss: 0.053096480667591095 Tiempo transcurrido: 22.874772310256958
#
# --- Starting trial: run-56
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0327 - mean_squared_error: 0.0327
# Loss: 0.03266577422618866 Tiempo transcurrido: 125.29130554199219
#
# --- Starting trial: run-57
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0356 - mean_squared_error: 0.0356
# Loss: 0.03556827828288078 Tiempo transcurrido: 57.95241451263428
#
# --- Starting trial: run-58
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0354 - mean_squared_error: 0.0354
# Loss: 0.035392630845308304 Tiempo transcurrido: 33.65755343437195
#
# --- Starting trial: run-59
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0515 - mean_squared_error: 0.0515
# Loss: 0.05148264020681381 Tiempo transcurrido: 22.19591760635376
#
# --- Starting trial: run-60
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0599 - mean_squared_error: 0.0599
# Loss: 0.05987299606204033 Tiempo transcurrido: 96.59132075309753
#
# --- Starting trial: run-61
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0405 - mean_squared_error: 0.0405
# Loss: 0.040549181401729584 Tiempo transcurrido: 46.4988329410553
#
# --- Starting trial: run-62
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0318 - mean_squared_error: 0.0318
# Loss: 0.03175904601812363 Tiempo transcurrido: 26.17475914955139
#
# --- Starting trial: run-63
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0493 - mean_squared_error: 0.0493
# Loss: 0.04931722581386566 Tiempo transcurrido: 15.873072862625122
#
# --- Starting trial: run-64
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Loss: 0.033423006534576416 Tiempo transcurrido: 83.48709511756897
#
# --- Starting trial: run-65
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0401 - mean_squared_error: 0.0401
# Loss: 0.04008065536618233 Tiempo transcurrido: 45.15489077568054
#
# --- Starting trial: run-66
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0374 - mean_squared_error: 0.0374
# Loss: 0.037362635135650635 Tiempo transcurrido: 26.758716344833374
#
# --- Starting trial: run-67
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0483 - mean_squared_error: 0.0483
# Loss: 0.048304859548807144 Tiempo transcurrido: 16.948539972305298
#
# --- Starting trial: run-68
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0663 - mean_squared_error: 0.0663
# Loss: 0.06633416563272476 Tiempo transcurrido: 92.40310001373291
#
# --- Starting trial: run-69
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0426 - mean_squared_error: 0.0426
# Loss: 0.04259442165493965 Tiempo transcurrido: 56.11435317993164
#
# --- Starting trial: run-70
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0361 - mean_squared_error: 0.0361
# Loss: 0.03607102483510971 Tiempo transcurrido: 30.695768356323242
#
# --- Starting trial: run-71
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0471 - mean_squared_error: 0.0471
# Loss: 0.04706370085477829 Tiempo transcurrido: 16.615918397903442
#
# --- Starting trial: run-72
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0312 - mean_squared_error: 0.0312
# Loss: 0.03117602877318859 Tiempo transcurrido: 105.06785941123962
#
# --- Starting trial: run-73
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0310 - mean_squared_error: 0.0310
# Loss: 0.03097103163599968 Tiempo transcurrido: 50.032331228256226
#
# --- Starting trial: run-74
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0362 - mean_squared_error: 0.0362
# Loss: 0.03621623292565346 Tiempo transcurrido: 29.968429565429688
#
# --- Starting trial: run-75
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0375 - mean_squared_error: 0.0375
# Loss: 0.037506211549043655 Tiempo transcurrido: 17.295283794403076
#
# --- Starting trial: run-76
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0752 - mean_squared_error: 0.0752
# Loss: 0.07519103586673737 Tiempo transcurrido: 95.65113973617554
#
# --- Starting trial: run-77
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0296 - mean_squared_error: 0.0296
# Loss: 0.02961898408830166 Tiempo transcurrido: 75.44968032836914
#
# --- Starting trial: run-78
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0410 - mean_squared_error: 0.0410
# Loss: 0.040978580713272095 Tiempo transcurrido: 52.89355754852295
#
# --- Starting trial: run-79
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0874 - mean_squared_error: 0.0874
# Loss: 0.08743377774953842 Tiempo transcurrido: 31.925913095474243
#
# --- Starting trial: run-80
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0327 - mean_squared_error: 0.0327
# Loss: 0.0327182412147522 Tiempo transcurrido: 144.37306261062622
#
# --- Starting trial: run-81
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0317 - mean_squared_error: 0.0317
# Loss: 0.031749043613672256 Tiempo transcurrido: 74.40265679359436
#
# --- Starting trial: run-82
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0439 - mean_squared_error: 0.0439
# Loss: 0.04385484382510185 Tiempo transcurrido: 31.64055347442627
#
# --- Starting trial: run-83
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0381 - mean_squared_error: 0.0381
# Loss: 0.038075003772974014 Tiempo transcurrido: 16.182328939437866
#
# --- Starting trial: run-84
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0810 - mean_squared_error: 0.0810
# Loss: 0.08103100955486298 Tiempo transcurrido: 85.67829823493958
#
# --- Starting trial: run-85
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0359 - mean_squared_error: 0.0359
# Loss: 0.03594047203660011 Tiempo transcurrido: 44.38856363296509
#
# --- Starting trial: run-86
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0447 - mean_squared_error: 0.0447
# Loss: 0.044729482382535934 Tiempo transcurrido: 25.670150995254517
#
# --- Starting trial: run-87
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0453 - mean_squared_error: 0.0453
# Loss: 0.04526554048061371 Tiempo transcurrido: 16.81572914123535
#
# --- Starting trial: run-88
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0349 - mean_squared_error: 0.0349
# Loss: 0.03488871827721596 Tiempo transcurrido: 108.98106217384338
#
# --- Starting trial: run-89
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0307 - mean_squared_error: 0.0307
# Loss: 0.030683059245347977 Tiempo transcurrido: 58.461745262145996
#
# --- Starting trial: run-90
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0452 - mean_squared_error: 0.0452
# Loss: 0.04523583501577377 Tiempo transcurrido: 32.89094257354736
#
# --- Starting trial: run-91
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0394 - mean_squared_error: 0.0394
# Loss: 0.03937191888689995 Tiempo transcurrido: 18.297001600265503
#
# --- Starting trial: run-92
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1064 - mean_squared_error: 0.1064
# Loss: 0.10638529807329178 Tiempo transcurrido: 98.26840686798096
#
# --- Starting trial: run-93
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0422 - mean_squared_error: 0.0422
# Loss: 0.04217454046010971 Tiempo transcurrido: 82.62004542350769
#
# --- Starting trial: run-94
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0327 - mean_squared_error: 0.0327
# Loss: 0.032703738659620285 Tiempo transcurrido: 35.593634843826294
#
# --- Starting trial: run-95
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0343 - mean_squared_error: 0.0343
# Loss: 0.03430866822600365 Tiempo transcurrido: 19.639758825302124
#
# --- Starting trial: run-96
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0297 - mean_squared_error: 0.0297
# Loss: 0.029650216922163963 Tiempo transcurrido: 93.45386362075806
#
# --- Starting trial: run-97
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0322 - mean_squared_error: 0.0322
# Loss: 0.032163627445697784 Tiempo transcurrido: 46.49397373199463
#
# --- Starting trial: run-98
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0352 - mean_squared_error: 0.0352
# Loss: 0.035210102796554565 Tiempo transcurrido: 25.38288950920105
#
# --- Starting trial: run-99
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0364 - mean_squared_error: 0.0364
# Loss: 0.03643258288502693 Tiempo transcurrido: 16.34128999710083
#
# --- Starting trial: run-100
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0726 - mean_squared_error: 0.0726
# Loss: 0.0725930854678154 Tiempo transcurrido: 89.04268264770508
#
# --- Starting trial: run-101
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0440 - mean_squared_error: 0.0440
# Loss: 0.044013578444719315 Tiempo transcurrido: 50.69978070259094
#
# --- Starting trial: run-102
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0400 - mean_squared_error: 0.0400
# Loss: 0.04000474885106087 Tiempo transcurrido: 28.254393339157104
#
# --- Starting trial: run-103
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0751 - mean_squared_error: 0.0751
# Loss: 0.0750630721449852 Tiempo transcurrido: 16.62012243270874
#
# --- Starting trial: run-104
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0362 - mean_squared_error: 0.0362
# Loss: 0.03618538752198219 Tiempo transcurrido: 102.77145886421204
#
# --- Starting trial: run-105
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0333 - mean_squared_error: 0.0333
# Loss: 0.033322934061288834 Tiempo transcurrido: 60.87625694274902
#
# --- Starting trial: run-106
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0475 - mean_squared_error: 0.0475
# Loss: 0.047465965151786804 Tiempo transcurrido: 40.63829684257507
#
# --- Starting trial: run-107
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0367 - mean_squared_error: 0.0367
# Loss: 0.03670807555317879 Tiempo transcurrido: 19.59632396697998
#
# --- Starting trial: run-108
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1174 - mean_squared_error: 0.1174
# Loss: 0.11739957332611084 Tiempo transcurrido: 90.88645672798157
#
# --- Starting trial: run-109
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0318 - mean_squared_error: 0.0318
# Loss: 0.031832076609134674 Tiempo transcurrido: 53.78746700286865
#
# --- Starting trial: run-110
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0337 - mean_squared_error: 0.0337
# Loss: 0.03373432531952858 Tiempo transcurrido: 34.4070987701416
#
# --- Starting trial: run-111
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0381 - mean_squared_error: 0.0381
# Loss: 0.03809976577758789 Tiempo transcurrido: 22.78818655014038
#
# --- Starting trial: run-112
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0342 - mean_squared_error: 0.0342
# Loss: 0.034162770956754684 Tiempo transcurrido: 118.17455863952637
#
# --- Starting trial: run-113
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Loss: 0.03291887417435646 Tiempo transcurrido: 64.6681661605835
#
# --- Starting trial: run-114
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0327 - mean_squared_error: 0.0327
# Loss: 0.03274890407919884 Tiempo transcurrido: 35.55761528015137
#
# --- Starting trial: run-115
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0322 - mean_squared_error: 0.0322
# Loss: 0.03223220258951187 Tiempo transcurrido: 21.347682237625122
#
# --- Starting trial: run-116
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0878 - mean_squared_error: 0.0878
# Loss: 0.08783311396837234 Tiempo transcurrido: 132.51229405403137
#
# --- Starting trial: run-117
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0399 - mean_squared_error: 0.0399
# Loss: 0.03989560902118683 Tiempo transcurrido: 64.78100657463074
#
# --- Starting trial: run-118
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372
# Loss: 0.03717887029051781 Tiempo transcurrido: 39.11027908325195
#
# --- Starting trial: run-119
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0396 - mean_squared_error: 0.0396
# Loss: 0.03956877067685127 Tiempo transcurrido: 23.04418182373047
#
# --- Starting trial: run-120
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0342 - mean_squared_error: 0.0342
# Loss: 0.03421890363097191 Tiempo transcurrido: 127.21613049507141
#
# --- Starting trial: run-121
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0326 - mean_squared_error: 0.0326
# Loss: 0.032638344913721085 Tiempo transcurrido: 67.1750156879425
#
# --- Starting trial: run-122
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0326 - mean_squared_error: 0.0326
# Loss: 0.032632242888212204 Tiempo transcurrido: 38.46376371383667
#
# --- Starting trial: run-123
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0375 - mean_squared_error: 0.0375
# Loss: 0.037539660930633545 Tiempo transcurrido: 24.289318084716797
#
# --- Starting trial: run-124
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0795
# Loss: 0.07947611063718796 Tiempo transcurrido: 146.09634566307068
#
# --- Starting trial: run-125
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0421 - mean_squared_error: 0.0421
# Loss: 0.04212126135826111 Tiempo transcurrido: 76.25984477996826
#
# --- Starting trial: run-126
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0385 - mean_squared_error: 0.0385
# Loss: 0.038466647267341614 Tiempo transcurrido: 43.13245177268982
#
# --- Starting trial: run-127
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0488 - mean_squared_error: 0.0488
# Loss: 0.04880204051733017 Tiempo transcurrido: 27.075721502304077
# 128

# %%
filename = "historial_jla_tunning.txt"
df = pd.DataFrame(datos, columns = ["Deep size", "Num units", "Learning rate", "Batch size", "MSE", "Tiempo de ejecución"])

df.sort_values(by=["MSE", "Tiempo de ejecución"], ascending=[True, True], ignore_index=True, inplace=True)

df.to_csv(filename, header=True, index=False, sep='\t', mode='w') # a=append, w=overwrite

# %%
df.head(2)
# Out:
#    Deep size  Num units  Learning rate  Batch size       MSE  \
# 0          2         50         0.0010          16  0.031442
# 1          4        150         0.0001          16  0.032232
#
#    Tiempo de ejecución
# 0            23.044686
# 1            21.347682

# %%
total_time = float(np.sum(df[["Tiempo de ejecución"]])/60)

print("Elapsed time {:.3f} minutes".format(total_time))
# Out:
# Elapsed time 10.446 minutes

# %%
df["Tiempo de ejecución"]
# Out:
# 0     23.044686
# 1     21.347682
# 2     19.639759
# 3     16.691831
# 4     16.341290
# 5     19.596324
# 6     17.295284
# 7     24.289318
# 8     16.182329
# 9     22.788187
# 10    18.297002
# 11    23.044182
# 12    14.458308
# 13    21.077509
# 14    16.815729
# 15    16.615918
# 16    16.948540
# 17    20.853782
# 18    15.754957
# 19    27.075722
# 20    15.873073
# 21    22.195918
# 22    22.874772
# 23    21.180001
# 24    16.620122
# 25    17.795614
# 26    31.925913
# 27    18.706803
# 28    21.453212
# 29    16.587430
# 30    15.540130
# 31    17.854442
# Name: Tiempo de ejecución, dtype: float64
