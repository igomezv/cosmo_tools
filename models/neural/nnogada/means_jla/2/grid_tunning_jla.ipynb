# %%
# %load_ext tensorboard
# Clear any logs from previous runs
# !rm -rf ./logs/

# %%
import numpy as np
import pandas as pd
import time, os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import to_categorical
from tensorboard.plugins.hparams import api as hp

from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Model

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split as split

import random
from math import floor
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from scipy.integrate import odeint
import scipy
import pandas as pd
np.random.seed(0)
# Out:
# 2022-12-16 10:58:25.285037: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-16 10:58:25.455756: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-16 10:58:25.455792: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-16 10:58:26.520187: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-16 10:58:26.520286: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-16 10:58:26.520298: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
url = 'https://raw.githubusercontent.com/igomezv/nnogada/main/data/jla.csv'
df=pd.read_csv(url)
N = len(df.values)
randomize = np.random.permutation(N)
data = df.values[randomize]
N = len(df.values)
z = data[:,0] 
y = data[:,1:3] ### coge el resto de variables a predecir 
y[:,1] = y[:,1]**2+data[:,2]
np.shape(y)
# Out:
# (740, 2)

# %%
scalerz = StandardScaler()
scalerz.fit(z.reshape(-1,1))
z = scalerz.transform(z.reshape(-1,1))

# %%
### Modificar para incluir phanteon como test
split = 0.8
ntrain = int(split * len(z))
indx = [ntrain]
X_train, X_test = np.split(z, indx)
Y_train, Y_test = np.split(y, indx)
np.shape(X_train), np.shape(X_test), Y_train.shape, Y_test.shape
# Out:
# ((592, 1), (148, 1), (592, 2), (148, 2))

# %%
# loss -> val_loss
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min',
                                   min_delta=0.0,
                                   patience=200,
                                   restore_best_weights=True, verbose=True)
                                   ]

n_cols = 1

# %%
HP_BATCHSIZE = hp.HParam('batch_size', hp.Discrete([2, 4, 8, 16]))
HP_LAYERS =    hp.HParam('layers', hp.Discrete([1, 2, 3, 4]))
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([50, 100, 150, 200]))
HP_LEARNING  = hp.HParam('learning_rate', hp.Discrete([1e-4,1e-3]))
# HP_NUM_UNITS3 = hp.HParam('num_units3', hp.Discrete([50, 100, 150, 200]))
# HP_NUM_UNITS4 = hp.HParam('num_units4', hp.Discrete([2, 5, 10]))
# HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.0, 0.2))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'Adadelta']))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam']))

# %%
epochs=200

# %%
# sess = tf.Session()
# writer = tf.summary.FileWriter("/tmp/tfvgg", sess.graph)
# init = tf.initialize_all_variables()
# sess.run(init)
# with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
#     hp.hparams_config(
#         hparams=[HP_NUM_UNITS1, HP_NUM_UNITS2, HP_NUM_UNITS3, HP_NUM_UNITS4,
#                  HP_OPTIMIZER, HP_BATCHSIZE],
#         metrics=[hp.Metric('loss', display_name="Loss")])

# %%
# METRIC_ACCURACY = 'accuracy'
with tf.summary.create_file_writer('logs/hparam_tuning3').as_default():
# with tf.summary.FileWriter('logs/hparam_tuning', sess.graph):
#     init = tf.initialize_all_variables()
#     sess.run(init)
    hp.hparams_config(
        hparams=[HP_LAYERS,
                 HP_NUM_UNITS,
                 HP_LEARNING, 
                 HP_BATCHSIZE],
        metrics=[hp.Metric('loss', display_name="Loss")])
# Out:
# 2022-12-16 10:58:28.071654: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 10:58:28.071876: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-16 10:58:28.071931: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 10:58:28.071980: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 10:58:28.072024: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-12-16 10:58:28.072069: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-12-16 10:58:28.072130: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 10:58:28.072176: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 10:58:28.072222: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-12-16 10:58:28.072229: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-12-16 10:58:28.072574: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def train_test_model(hparams):    
    
    # Train LSTM model and predict on validation set
    model = tf.keras.Sequential()
    model.add(Dense(int(X_train.shape[1])))
#     model.add(Dense(hparams[HP_NUM_UNITS], input_shape=(int(X_train.shape[1]),)))
    
    for i in range(hparams[HP_LAYERS]):        
        model.add(Dense(hparams[HP_NUM_UNITS], activation='relu'))
    model.add(Dense(2, activation='linear'))
     
    optimizer = tf.keras.optimizers.Adam(learning_rate=hparams[HP_LEARNING], beta_1=0.9, beta_2=0.999, epsilon=1e-3)
    model.compile(
            optimizer=optimizer,
            loss='mse', 
            metrics=['mean_squared_error'])
    
    # Run with 1 epoch to speed things up for demo purposes

    model.fit(X_train, Y_train, epochs=epochs, validation_data=(X_test, Y_test),
              callbacks=callbacks, batch_size=hparams[HP_BATCHSIZE], shuffle=False, verbose=0)

    _, loss = model.evaluate(X_test, Y_test)
    
    return loss

# %%
def run(run_dir, hparams):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        loss = train_test_model(hparams)
        tf.summary.scalar("loss", loss, step=1)
        return loss

# %%
session_num = 0
datos = []

for deep_layers in HP_LAYERS.domain.values:
    for num_units in HP_NUM_UNITS.domain.values:
        for learning_rate in HP_LEARNING.domain.values:
            for batch_size in HP_BATCHSIZE.domain.values:
                t = time.time()
                hparams = {

                    HP_LAYERS: deep_layers,
                    HP_NUM_UNITS: num_units,
                    HP_LEARNING: learning_rate,
                    HP_BATCHSIZE: batch_size,
                }
                run_name = "run-%d" % session_num
                print('\n--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                score = run('logs/hparam_tuning3/' + run_name, hparams)
                t = time.time()-t
                session_num += 1
                print("Loss:", score, "Tiempo transcurrido:", t)
            
            datos.append([deep_layers, num_units, learning_rate, batch_size, score, t])

print(session_num)
# Out:
# --- Starting trial: run-0
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0626 - mean_squared_error: 0.0626
# Loss: 0.0626378282904625 Tiempo transcurrido: 100.73911809921265
#
# --- Starting trial: run-1
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1157 - mean_squared_error: 0.1157
# Loss: 0.11571776121854782 Tiempo transcurrido: 52.81896448135376
#
# --- Starting trial: run-2
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1855 - mean_squared_error: 0.1855
# Loss: 0.18548725545406342 Tiempo transcurrido: 28.00128936767578
#
# --- Starting trial: run-3
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.9441 - mean_squared_error: 0.9441
# Loss: 0.944054901599884 Tiempo transcurrido: 17.556798696517944
#
# --- Starting trial: run-4
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0311 - mean_squared_error: 0.0311
# Loss: 0.031059887260198593 Tiempo transcurrido: 91.89010000228882
#
# --- Starting trial: run-5
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372
# Loss: 0.037169117480516434 Tiempo transcurrido: 82.98585414886475
#
# --- Starting trial: run-6
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0565 - mean_squared_error: 0.0565
# Loss: 0.05649115517735481 Tiempo transcurrido: 32.355578899383545
#
# --- Starting trial: run-7
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0449 - mean_squared_error: 0.0449
# Loss: 0.0449170358479023 Tiempo transcurrido: 20.161534786224365
#
# --- Starting trial: run-8
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0712 - mean_squared_error: 0.0712
# Loss: 0.0712217316031456 Tiempo transcurrido: 100.77811026573181
#
# --- Starting trial: run-9
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0702 - mean_squared_error: 0.0702
# Loss: 0.07021132111549377 Tiempo transcurrido: 83.00873351097107
#
# --- Starting trial: run-10
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1218 - mean_squared_error: 0.1218
# Loss: 0.12177102267742157 Tiempo transcurrido: 29.15226721763611
#
# --- Starting trial: run-11
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6640 - mean_squared_error: 0.6640
# Loss: 0.6640001535415649 Tiempo transcurrido: 17.67266035079956
#
# --- Starting trial: run-12
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0313 - mean_squared_error: 0.0313
# Loss: 0.03132825344800949 Tiempo transcurrido: 142.95509505271912
#
# --- Starting trial: run-13
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0312 - mean_squared_error: 0.0312
# Loss: 0.031157510355114937 Tiempo transcurrido: 55.45771503448486
#
# --- Starting trial: run-14
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0373 - mean_squared_error: 0.0373
# Loss: 0.03727547824382782 Tiempo transcurrido: 33.24917507171631
#
# --- Starting trial: run-15
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0393 - mean_squared_error: 0.0393
# Loss: 0.03932066634297371 Tiempo transcurrido: 18.32096529006958
#
# --- Starting trial: run-16
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0484 - mean_squared_error: 0.0484
# Loss: 0.04842331260442734 Tiempo transcurrido: 142.846040725708
#
# --- Starting trial: run-17
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1516 - mean_squared_error: 0.1516
# Loss: 0.15156607329845428 Tiempo transcurrido: 56.10282516479492
#
# --- Starting trial: run-18
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0941 - mean_squared_error: 0.0941
# Loss: 0.09413065016269684 Tiempo transcurrido: 28.261096000671387
#
# --- Starting trial: run-19
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2417 - mean_squared_error: 0.2417
# Loss: 0.2416778802871704 Tiempo transcurrido: 21.514397382736206
#
# --- Starting trial: run-20
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0311 - mean_squared_error: 0.0311
# Loss: 0.031083161011338234 Tiempo transcurrido: 94.44354772567749
#
# --- Starting trial: run-21
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0368 - mean_squared_error: 0.0368
# Loss: 0.03683235123753548 Tiempo transcurrido: 52.28286409378052
#
# --- Starting trial: run-22
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0367 - mean_squared_error: 0.0367
# Loss: 0.03668491542339325 Tiempo transcurrido: 33.47288751602173
#
# --- Starting trial: run-23
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0418 - mean_squared_error: 0.0418
# Loss: 0.041815854609012604 Tiempo transcurrido: 19.11286425590515
#
# --- Starting trial: run-24
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0448 - mean_squared_error: 0.0448
# Loss: 0.04475647211074829 Tiempo transcurrido: 101.81676387786865
#
# --- Starting trial: run-25
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0579 - mean_squared_error: 0.0579
# Loss: 0.0579102486371994 Tiempo transcurrido: 83.72704648971558
#
# --- Starting trial: run-26
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3704 - mean_squared_error: 0.3704
# Loss: 0.37041303515434265 Tiempo transcurrido: 36.65125274658203
#
# --- Starting trial: run-27
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3861 - mean_squared_error: 0.3861
# Loss: 0.38609910011291504 Tiempo transcurrido: 24.89420175552368
#
# --- Starting trial: run-28
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0341 - mean_squared_error: 0.0341
# Loss: 0.03411755710840225 Tiempo transcurrido: 105.55257678031921
#
# --- Starting trial: run-29
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0298 - mean_squared_error: 0.0298
# Loss: 0.029802542179822922 Tiempo transcurrido: 52.259968757629395
#
# --- Starting trial: run-30
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0380 - mean_squared_error: 0.0380
# Loss: 0.03804748132824898 Tiempo transcurrido: 36.657569885253906
#
# --- Starting trial: run-31
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0361 - mean_squared_error: 0.0361
# Loss: 0.03606678918004036 Tiempo transcurrido: 21.493022203445435
#
# --- Starting trial: run-32
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0331 - mean_squared_error: 0.0331
# Loss: 0.03311280161142349 Tiempo transcurrido: 111.81642723083496
#
# --- Starting trial: run-33
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0372 - mean_squared_error: 0.0372
# Loss: 0.03720268979668617 Tiempo transcurrido: 64.16965508460999
#
# --- Starting trial: run-34
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0526 - mean_squared_error: 0.0526
# Loss: 0.0526273176074028 Tiempo transcurrido: 40.551892042160034
#
# --- Starting trial: run-35
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1238 - mean_squared_error: 0.1238
# Loss: 0.12375010550022125 Tiempo transcurrido: 24.203935146331787
#
# --- Starting trial: run-36
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Loss: 0.03335829824209213 Tiempo transcurrido: 143.58675050735474
#
# --- Starting trial: run-37
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0362 - mean_squared_error: 0.0362
# Loss: 0.03624178096652031 Tiempo transcurrido: 56.09709572792053
#
# --- Starting trial: run-38
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Loss: 0.03338630869984627 Tiempo transcurrido: 36.34924602508545
#
# --- Starting trial: run-39
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0337 - mean_squared_error: 0.0337
# Loss: 0.033669352531433105 Tiempo transcurrido: 23.042749881744385
#
# --- Starting trial: run-40
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0307 - mean_squared_error: 0.0307
# Loss: 0.030710715800523758 Tiempo transcurrido: 115.02740550041199
#
# --- Starting trial: run-41
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0372 - mean_squared_error: 0.0372
# Loss: 0.03718620538711548 Tiempo transcurrido: 83.98604822158813
#
# --- Starting trial: run-42
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0415 - mean_squared_error: 0.0415
# Loss: 0.04145969823002815 Tiempo transcurrido: 42.26014041900635
#
# --- Starting trial: run-43
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0937 - mean_squared_error: 0.0937
# Loss: 0.09372380375862122 Tiempo transcurrido: 22.064104318618774
#
# --- Starting trial: run-44
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0722 - mean_squared_error: 0.0722
# Loss: 0.0721929520368576 Tiempo transcurrido: 115.21553635597229
#
# --- Starting trial: run-45
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0443 - mean_squared_error: 0.0443
# Loss: 0.04432408884167671 Tiempo transcurrido: 83.3327248096466
#
# --- Starting trial: run-46
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0348 - mean_squared_error: 0.0348
# Loss: 0.0348469577729702 Tiempo transcurrido: 27.541805028915405
#
# --- Starting trial: run-47
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0547 - mean_squared_error: 0.0547
# Loss: 0.05471832677721977 Tiempo transcurrido: 16.22747492790222
#
# --- Starting trial: run-48
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0307 - mean_squared_error: 0.0307
# Loss: 0.0306941457092762 Tiempo transcurrido: 80.85076475143433
#
# --- Starting trial: run-49
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0360 - mean_squared_error: 0.0360
# Loss: 0.035986945033073425 Tiempo transcurrido: 41.53501796722412
#
# --- Starting trial: run-50
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0402 - mean_squared_error: 0.0402
# Loss: 0.040218960493803024 Tiempo transcurrido: 25.25200629234314
#
# --- Starting trial: run-51
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0548 - mean_squared_error: 0.0548
# Loss: 0.054808203130960464 Tiempo transcurrido: 16.69494366645813
#
# --- Starting trial: run-52
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0598 - mean_squared_error: 0.0598
# Loss: 0.05984450504183769 Tiempo transcurrido: 76.32978653907776
#
# --- Starting trial: run-53
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0432 - mean_squared_error: 0.0432
# Loss: 0.04316845163702965 Tiempo transcurrido: 44.63000535964966
#
# --- Starting trial: run-54
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0361 - mean_squared_error: 0.0361
# Loss: 0.03609355911612511 Tiempo transcurrido: 27.507249355316162
#
# --- Starting trial: run-55
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0448 - mean_squared_error: 0.0448
# Loss: 0.04483122378587723 Tiempo transcurrido: 17.940388202667236
#
# --- Starting trial: run-56
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0297 - mean_squared_error: 0.0297
# Loss: 0.029683012515306473 Tiempo transcurrido: 86.2122278213501
#
# --- Starting trial: run-57
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0351 - mean_squared_error: 0.0351
# Loss: 0.03512506186962128 Tiempo transcurrido: 38.84357833862305
#
# --- Starting trial: run-58
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0374 - mean_squared_error: 0.0374
# Loss: 0.03736232593655586 Tiempo transcurrido: 20.876946210861206
#
# --- Starting trial: run-59
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0454 - mean_squared_error: 0.0454
# Loss: 0.04542374610900879 Tiempo transcurrido: 13.44869875907898
#
# --- Starting trial: run-60
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0838 - mean_squared_error: 0.0838
# Loss: 0.08377479016780853 Tiempo transcurrido: 61.99929594993591
#
# --- Starting trial: run-61
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0517 - mean_squared_error: 0.0517
# Loss: 0.05168323963880539 Tiempo transcurrido: 33.86197853088379
#
# --- Starting trial: run-62
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0324 - mean_squared_error: 0.0324
# Loss: 0.03238251432776451 Tiempo transcurrido: 20.304824113845825
#
# --- Starting trial: run-63
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0550 - mean_squared_error: 0.0550
# Loss: 0.05504697561264038 Tiempo transcurrido: 13.601906299591064
#
# --- Starting trial: run-64
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0328 - mean_squared_error: 0.0328
# Loss: 0.03278408572077751 Tiempo transcurrido: 57.92959547042847
#
# --- Starting trial: run-65
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0395 - mean_squared_error: 0.0395
# Loss: 0.03948397934436798 Tiempo transcurrido: 31.821208715438843
#
# --- Starting trial: run-66
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0360 - mean_squared_error: 0.0360
# Loss: 0.03600509092211723 Tiempo transcurrido: 19.454575777053833
#
# --- Starting trial: run-67
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0591 - mean_squared_error: 0.0591
# Loss: 0.059079498052597046 Tiempo transcurrido: 12.715001344680786
#
# --- Starting trial: run-68
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0569 - mean_squared_error: 0.0569
# Loss: 0.056916411966085434 Tiempo transcurrido: 58.77960205078125
#
# --- Starting trial: run-69
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0377 - mean_squared_error: 0.0377
# Loss: 0.03771103546023369 Tiempo transcurrido: 32.05831789970398
#
# --- Starting trial: run-70
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0364 - mean_squared_error: 0.0364
# Loss: 0.03636746481060982 Tiempo transcurrido: 19.99521040916443
#
# --- Starting trial: run-71
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0513 - mean_squared_error: 0.0513
# Loss: 0.0512508898973465 Tiempo transcurrido: 12.674034595489502
#
# --- Starting trial: run-72
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0314 - mean_squared_error: 0.0314
# Loss: 0.03142610937356949 Tiempo transcurrido: 60.50180244445801
#
# --- Starting trial: run-73
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0344 - mean_squared_error: 0.0344
# Loss: 0.03439531475305557 Tiempo transcurrido: 33.24866771697998
#
# --- Starting trial: run-74
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0367 - mean_squared_error: 0.0367
# Loss: 0.036724675446748734 Tiempo transcurrido: 20.261962413787842
#
# --- Starting trial: run-75
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0407 - mean_squared_error: 0.0407
# Loss: 0.04068268463015556 Tiempo transcurrido: 13.261669397354126
#
# --- Starting trial: run-76
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0736 - mean_squared_error: 0.0736
# Loss: 0.07356046885251999 Tiempo transcurrido: 61.77134418487549
#
# --- Starting trial: run-77
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0630 - mean_squared_error: 0.0630
# Loss: 0.06298264116048813 Tiempo transcurrido: 33.68432974815369
#
# --- Starting trial: run-78
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0396 - mean_squared_error: 0.0396
# Loss: 0.03961941599845886 Tiempo transcurrido: 20.242833614349365
#
# --- Starting trial: run-79
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0390 - mean_squared_error: 0.0390
# Loss: 0.039047300815582275 Tiempo transcurrido: 13.206993341445923
#
# --- Starting trial: run-80
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0333 - mean_squared_error: 0.0333
# Loss: 0.03331558778882027 Tiempo transcurrido: 64.58204102516174
#
# --- Starting trial: run-81
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0305 - mean_squared_error: 0.0305
# Loss: 0.030489563941955566 Tiempo transcurrido: 35.7402880191803
#
# --- Starting trial: run-82
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0451 - mean_squared_error: 0.0451
# Loss: 0.04507235065102577 Tiempo transcurrido: 21.468097925186157
#
# --- Starting trial: run-83
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0381 - mean_squared_error: 0.0381
# Loss: 0.03806966170668602 Tiempo transcurrido: 14.407192945480347
#
# --- Starting trial: run-84
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.1182 - mean_squared_error: 0.1182
# Loss: 0.1181533932685852 Tiempo transcurrido: 66.24252963066101
#
# --- Starting trial: run-85
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0325 - mean_squared_error: 0.0325
# Loss: 0.032479383051395416 Tiempo transcurrido: 36.65264415740967
#
# --- Starting trial: run-86
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0441 - mean_squared_error: 0.0441
# Loss: 0.04410025104880333 Tiempo transcurrido: 21.886409997940063
#
# --- Starting trial: run-87
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0476 - mean_squared_error: 0.0476
# Loss: 0.04758445546030998 Tiempo transcurrido: 14.322024583816528
#
# --- Starting trial: run-88
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0364 - mean_squared_error: 0.0364
# Loss: 0.036405663937330246 Tiempo transcurrido: 74.72950196266174
#
# --- Starting trial: run-89
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0305 - mean_squared_error: 0.0305
# Loss: 0.030523648485541344 Tiempo transcurrido: 41.413280725479126
#
# --- Starting trial: run-90
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0443 - mean_squared_error: 0.0443
# Loss: 0.04434683173894882 Tiempo transcurrido: 24.654456615447998
#
# --- Starting trial: run-91
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0387 - mean_squared_error: 0.0387
# Loss: 0.03873399272561073 Tiempo transcurrido: 15.622891902923584
#
# --- Starting trial: run-92
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0736 - mean_squared_error: 0.0736
# Loss: 0.07357790321111679 Tiempo transcurrido: 70.82695603370667
#
# --- Starting trial: run-93
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0324 - mean_squared_error: 0.0324
# Loss: 0.03239349275827408 Tiempo transcurrido: 37.56405830383301
#
# --- Starting trial: run-94
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0335 - mean_squared_error: 0.0335
# Loss: 0.033487483859062195 Tiempo transcurrido: 22.547380447387695
#
# --- Starting trial: run-95
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0412 - mean_squared_error: 0.0412
# Loss: 0.04124600067734718 Tiempo transcurrido: 14.403990507125854
#
# --- Starting trial: run-96
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0304 - mean_squared_error: 0.0304
# Loss: 0.030388806015253067 Tiempo transcurrido: 61.15305709838867
#
# --- Starting trial: run-97
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0318 - mean_squared_error: 0.0318
# Loss: 0.031822387129068375 Tiempo transcurrido: 33.45351696014404
#
# --- Starting trial: run-98
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0412 - mean_squared_error: 0.0412
# Loss: 0.04117889702320099 Tiempo transcurrido: 20.245667457580566
#
# --- Starting trial: run-99
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0454 - mean_squared_error: 0.0454
# Loss: 0.04536883160471916 Tiempo transcurrido: 13.06070327758789
#
# --- Starting trial: run-100
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0687 - mean_squared_error: 0.0687
# Loss: 0.06872791051864624 Tiempo transcurrido: 61.911640882492065
#
# --- Starting trial: run-101
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0530 - mean_squared_error: 0.0530
# Loss: 0.05298999324440956 Tiempo transcurrido: 33.797683238983154
#
# --- Starting trial: run-102
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0398 - mean_squared_error: 0.0398
# Loss: 0.03980475291609764 Tiempo transcurrido: 20.39575982093811
#
# --- Starting trial: run-103
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 966us/step - loss: 0.0363 - mean_squared_error: 0.0363
# Loss: 0.0362592414021492 Tiempo transcurrido: 13.890555620193481
#
# --- Starting trial: run-104
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0343 - mean_squared_error: 0.0343
# Loss: 0.034319400787353516 Tiempo transcurrido: 64.32258796691895
#
# --- Starting trial: run-105
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0349 - mean_squared_error: 0.0349
# Loss: 0.03490792214870453 Tiempo transcurrido: 35.20956039428711
#
# --- Starting trial: run-106
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0392 - mean_squared_error: 0.0392
# Loss: 0.03918880224227905 Tiempo transcurrido: 21.307053565979004
#
# --- Starting trial: run-107
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0390 - mean_squared_error: 0.0390
# Loss: 0.039010871201753616 Tiempo transcurrido: 13.899126052856445
#
# --- Starting trial: run-108
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0981 - mean_squared_error: 0.0981
# Loss: 0.09814263880252838 Tiempo transcurrido: 65.58764481544495
#
# --- Starting trial: run-109
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0368 - mean_squared_error: 0.0368
# Loss: 0.036788541823625565 Tiempo transcurrido: 36.44186544418335
#
# --- Starting trial: run-110
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0397 - mean_squared_error: 0.0397
# Loss: 0.03969702869653702 Tiempo transcurrido: 21.671783924102783
#
# --- Starting trial: run-111
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Loss: 0.03340142220258713 Tiempo transcurrido: 14.066661596298218
#
# --- Starting trial: run-112
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0345 - mean_squared_error: 0.0345
# Loss: 0.03450331464409828 Tiempo transcurrido: 70.39772343635559
#
# --- Starting trial: run-113
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Loss: 0.0328504778444767 Tiempo transcurrido: 38.55506110191345
#
# --- Starting trial: run-114
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0314 - mean_squared_error: 0.0314
# Loss: 0.031385816633701324 Tiempo transcurrido: 23.320560693740845
#
# --- Starting trial: run-115
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0325 - mean_squared_error: 0.0325
# Loss: 0.03253771737217903 Tiempo transcurrido: 15.633504867553711
#
# --- Starting trial: run-116
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0779 - mean_squared_error: 0.0779
# Loss: 0.07788555324077606 Tiempo transcurrido: 72.6360113620758
#
# --- Starting trial: run-117
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0515 - mean_squared_error: 0.0515
# Loss: 0.05150139704346657 Tiempo transcurrido: 39.97171711921692
#
# --- Starting trial: run-118
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0413 - mean_squared_error: 0.0413
# Loss: 0.04134924337267876 Tiempo transcurrido: 24.47513484954834
#
# --- Starting trial: run-119
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0566 - mean_squared_error: 0.0566
# Loss: 0.05664164200425148 Tiempo transcurrido: 15.724212169647217
#
# --- Starting trial: run-120
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0405 - mean_squared_error: 0.0405
# Loss: 0.04049968346953392 Tiempo transcurrido: 88.20311164855957
#
# --- Starting trial: run-121
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0316 - mean_squared_error: 0.0316
# Loss: 0.0316370353102684 Tiempo transcurrido: 48.95426845550537
#
# --- Starting trial: run-122
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0340 - mean_squared_error: 0.0340
# Loss: 0.03399764001369476 Tiempo transcurrido: 28.231743097305298
#
# --- Starting trial: run-123
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0348 - mean_squared_error: 0.0348
# Loss: 0.03482115641236305 Tiempo transcurrido: 18.078668355941772
#
# --- Starting trial: run-124
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0697 - mean_squared_error: 0.0697
# Loss: 0.06965754181146622 Tiempo transcurrido: 72.36147856712341
#
# --- Starting trial: run-125
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0410 - mean_squared_error: 0.0410
# Loss: 0.04098201543092728 Tiempo transcurrido: 36.338478565216064
#
# --- Starting trial: run-126
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0405 - mean_squared_error: 0.0405
# Loss: 0.04048624262213707 Tiempo transcurrido: 21.701865434646606
#
# --- Starting trial: run-127
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0692 - mean_squared_error: 0.0692
# Loss: 0.06924372911453247 Tiempo transcurrido: 13.430502653121948
# 128

# %%
filename = "historial_jla_tunning.txt"
df = pd.DataFrame(datos, columns = ["Deep size", "Num units", "Learning rate", "Batch size", "MSE", "Tiempo de ejecución"])

df.sort_values(by=["MSE", "Tiempo de ejecución"], ascending=[True, True], ignore_index=True, inplace=True)

df.to_csv(filename, header=True, index=False, sep='\t', mode='w') # a=append, w=overwrite

# %%
df.head(2)
# Out:
#    Deep size  Num units  Learning rate  Batch size       MSE  \
# 0          4        150         0.0001          16  0.032538
# 1          4        100         0.0010          16  0.033401
#
#    Tiempo de ejecución
# 0            15.633505
# 1            14.066662

# %%
total_time = float(np.sum(df[["Tiempo de ejecución"]])/60)

print("Elapsed time {:.3f} minutes".format(total_time))
# Out:
# Elapsed time 8.939 minutes

# %%
df["Tiempo de ejecución"]
# Out:
# 0     15.633505
# 1     14.066662
# 2     23.042750
# 3     18.078668
# 4     21.493022
# 5     13.890556
# 6     14.407193
# 7     15.622892
# 8     13.899126
# 9     13.206993
# 10    18.320965
# 11    13.261669
# 12    14.403991
# 13    19.112864
# 14    17.940388
# 15    20.161535
# 16    13.060703
# 17    13.448699
# 18    14.322025
# 19    12.674035
# 20    16.227475
# 21    16.694944
# 22    13.601906
# 23    15.724212
# 24    12.715001
# 25    13.430503
# 26    22.064104
# 27    24.203935
# 28    21.514397
# 29    24.894202
# 30    17.672660
# 31    17.556799
# Name: Tiempo de ejecución, dtype: float64
