# %%
# %load_ext tensorboard
# Clear any logs from previous runs
# !rm -rf ./logs/

# %%
import numpy as np
import pandas as pd
import time, os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import to_categorical
from tensorboard.plugins.hparams import api as hp

from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Model

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split as split

import random
from math import floor
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from scipy.integrate import odeint
import scipy
import pandas as pd
np.random.seed(0)
# Out:
# 2022-12-16 18:54:51.041939: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-16 18:54:51.183578: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-16 18:54:51.183600: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-16 18:54:52.140020: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-16 18:54:52.140090: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-16 18:54:52.140100: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
url = 'https://raw.githubusercontent.com/igomezv/nnogada/main/data/jla.csv'
df=pd.read_csv(url)
N = len(df.values)
randomize = np.random.permutation(N)
data = df.values[randomize]
N = len(df.values)
z = data[:,0] 
y = data[:,1:3] ### coge el resto de variables a predecir 
y[:,1] = y[:,1]**2+data[:,2]
np.shape(y)
# Out:
# (740, 2)

# %%
scalerz = StandardScaler()
scalerz.fit(z.reshape(-1,1))
z = scalerz.transform(z.reshape(-1,1))

# %%
### Modificar para incluir phanteon como test
split = 0.8
ntrain = int(split * len(z))
indx = [ntrain]
X_train, X_test = np.split(z, indx)
Y_train, Y_test = np.split(y, indx)
np.shape(X_train), np.shape(X_test), Y_train.shape, Y_test.shape
# Out:
# ((592, 1), (148, 1), (592, 2), (148, 2))

# %%
# loss -> val_loss
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min',
                                   min_delta=0.0,
                                   patience=200,
                                   restore_best_weights=True, verbose=True)
                                   ]

n_cols = 1

# %%
HP_BATCHSIZE = hp.HParam('batch_size', hp.Discrete([2, 4, 8, 16]))
HP_LAYERS =    hp.HParam('layers', hp.Discrete([1, 2, 3, 4]))
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([50, 100, 150, 200]))
HP_LEARNING  = hp.HParam('learning_rate', hp.Discrete([1e-4,1e-3]))
# HP_NUM_UNITS3 = hp.HParam('num_units3', hp.Discrete([50, 100, 150, 200]))
# HP_NUM_UNITS4 = hp.HParam('num_units4', hp.Discrete([2, 5, 10]))
# HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.0, 0.2))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'Adadelta']))
# HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam']))

# %%
epochs=200

# %%
# sess = tf.Session()
# writer = tf.summary.FileWriter("/tmp/tfvgg", sess.graph)
# init = tf.initialize_all_variables()
# sess.run(init)
# with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
#     hp.hparams_config(
#         hparams=[HP_NUM_UNITS1, HP_NUM_UNITS2, HP_NUM_UNITS3, HP_NUM_UNITS4,
#                  HP_OPTIMIZER, HP_BATCHSIZE],
#         metrics=[hp.Metric('loss', display_name="Loss")])

# %%
# METRIC_ACCURACY = 'accuracy'
with tf.summary.create_file_writer('logs/hparam_tuning3').as_default():
# with tf.summary.FileWriter('logs/hparam_tuning', sess.graph):
#     init = tf.initialize_all_variables()
#     sess.run(init)
    hp.hparams_config(
        hparams=[HP_LAYERS,
                 HP_NUM_UNITS,
                 HP_LEARNING, 
                 HP_BATCHSIZE],
        metrics=[hp.Metric('loss', display_name="Loss")])
# Out:
# 2022-12-16 18:54:53.683330: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 18:54:53.683594: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-16 18:54:53.683659: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 18:54:53.683711: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 18:54:53.683762: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-12-16 18:54:53.683823: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-12-16 18:54:53.683879: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 18:54:53.683943: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-12-16 18:54:53.684010: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-12-16 18:54:53.684027: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-12-16 18:54:53.684291: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def train_test_model(hparams):    
    
    # Train LSTM model and predict on validation set
    model = tf.keras.Sequential()
    model.add(Dense(int(X_train.shape[1])))
#     model.add(Dense(hparams[HP_NUM_UNITS], input_shape=(int(X_train.shape[1]),)))
    
    for i in range(hparams[HP_LAYERS]):        
        model.add(Dense(hparams[HP_NUM_UNITS], activation='relu'))
    model.add(Dense(2, activation='linear'))
     
    optimizer = tf.keras.optimizers.Adam(learning_rate=hparams[HP_LEARNING], beta_1=0.9, beta_2=0.999, epsilon=1e-3)
    model.compile(
            optimizer=optimizer,
            loss='mse', 
            metrics=['mean_squared_error'])
    
    # Run with 1 epoch to speed things up for demo purposes

    model.fit(X_train, Y_train, epochs=epochs, validation_data=(X_test, Y_test),
              callbacks=callbacks, batch_size=hparams[HP_BATCHSIZE], shuffle=False, verbose=0)

    _, loss = model.evaluate(X_test, Y_test)
    
    return loss

# %%
def run(run_dir, hparams):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        loss = train_test_model(hparams)
        tf.summary.scalar("loss", loss, step=1)
        return loss

# %%
session_num = 0
datos = []

for deep_layers in HP_LAYERS.domain.values:
    for num_units in HP_NUM_UNITS.domain.values:
        for learning_rate in HP_LEARNING.domain.values:
            for batch_size in HP_BATCHSIZE.domain.values:
                t = time.time()
                hparams = {

                    HP_LAYERS: deep_layers,
                    HP_NUM_UNITS: num_units,
                    HP_LEARNING: learning_rate,
                    HP_BATCHSIZE: batch_size,
                }
                run_name = "run-%d" % session_num
                print('\n--- Starting trial: %s' % run_name)
                print({h.name: hparams[h] for h in hparams})
                score = run('logs/hparam_tuning3/' + run_name, hparams)
                t = time.time()-t
                session_num += 1
                print("Loss:", score, "Tiempo transcurrido:", t)
            
            datos.append([deep_layers, num_units, learning_rate, batch_size, score, t])

print(session_num)
# Out:
# --- Starting trial: run-0
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1755 - mean_squared_error: 0.1755
# Loss: 0.1754550188779831 Tiempo transcurrido: 106.4606511592865
#
# --- Starting trial: run-1
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0841 - mean_squared_error: 0.0841
# Loss: 0.0841488465666771 Tiempo transcurrido: 56.67837905883789
#
# --- Starting trial: run-2
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1985 - mean_squared_error: 0.1985
# Loss: 0.19854989647865295 Tiempo transcurrido: 42.11374497413635
#
# --- Starting trial: run-3
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 10.6140 - mean_squared_error: 10.6140
# Loss: 10.614033699035645 Tiempo transcurrido: 22.2125244140625
#
# --- Starting trial: run-4
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0301 - mean_squared_error: 0.0301
# Loss: 0.030130788683891296 Tiempo transcurrido: 98.05307078361511
#
# --- Starting trial: run-5
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0359 - mean_squared_error: 0.0359
# Loss: 0.03585197031497955 Tiempo transcurrido: 59.16891837120056
#
# --- Starting trial: run-6
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0427 - mean_squared_error: 0.0427
# Loss: 0.04266368970274925 Tiempo transcurrido: 34.30242323875427
#
# --- Starting trial: run-7
# {'layers': 1, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0512 - mean_squared_error: 0.0512
# Loss: 0.05117252469062805 Tiempo transcurrido: 21.21615171432495
#
# --- Starting trial: run-8
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0534 - mean_squared_error: 0.0534
# Loss: 0.05344325676560402 Tiempo transcurrido: 143.44766545295715
#
# --- Starting trial: run-9
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0694 - mean_squared_error: 0.0694
# Loss: 0.06944473832845688 Tiempo transcurrido: 82.93980002403259
#
# --- Starting trial: run-10
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5538 - mean_squared_error: 0.5538
# Loss: 0.5538329482078552 Tiempo transcurrido: 33.082046031951904
#
# --- Starting trial: run-11
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8887 - mean_squared_error: 0.8887
# Loss: 0.8887252807617188 Tiempo transcurrido: 23.506102323532104
#
# --- Starting trial: run-12
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0333 - mean_squared_error: 0.0333
# Loss: 0.03333520516753197 Tiempo transcurrido: 119.5740098953247
#
# --- Starting trial: run-13
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0305 - mean_squared_error: 0.0305
# Loss: 0.03053515963256359 Tiempo transcurrido: 52.12729334831238
#
# --- Starting trial: run-14
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0430 - mean_squared_error: 0.0430
# Loss: 0.04304454103112221 Tiempo transcurrido: 32.42776536941528
#
# --- Starting trial: run-15
# {'layers': 1, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0394 - mean_squared_error: 0.0394
# Loss: 0.039350125938653946 Tiempo transcurrido: 19.507200241088867
#
# --- Starting trial: run-16
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0493 - mean_squared_error: 0.0493
# Loss: 0.04928308725357056 Tiempo transcurrido: 106.03958940505981
#
# --- Starting trial: run-17
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0846 - mean_squared_error: 0.0846
# Loss: 0.08459470421075821 Tiempo transcurrido: 57.4754843711853
#
# --- Starting trial: run-18
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5243 - mean_squared_error: 0.5243
# Loss: 0.5242677927017212 Tiempo transcurrido: 42.12591576576233
#
# --- Starting trial: run-19
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2821 - mean_squared_error: 0.2821
# Loss: 0.2820647656917572 Tiempo transcurrido: 22.291658878326416
#
# --- Starting trial: run-20
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0349 - mean_squared_error: 0.0349
# Loss: 0.03492984548211098 Tiempo transcurrido: 110.06639289855957
#
# --- Starting trial: run-21
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0301 - mean_squared_error: 0.0301
# Loss: 0.030085489153862 Tiempo transcurrido: 52.80543327331543
#
# --- Starting trial: run-22
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0393 - mean_squared_error: 0.0393
# Loss: 0.03929661586880684 Tiempo transcurrido: 34.92423343658447
#
# --- Starting trial: run-23
# {'layers': 1, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0411 - mean_squared_error: 0.0411
# Loss: 0.041144318878650665 Tiempo transcurrido: 21.63630175590515
#
# --- Starting trial: run-24
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0467 - mean_squared_error: 0.0467
# Loss: 0.04671090468764305 Tiempo transcurrido: 112.43136978149414
#
# --- Starting trial: run-25
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0565 - mean_squared_error: 0.0565
# Loss: 0.0564967542886734 Tiempo transcurrido: 59.639976978302
#
# --- Starting trial: run-26
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3213 - mean_squared_error: 0.3213
# Loss: 0.32127198576927185 Tiempo transcurrido: 33.17362856864929
#
# --- Starting trial: run-27
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2067 - mean_squared_error: 0.2067
# Loss: 0.2067335695028305 Tiempo transcurrido: 19.668461322784424
#
# --- Starting trial: run-28
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0337 - mean_squared_error: 0.0337
# Loss: 0.03366239741444588 Tiempo transcurrido: 102.21312594413757
#
# --- Starting trial: run-29
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0308 - mean_squared_error: 0.0308
# Loss: 0.03076963871717453 Tiempo transcurrido: 60.371113538742065
#
# --- Starting trial: run-30
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0366 - mean_squared_error: 0.0366
# Loss: 0.036590494215488434 Tiempo transcurrido: 37.99648904800415
#
# --- Starting trial: run-31
# {'layers': 1, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0362 - mean_squared_error: 0.0362
# Loss: 0.036168280988931656 Tiempo transcurrido: 22.394182920455933
#
# --- Starting trial: run-32
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0441 - mean_squared_error: 0.0441
# Loss: 0.044145938009023666 Tiempo transcurrido: 114.76960730552673
#
# --- Starting trial: run-33
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0409 - mean_squared_error: 0.0409
# Loss: 0.04087039455771446 Tiempo transcurrido: 60.33231735229492
#
# --- Starting trial: run-34
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0504 - mean_squared_error: 0.0504
# Loss: 0.05038710683584213 Tiempo transcurrido: 36.94136667251587
#
# --- Starting trial: run-35
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1317 - mean_squared_error: 0.1317
# Loss: 0.13174909353256226 Tiempo transcurrido: 23.821011543273926
#
# --- Starting trial: run-36
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Loss: 0.03341228887438774 Tiempo transcurrido: 105.89402198791504
#
# --- Starting trial: run-37
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0321 - mean_squared_error: 0.0321
# Loss: 0.032122839242219925 Tiempo transcurrido: 53.97910475730896
#
# --- Starting trial: run-38
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0335 - mean_squared_error: 0.0335
# Loss: 0.03348088264465332 Tiempo transcurrido: 42.34564781188965
#
# --- Starting trial: run-39
# {'layers': 2, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0437 - mean_squared_error: 0.0437
# Loss: 0.04374414682388306 Tiempo transcurrido: 21.433480739593506
#
# --- Starting trial: run-40
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0313 - mean_squared_error: 0.0313
# Loss: 0.03125131502747536 Tiempo transcurrido: 119.00563454627991
#
# --- Starting trial: run-41
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0358 - mean_squared_error: 0.0358
# Loss: 0.03583930432796478 Tiempo transcurrido: 60.2639274597168
#
# --- Starting trial: run-42
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0454 - mean_squared_error: 0.0454
# Loss: 0.04536475986242294 Tiempo transcurrido: 28.26729464530945
#
# --- Starting trial: run-43
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0596 - mean_squared_error: 0.0596
# Loss: 0.059623833745718 Tiempo transcurrido: 18.681626319885254
#
# --- Starting trial: run-44
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0581 - mean_squared_error: 0.0581
# Loss: 0.05807043984532356 Tiempo transcurrido: 101.42431592941284
#
# --- Starting trial: run-45
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0376 - mean_squared_error: 0.0376
# Loss: 0.03763390704989433 Tiempo transcurrido: 53.38623070716858
#
# --- Starting trial: run-46
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0353 - mean_squared_error: 0.0353
# Loss: 0.03534198924899101 Tiempo transcurrido: 31.260461568832397
#
# --- Starting trial: run-47
# {'layers': 2, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0386 - mean_squared_error: 0.0386
# Loss: 0.03864779323339462 Tiempo transcurrido: 19.257323026657104
#
# --- Starting trial: run-48
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0301 - mean_squared_error: 0.0301
# Loss: 0.030121829360723495 Tiempo transcurrido: 104.23205995559692
#
# --- Starting trial: run-49
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0368 - mean_squared_error: 0.0368
# Loss: 0.03684870898723602 Tiempo transcurrido: 53.43658924102783
#
# --- Starting trial: run-50
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0389 - mean_squared_error: 0.0389
# Loss: 0.03887593746185303 Tiempo transcurrido: 24.40769124031067
#
# --- Starting trial: run-51
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0568 - mean_squared_error: 0.0568
# Loss: 0.05681198835372925 Tiempo transcurrido: 14.400748252868652
#
# --- Starting trial: run-52
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0564 - mean_squared_error: 0.0564
# Loss: 0.05642622709274292 Tiempo transcurrido: 65.65464973449707
#
# --- Starting trial: run-53
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0407 - mean_squared_error: 0.0407
# Loss: 0.040677331387996674 Tiempo transcurrido: 37.40058159828186
#
# --- Starting trial: run-54
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Loss: 0.03291840851306915 Tiempo transcurrido: 22.151761054992676
#
# --- Starting trial: run-55
# {'layers': 2, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0422 - mean_squared_error: 0.0422
# Loss: 0.04215047508478165 Tiempo transcurrido: 14.709436655044556
#
# --- Starting trial: run-56
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0326 - mean_squared_error: 0.0326
# Loss: 0.032550085335969925 Tiempo transcurrido: 71.05871081352234
#
# --- Starting trial: run-57
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0355 - mean_squared_error: 0.0355
# Loss: 0.03551582619547844 Tiempo transcurrido: 39.65039038658142
#
# --- Starting trial: run-58
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0363 - mean_squared_error: 0.0363
# Loss: 0.03628793731331825 Tiempo transcurrido: 21.017272233963013
#
# --- Starting trial: run-59
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0508 - mean_squared_error: 0.0508
# Loss: 0.05075492709875107 Tiempo transcurrido: 13.570510149002075
#
# --- Starting trial: run-60
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0921 - mean_squared_error: 0.0921
# Loss: 0.0921386107802391 Tiempo transcurrido: 62.56034231185913
#
# --- Starting trial: run-61
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0487 - mean_squared_error: 0.0487
# Loss: 0.048652201890945435 Tiempo transcurrido: 34.337318658828735
#
# --- Starting trial: run-62
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0318 - mean_squared_error: 0.0318
# Loss: 0.03182791545987129 Tiempo transcurrido: 20.489304304122925
#
# --- Starting trial: run-63
# {'layers': 2, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0506 - mean_squared_error: 0.0506
# Loss: 0.05060180276632309 Tiempo transcurrido: 13.837913513183594
#
# --- Starting trial: run-64
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0314 - mean_squared_error: 0.0314
# Loss: 0.031351152807474136 Tiempo transcurrido: 58.94223713874817
#
# --- Starting trial: run-65
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0386 - mean_squared_error: 0.0386
# Loss: 0.03862576186656952 Tiempo transcurrido: 31.919742345809937
#
# --- Starting trial: run-66
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0352 - mean_squared_error: 0.0352
# Loss: 0.035213492810726166 Tiempo transcurrido: 19.209480047225952
#
# --- Starting trial: run-67
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0660 - mean_squared_error: 0.0660
# Loss: 0.06603223085403442 Tiempo transcurrido: 12.602003812789917
#
# --- Starting trial: run-68
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0741 - mean_squared_error: 0.0741
# Loss: 0.07411263883113861 Tiempo transcurrido: 57.97813701629639
#
# --- Starting trial: run-69
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0578 - mean_squared_error: 0.0578
# Loss: 0.05781888961791992 Tiempo transcurrido: 31.59846043586731
#
# --- Starting trial: run-70
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0397 - mean_squared_error: 0.0397
# Loss: 0.03968144208192825 Tiempo transcurrido: 19.469770669937134
#
# --- Starting trial: run-71
# {'layers': 3, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0416 - mean_squared_error: 0.0416
# Loss: 0.04157034680247307 Tiempo transcurrido: 12.571565866470337
#
# --- Starting trial: run-72
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0324 - mean_squared_error: 0.0324
# Loss: 0.03241076320409775 Tiempo transcurrido: 60.70697784423828
#
# --- Starting trial: run-73
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0325 - mean_squared_error: 0.0325
# Loss: 0.03252508118748665 Tiempo transcurrido: 33.043176889419556
#
# --- Starting trial: run-74
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0398 - mean_squared_error: 0.0398
# Loss: 0.03976095840334892 Tiempo transcurrido: 19.876479864120483
#
# --- Starting trial: run-75
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0442 - mean_squared_error: 0.0442
# Loss: 0.04416947811841965 Tiempo transcurrido: 13.217486381530762
#
# --- Starting trial: run-76
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0849 - mean_squared_error: 0.0849
# Loss: 0.08493679761886597 Tiempo transcurrido: 60.918474435806274
#
# --- Starting trial: run-77
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0445 - mean_squared_error: 0.0445
# Loss: 0.04451487585902214 Tiempo transcurrido: 33.11279845237732
#
# --- Starting trial: run-78
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0468 - mean_squared_error: 0.0468
# Loss: 0.04681915044784546 Tiempo transcurrido: 19.897886037826538
#
# --- Starting trial: run-79
# {'layers': 3, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0684 - mean_squared_error: 0.0684
# Loss: 0.06844467669725418 Tiempo transcurrido: 13.1035635471344
#
# --- Starting trial: run-80
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0346 - mean_squared_error: 0.0346
# Loss: 0.03458927199244499 Tiempo transcurrido: 64.40748000144958
#
# --- Starting trial: run-81
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0303 - mean_squared_error: 0.0303
# Loss: 0.030263883993029594 Tiempo transcurrido: 35.32669186592102
#
# --- Starting trial: run-82
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0407 - mean_squared_error: 0.0407
# Loss: 0.04069021716713905 Tiempo transcurrido: 21.15848731994629
#
# --- Starting trial: run-83
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0405 - mean_squared_error: 0.0405
# Loss: 0.040451932698488235 Tiempo transcurrido: 14.471086502075195
#
# --- Starting trial: run-84
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0996 - mean_squared_error: 0.0996
# Loss: 0.09961211681365967 Tiempo transcurrido: 64.01585721969604
#
# --- Starting trial: run-85
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0359 - mean_squared_error: 0.0359
# Loss: 0.03587021306157112 Tiempo transcurrido: 35.21088886260986
#
# --- Starting trial: run-86
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0487 - mean_squared_error: 0.0487
# Loss: 0.04865726828575134 Tiempo transcurrido: 21.245904445648193
#
# --- Starting trial: run-87
# {'layers': 3, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0474 - mean_squared_error: 0.0474
# Loss: 0.04738221317529678 Tiempo transcurrido: 13.712613105773926
#
# --- Starting trial: run-88
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0352 - mean_squared_error: 0.0352
# Loss: 0.03521289676427841 Tiempo transcurrido: 77.30078840255737
#
# --- Starting trial: run-89
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0346 - mean_squared_error: 0.0346
# Loss: 0.034617919474840164 Tiempo transcurrido: 46.766050577163696
#
# --- Starting trial: run-90
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0438 - mean_squared_error: 0.0438
# Loss: 0.04377392679452896 Tiempo transcurrido: 27.548019647598267
#
# --- Starting trial: run-91
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0370 - mean_squared_error: 0.0370
# Loss: 0.03703442960977554 Tiempo transcurrido: 17.760742664337158
#
# --- Starting trial: run-92
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0716 - mean_squared_error: 0.0716
# Loss: 0.07162091881036758 Tiempo transcurrido: 84.54962134361267
#
# --- Starting trial: run-93
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0317 - mean_squared_error: 0.0317
# Loss: 0.03165964037179947 Tiempo transcurrido: 46.09028959274292
#
# --- Starting trial: run-94
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0324 - mean_squared_error: 0.0324
# Loss: 0.032395731657743454 Tiempo transcurrido: 26.84585738182068
#
# --- Starting trial: run-95
# {'layers': 3, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0310 - mean_squared_error: 0.0310
# Loss: 0.03097437508404255 Tiempo transcurrido: 17.165323972702026
#
# --- Starting trial: run-96
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0331 - mean_squared_error: 0.0331
# Loss: 0.03312380239367485 Tiempo transcurrido: 68.58928275108337
#
# --- Starting trial: run-97
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0311 - mean_squared_error: 0.0311
# Loss: 0.03105161339044571 Tiempo transcurrido: 36.41945028305054
#
# --- Starting trial: run-98
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0373 - mean_squared_error: 0.0373
# Loss: 0.037269316613674164 Tiempo transcurrido: 21.95944094657898
#
# --- Starting trial: run-99
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0458 - mean_squared_error: 0.0458
# Loss: 0.04580584913492203 Tiempo transcurrido: 14.658831596374512
#
# --- Starting trial: run-100
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0780 - mean_squared_error: 0.0780
# Loss: 0.0780356302857399 Tiempo transcurrido: 65.57365465164185
#
# --- Starting trial: run-101
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0407 - mean_squared_error: 0.0407
# Loss: 0.04067692905664444 Tiempo transcurrido: 36.40575098991394
#
# --- Starting trial: run-102
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0330 - mean_squared_error: 0.0330
# Loss: 0.03298039734363556 Tiempo transcurrido: 21.779213666915894
#
# --- Starting trial: run-103
# {'layers': 4, 'num_units': 50, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0782 - mean_squared_error: 0.0782
# Loss: 0.07819738239049911 Tiempo transcurrido: 15.013031721115112
#
# --- Starting trial: run-104
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0344 - mean_squared_error: 0.0344
# Loss: 0.03436390310525894 Tiempo transcurrido: 70.15986633300781
#
# --- Starting trial: run-105
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0351 - mean_squared_error: 0.0351
# Loss: 0.035083286464214325 Tiempo transcurrido: 39.25445747375488
#
# --- Starting trial: run-106
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0452 - mean_squared_error: 0.0452
# Loss: 0.04523846134543419 Tiempo transcurrido: 23.690897464752197
#
# --- Starting trial: run-107
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0392 - mean_squared_error: 0.0392
# Loss: 0.03922484070062637 Tiempo transcurrido: 15.481573820114136
#
# --- Starting trial: run-108
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0660 - mean_squared_error: 0.0660
# Loss: 0.06601815670728683 Tiempo transcurrido: 70.600839138031
#
# --- Starting trial: run-109
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0342 - mean_squared_error: 0.0342
# Loss: 0.034232962876558304 Tiempo transcurrido: 39.107354164123535
#
# --- Starting trial: run-110
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0323 - mean_squared_error: 0.0323
# Loss: 0.03230374678969383 Tiempo transcurrido: 23.241296529769897
#
# --- Starting trial: run-111
# {'layers': 4, 'num_units': 100, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0384 - mean_squared_error: 0.0384
# Loss: 0.03843862935900688 Tiempo transcurrido: 15.349869728088379
#
# --- Starting trial: run-112
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0354 - mean_squared_error: 0.0354
# Loss: 0.035426486283540726 Tiempo transcurrido: 76.73225736618042
#
# --- Starting trial: run-113
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0328 - mean_squared_error: 0.0328
# Loss: 0.03283989802002907 Tiempo transcurrido: 43.9605348110199
#
# --- Starting trial: run-114
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Loss: 0.03288693353533745 Tiempo transcurrido: 25.978742837905884
#
# --- Starting trial: run-115
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0326 - mean_squared_error: 0.0326
# Loss: 0.03256523236632347 Tiempo transcurrido: 17.646857976913452
#
# --- Starting trial: run-116
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.1024 - mean_squared_error: 0.1024
# Loss: 0.10242913663387299 Tiempo transcurrido: 79.75274348258972
#
# --- Starting trial: run-117
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0393 - mean_squared_error: 0.0393
# Loss: 0.0392511710524559 Tiempo transcurrido: 43.49129867553711
#
# --- Starting trial: run-118
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0460 - mean_squared_error: 0.0460
# Loss: 0.046002183109521866 Tiempo transcurrido: 25.89333724975586
#
# --- Starting trial: run-119
# {'layers': 4, 'num_units': 150, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0392 - mean_squared_error: 0.0392
# Loss: 0.039163265377283096 Tiempo transcurrido: 16.79173517227173
#
# --- Starting trial: run-120
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0332 - mean_squared_error: 0.0332
# Loss: 0.03315746784210205 Tiempo transcurrido: 94.98616623878479
#
# --- Starting trial: run-121
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0348 - mean_squared_error: 0.0348
# Loss: 0.03476586937904358 Tiempo transcurrido: 56.46636438369751
#
# --- Starting trial: run-122
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 8}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0321 - mean_squared_error: 0.0321
# Loss: 0.03206726163625717 Tiempo transcurrido: 31.92318844795227
#
# --- Starting trial: run-123
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.0001, 'batch_size': 16}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0374 - mean_squared_error: 0.0374
# Loss: 0.037363965064287186 Tiempo transcurrido: 20.229596853256226
#
# --- Starting trial: run-124
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 2}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0873 - mean_squared_error: 0.0873
# Loss: 0.08729954063892365 Tiempo transcurrido: 99.67405796051025
#
# --- Starting trial: run-125
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 4}
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0418 - mean_squared_error: 0.0418
# Loss: 0.0418490394949913 Tiempo transcurrido: 55.061033964157104
#
# --- Starting trial: run-126
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 8}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0415 - mean_squared_error: 0.0415
# Loss: 0.04150489345192909 Tiempo transcurrido: 32.40886473655701
#
# --- Starting trial: run-127
# {'layers': 4, 'num_units': 200, 'learning_rate': 0.001, 'batch_size': 16}
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0739 - mean_squared_error: 0.0739
# Loss: 0.07386931777000427 Tiempo transcurrido: 20.096463918685913
# 128

# %%
filename = "historial_jla_tunning.txt"
df = pd.DataFrame(datos, columns = ["Deep size", "Num units", "Learning rate", "Batch size", "MSE", "Tiempo de ejecución"])

df.sort_values(by=["MSE", "Tiempo de ejecución"], ascending=[True, True], ignore_index=True, inplace=True)

df.to_csv(filename, header=True, index=False, sep='\t', mode='w') # a=append, w=overwrite

# %%
df.head(2)
# Out:
#    Deep size  Num units  Learning rate  Batch size       MSE  \
# 0          3        200         0.0010          16  0.030974
# 1          4        150         0.0001          16  0.032565
#
#    Tiempo de ejecución
# 0            17.165324
# 1            17.646858

# %%
total_time = float(np.sum(df[["Tiempo de ejecución"]])/60)

print("Elapsed time {:.3f} minutes".format(total_time))
# Out:
# Elapsed time 9.367 minutes

# %%
df["Tiempo de ejecución"]
# Out:
# 0     17.165324
# 1     17.646858
# 2     22.394183
# 3     17.760743
# 4     20.229597
# 5     15.349870
# 6     19.257323
# 7     16.791735
# 8     15.481574
# 9     19.507200
# 10    14.471087
# 11    21.636302
# 12    12.571566
# 13    14.709437
# 14    21.433481
# 15    13.217486
# 16    14.658832
# 17    13.712613
# 18    13.837914
# 19    13.570510
# 20    21.216152
# 21    14.400748
# 22    18.681626
# 23    12.602004
# 24    13.103564
# 25    20.096464
# 26    15.013032
# 27    23.821012
# 28    19.668461
# 29    22.291659
# 30    23.506102
# 31    22.212524
# Name: Tiempo de ejecución, dtype: float64
