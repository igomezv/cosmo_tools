# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
from matplotlib import pyplot as plt

# %%
dir_name = '/home/isidro/Documents/github/cosmo_tools/models/neural/neuralike/chains/'

# %%
header = ['weights', 'logL', 'Om', 'Obh2', 'h', 'w', 'wa', 'BAOlike', 'DR14autolike', 'DR14crosslike', 'sixfgslike', 
           'mgslike', 'ebosslike', 'hdlike', 'Pantheonlike', 'theory_prior']
nested_data = pd.read_csv(dir_name+'waCDM_phy_CBAO+HD+Pantheon_nested_multi_4k_1.txt', sep=' ', names=header)
neuralike_data1 = pd.read_csv(dir_name+'waCDM_phy_CBAO+HD+Pantheon_nested_multi_neuralike_4kdlogz50_1.txt', sep=' ', names=header)
neuralike_data2 = pd.read_csv(dir_name+'waCDM_phy_HD+CBAO+Pantheon_nested_multi_neuralike_4kdlogz20_1.txt', sep=' ', names=header)

# %%
nested_data.head()
# Out:
#    weights         logL        Om      Obh2         h         w        wa  \
# 0      0.0  5039.166704  0.122594  0.024293  0.869570 -0.027015  1.721024
# 1      0.0  4005.739147  0.209762  0.024984  0.859991 -0.065210  1.861703
# 2      0.0  3829.491384  0.213835  0.022737  0.844886 -0.069794  1.855829
# 3      0.0  3723.390346  0.241254  0.023807  0.755129 -0.011220  1.999157
# 4      0.0  3571.474153  0.185441  0.024867  0.769612 -0.037513  1.798050
#
#        BAOlike  DR14autolike  DR14crosslike  sixfgslike   mgslike  ebosslike  \
# 0    -1.625589     -0.713475      -1.959423   -0.002244 -0.924464  -0.755315
# 1 -1937.705391    -21.991699     -26.938354   -2.000000 -4.500000  -2.000000
# 2 -1121.686162    -21.991699     -26.938354   -2.000000 -4.500000  -2.000000
# 3 -1102.829458    -21.991699     -26.938354   -2.000000 -4.500000  -2.000000
# 4  -862.807747    -21.991699     -26.938354   -2.000000 -3.984661  -2.000000
#
#         hdlike  Pantheonlike  theory_prior
# ...
